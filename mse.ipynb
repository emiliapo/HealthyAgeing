# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/mse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import math
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random
import decimal

last = []
labels = []
images = []
ageList = []
sexList = []

class Image:

    def image_processing(self, folder):
      files = os.listdir(folder)
      for filename in files:
        img = cv2.imread(folder+'/'+filename)
        if img is not None:
          label = self.establishLabels(filename)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          img = cv2.resize(img, (48, 48))
          images.append(img)
          ageList.append(label[0])
          sexList.append(label[1])

          labels.append(label)
      nofOGFiles = len(images.copy())
      self.dataAugmentation()
      #self.showProcessedImage(564)

      # convert the labels and images to NumPy arrays

      images_f = np.array(images)
      sexList_f = np.array(sexList)
      ageList_f = np.array(ageList)
      labels_f = np.array(labels)

      np.save('image.npy', images_f)
      np.save('gender.npy', sexList_f)
      np.save('age.npy', ageList_f)

      #self.showSexDistribution(sexList_f)
      #self.showAgeDistribution(ageList_f)

      # normalise the images array by dividing it with 255
      print("Number of images" +str(len(images_f)))
      images_f_2 = images_f / 255
      X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.25)
      #Y_train[0:5]

      Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
      Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

      # Y_train_2[0][0:5]

      # Y_train_2[1][0:5]

      Model = self.model((48, 48, 3))
      # print(Model.summary())

      self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)

      self.testRandomImages(8, nofOGFiles, images_f, images_f_2, Model)


    def establishLabels(self, filename):
        name = filename.split(".")[0]
        splitName = name.split("A")
        s = int(splitName[-1])
        a = int(splitName[-2])
        #output = {'sex': s, 'age': a}
        output = [a, s]

        return output

    def dataAugmentation(self):
      ogimages = images.copy()
      oglabels = labels.copy()
      i = 0
      #flip originals
      for ogimage in ogimages:
        placeholder = cv2.flip(ogimage, 1)
        images.append(placeholder)
        newlabel = oglabels[i]
        labels.append(newlabel)
        i+=1
      # #scale
      imageCopy2 = images.copy()
      lableCopy2 = labels.copy()
      flippedScaledImages = []
      j = 0
      for ogimage in imageCopy2:
        if j == 0: s = 1.75
        else:
          s = float(decimal.Decimal(random.randrange(110, 165))/100) #random between 1.1 and 3.0
        scaled = cv2.resize(ogimage, None, fx= s, fy= s, interpolation= cv2.INTER_LINEAR)
        #crop back to 48 48
        cntr = int(scaled.shape[0] /2)

        crop_img = scaled[cntr - 24:cntr + 24, cntr - 24:cntr + 24].copy()
        newimg = cv2.resize(crop_img, (48,48))

        images.append(newimg)
        newlabel = lableCopy2[j].copy()
        labels.append(newlabel)

        #flip zoomed
        placeholder = cv2.flip(newimg, 1)
        flippedScaledImages.append(placeholder)
        
        j+=1

      #for the sake of consistency  
      k = 0
      for f in flippedScaledImages:
        images.append(f)
        newlabel = lableCopy2[k].copy()
        labels.append(newlabel)
        k+=1


      
    def showProcessedImage(self, index):

        cv2_imshow(images[index])
        print(labels[index])

        print("Press any key to exit...")
        cv2.waitKey(0) #waits for any key press

    def showSexDistribution(self, sexList_f):
        values, counts = np.unique(sexList_f, return_counts=True)
        #print(counts) #returns 207, 219

        plt.xlabel("Sex")
        plt.ylabel("Distribution")
        sex = ['Female', 'Male']
        plt.bar(sex, counts)
        plt.show()


    def showAgeDistribution(self, ageList_f):
        values, counts = np.unique(ageList_f, return_counts=True)
        #print(counts)

        plt.plot(values, counts)
        plt.xlabel('ages')
        plt.ylabel('distribution')
        plt.show()

    def testRandomImages(self, num, nOfOGFiles, images_f, images_f_2, Model):
      for i in range(num):
        max = int(nOfOGFiles - 1)
        index = random.randint(0, max)
        self.test_image(index, images_f, images_f_2, Model)
        self.test_image(index + 426, images_f, images_f_2, Model)
        self.test_image(index + 852, images_f, images_f_2, Model)
        self.test_image(index + 1278, images_f, images_f_2, Model)
      self.test_image(0, images_f, images_f_2, Model)
      self.test_image(426, images_f, images_f_2, Model)
      self.test_image(852, images_f, images_f_2, Model)
      self.test_image(1278, images_f, images_f_2, Model)

    def Convolution(self, input_tensor, filters):
        x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
            input_tensor)
        x = Dropout(0.1)(x)
        x = Activation('relu')(x)
        return x


    def model(self, input_shape):
        inputs = Input((input_shape))

        conv_1 = self.Convolution(inputs, 32)
        maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
        conv_2 = self.Convolution(maxp_1, 64)
        maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
        conv_3 = self.Convolution(maxp_2, 128)
        maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
        conv_4 = self.Convolution(maxp_3, 256)
        maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
        flatten = Flatten()(maxp_4)
        dense_1 = Dense(64, activation='relu')(flatten)
        dense_2 = Dense(64, activation='relu')(flatten)
        drop_1 = Dropout(0.2)(dense_1)
        drop_2 = Dropout(0.2)(dense_2)
        output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
        output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

        model = Model(inputs=[inputs], outputs=[output_1, output_2])
        model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                      metrics=["accuracy"])
        return model

    def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                              Y_test, Y_train_2, Y_test_2):
        fle_s='Age_sex_detection.h5'
        checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       save_freq='epoch')
        Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
        callback_list=[checkpointer,Early_stop]

        History = Model.fit(X_train, Y_train_2,
                 validation_data=(X_test, Y_test_2),
                 epochs=500,
                 batch_size = 64,
                 callbacks=[callback_list])
        
        print("History: ")
        print(History.history)
        
        Model.evaluate(X_test, Y_test_2)
        pred=Model.predict(X_test)

        #print(pred[1])

        plt.plot(History.history['loss'])
        plt.plot(History.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #For sex

        plt.plot(History.history['sex_out_accuracy'])
        plt.plot(History.history['val_sex_out_accuracy'])
        plt.title('Model accuracy sex')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #for age

        fig, ax = plt.subplots()
        ax.scatter(Y_test_2[1], pred[1])
        ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
        ax.set_xlabel('Actual Age')
        ax.set_ylabel('Predicted Age')

        plt.show()

        # Calculation of Mean Squared Error (MSE) for sex
        msesex = mean_squared_error(Y_test_2[0], pred[0])
        maesex = mean_absolute_error(Y_test_2[0], pred[0])
        print("mean_squared_error sex: " + str(msesex))
        print("ROOT mean_squared_error sex: " + str(math.sqrt(msesex)))
        print("mean_absolute_error sex: " + str(maesex) + "\n")

        # Calculation of Mean Squared Error (MSE) for age
        mseage = mean_squared_error(Y_test_2[1], pred[1])
        maeage = mean_absolute_error(Y_test_2[1], pred[1])
        print("mean_squared_error age: " + str(mseage))
        print("ROOT mean_squared_error age: " + str(math.sqrt(mseage)))
        print("mean_absolute_error age: " + str(maeage))

        #for sex
        j = 0
        Pred_l=[]
        while(j<len(pred[0])):
          Pred_l.append(int(np.round(pred[0][j])))
          j+=1

        print("Report:")
        report=classification_report(Y_test_2[0], Pred_l)
        print(report)

        print("Results:")
        results = confusion_matrix(Y_test_2[0], Pred_l)
        sns.heatmap(results, annot=True)

    def test_image(self, ind, images_f, images_f_2, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1=Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      actualsex = ""

      if labels[ind][1] == 0:
        actualsex = "Female"
      if labels[ind][1] == 1:
        actualsex = "Male"
      print("Index: "+ str(ind))
      print("Actual age: " + str(labels[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + actualsex)
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
Image().image_processing(folder)
# Out:
# Number of images2556
# Epoch 1/500
# 30/30 [==============================] - 3s 54ms/step - loss: 45.5951 - sex_out_loss: 1.3123 - age_out_loss: 44.0128 - sex_out_accuracy: 0.5026 - age_out_accuracy: 0.0000e+00 - val_loss: 26.7844 - val_sex_out_loss: 0.7282 - val_age_out_loss: 25.8380 - val_sex_out_accuracy: 0.4726 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 26.78436, saving model to Age_sex_detection.h5
# Epoch 2/500
# 30/30 [==============================] - 1s 29ms/step - loss: 13.1537 - sex_out_loss: 0.7373 - age_out_loss: 12.2053 - sex_out_accuracy: 0.4957 - age_out_accuracy: 0.0000e+00 - val_loss: 28.1377 - val_sex_out_loss: 0.6892 - val_age_out_loss: 27.2518 - val_sex_out_accuracy: 0.5571 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 26.78436
# Epoch 3/500
# 30/30 [==============================] - 1s 29ms/step - loss: 11.8496 - sex_out_loss: 0.6900 - age_out_loss: 10.9653 - sex_out_accuracy: 0.5419 - age_out_accuracy: 0.0000e+00 - val_loss: 23.2369 - val_sex_out_loss: 0.6931 - val_age_out_loss: 22.3558 - val_sex_out_accuracy: 0.4617 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 26.78436 to 23.23688, saving model to Age_sex_detection.h5
# Epoch 4/500
# 30/30 [==============================] - 1s 30ms/step - loss: 11.8299 - sex_out_loss: 0.6923 - age_out_loss: 10.9512 - sex_out_accuracy: 0.5335 - age_out_accuracy: 0.0000e+00 - val_loss: 21.4693 - val_sex_out_loss: 0.7113 - val_age_out_loss: 20.5752 - val_sex_out_accuracy: 0.4726 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 23.23688 to 21.46932, saving model to Age_sex_detection.h5
# Epoch 5/500
# 30/30 [==============================] - 1s 30ms/step - loss: 10.0192 - sex_out_loss: 0.6932 - age_out_loss: 9.1441 - sex_out_accuracy: 0.5270 - age_out_accuracy: 0.0000e+00 - val_loss: 17.6285 - val_sex_out_loss: 0.6921 - val_age_out_loss: 16.7567 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss improved from 21.46932 to 17.62853, saving model to Age_sex_detection.h5
# Epoch 6/500
# 30/30 [==============================] - 1s 30ms/step - loss: 11.3872 - sex_out_loss: 0.6939 - age_out_loss: 10.5146 - sex_out_accuracy: 0.5004 - age_out_accuracy: 0.0000e+00 - val_loss: 23.4655 - val_sex_out_loss: 0.6920 - val_age_out_loss: 22.5971 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 17.62853
# Epoch 7/500
# 30/30 [==============================] - 1s 30ms/step - loss: 9.2311 - sex_out_loss: 0.6944 - age_out_loss: 8.3608 - sex_out_accuracy: 0.4924 - age_out_accuracy: 0.0000e+00 - val_loss: 26.9785 - val_sex_out_loss: 0.6930 - val_age_out_loss: 26.1116 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 17.62853
# Epoch 8/500
# 30/30 [==============================] - 1s 29ms/step - loss: 9.5457 - sex_out_loss: 0.6931 - age_out_loss: 8.6792 - sex_out_accuracy: 0.5123 - age_out_accuracy: 0.0000e+00 - val_loss: 18.4421 - val_sex_out_loss: 0.6928 - val_age_out_loss: 17.5774 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 17.62853
# Epoch 9/500
# 30/30 [==============================] - 1s 29ms/step - loss: 8.9846 - sex_out_loss: 0.6928 - age_out_loss: 8.1206 - sex_out_accuracy: 0.5191 - age_out_accuracy: 0.0000e+00 - val_loss: 18.0273 - val_sex_out_loss: 0.6927 - val_age_out_loss: 17.1654 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 17.62853
# Epoch 10/500
# 30/30 [==============================] - 1s 30ms/step - loss: 8.8935 - sex_out_loss: 0.6928 - age_out_loss: 8.0324 - sex_out_accuracy: 0.5166 - age_out_accuracy: 0.0000e+00 - val_loss: 19.2329 - val_sex_out_loss: 0.6925 - val_age_out_loss: 18.3740 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 17.62853
# Epoch 11/500
# 30/30 [==============================] - 1s 29ms/step - loss: 9.2759 - sex_out_loss: 0.6929 - age_out_loss: 8.4173 - sex_out_accuracy: 0.5142 - age_out_accuracy: 0.0000e+00 - val_loss: 20.3451 - val_sex_out_loss: 0.6928 - val_age_out_loss: 19.4880 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 17.62853
# Epoch 12/500
# 30/30 [==============================] - 1s 31ms/step - loss: 9.0452 - sex_out_loss: 0.6938 - age_out_loss: 8.1878 - sex_out_accuracy: 0.4970 - age_out_accuracy: 0.0000e+00 - val_loss: 20.1566 - val_sex_out_loss: 0.6926 - val_age_out_loss: 19.3020 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 17.62853
# Epoch 13/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7
- val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 14.52303
# Epoch 72/500
# 30/30 [==============================] - 1s 29ms/step - loss: 9.5849 - sex_out_loss: 0.6927 - age_out_loss: 8.7742 - sex_out_accuracy: 0.5173 - age_out_accuracy: 0.0000e+00 - val_loss: 16.2905 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.4794 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 14.52303
# Epoch 73/500
# 30/30 [==============================] - 1s 30ms/step - loss: 8.2151 - sex_out_loss: 0.6931 - age_out_loss: 7.4031 - sex_out_accuracy: 0.5073 - age_out_accuracy: 0.0000e+00 - val_loss: 17.4480 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.6367 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 14.52303
# Epoch 74/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7327 - sex_out_loss: 0.6929 - age_out_loss: 6.9208 - sex_out_accuracy: 0.5105 - age_out_accuracy: 0.0000e+00 - val_loss: 17.6505 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.8394 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 14.52303
# Epoch 75/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5893 - sex_out_loss: 0.6928 - age_out_loss: 6.7776 - sex_out_accuracy: 0.5139 - age_out_accuracy: 0.0000e+00 - val_loss: 18.2612 - val_sex_out_loss: 0.6923 - val_age_out_loss: 17.4504 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 14.52303
# Epoch 76/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.8040 - sex_out_loss: 0.6933 - age_out_loss: 6.9920 - sex_out_accuracy: 0.5008 - age_out_accuracy: 0.0000e+00 - val_loss: 16.4361 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.6255 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 14.52303
# Epoch 77/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.9300 - sex_out_loss: 0.6928 - age_out_loss: 7.1189 - sex_out_accuracy: 0.5137 - age_out_accuracy: 0.0000e+00 - val_loss: 17.5159 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.7058 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 14.52303
# Epoch 78/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6710 - sex_out_loss: 0.6931 - age_out_loss: 6.8601 - sex_out_accuracy: 0.5072 - age_out_accuracy: 0.0000e+00 - val_loss: 19.9769 - val_sex_out_loss: 0.6923 - val_age_out_loss: 19.1670 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 14.52303
# Epoch 79/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.9689 - sex_out_loss: 0.6941 - age_out_loss: 7.1569 - sex_out_accuracy: 0.4979 - age_out_accuracy: 0.0000e+00 - val_loss: 15.3258 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.5150 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 14.52303
# Epoch 80/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.7045 - sex_out_loss: 0.6931 - age_out_loss: 6.8932 - sex_out_accuracy: 0.5073 - age_out_accuracy: 0.0000e+00 - val_loss: 16.3574 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.5472 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 14.52303
# Epoch 81/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6248 - sex_out_loss: 0.6933 - age_out_loss: 6.8135 - sex_out_accuracy: 0.4999 - age_out_accuracy: 0.0000e+00 - val_loss: 15.5212 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.7110 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 14.52303
# Epoch 82/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.4300 - sex_out_loss: 0.6929 - age_out_loss: 6.6191 - sex_out_accuracy: 0.5108 - age_out_accuracy: 0.0000e+00 - val_loss: 16.1156 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.3049 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 14.52303
# Epoch 83/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.8327 - sex_out_loss: 0.6927 - age_out_loss: 7.0216 - sex_out_accuracy: 0.5153 - age_out_accuracy: 0.0000e+00 - val_loss: 16.9445 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.1341 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 14.52303
# Epoch 84/500
# 30/30 [==============================] - 1s 30ms/step - loss: 8.0618 - sex_out_loss: 0.6932 - age_out_loss: 7.2508 - sex_out_accuracy: 0.5033 - age_out_accuracy: 0.0000e+00 - val_loss: 20.0266 - val_sex_out_loss: 0.6923 - val_age_out_loss: 19.2174 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 14.52303
# Epoch 85/500
# 30/30 [==============================] - 1s 30ms/step - loss: 8.8324 - sex_out_loss: 0.6917 - age_out_loss: 8.0232 - sex_out_accuracy: 0.5419 - age_out_accuracy: 0.0000e+00 - val_loss: 16.7650 - val_sex_out_loss: 0.6922 - val_age_out_loss: 15.9548 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 14.52303
# Epoch 86/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5022 - sex_out_loss: 0.6934 - age_out_loss: 6.6909 - sex_out_accuracy: 0.5013 - age_out_accuracy: 0.0000e+00 - val_loss: 16.4662 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.6559 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 14.52303
# Epoch 87/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5544 - sex_out_loss: 0.6934 - age_out_loss: 6.7431 - sex_out_accuracy: 0.4988 - age_out_accuracy: 0.0000e+00 - val_loss: 18.7080 - val_sex_out_loss: 0.6923 - val_age_out_loss: 17.8979 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 14.52303
# Epoch 88/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.7267 - sex_out_loss: 0.6934 - age_out_loss: 6.9150 - sex_out_accuracy: 0.4981 - age_out_accuracy: 0.0000e+00 - val_loss: 15.3033 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.4920 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 14.52303
# Epoch 89/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.7443 - sex_out_loss: 0.6924 - age_out_loss: 6.9334 - sex_out_accuracy: 0.5237 - age_out_accuracy: 0.0000e+00 - val_loss: 16.2541 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.4443 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 14.52303
# Epoch 90/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.8265 - sex_out_loss: 0.6931 - age_out_loss: 7.0157 - sex_out_accuracy: 0.5064 - age_out_accuracy: 0.0000e+00 - val_loss: 17.5491 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.7395 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 14.52303
# Epoch 91/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.8352 - sex_out_loss: 0.6927 - age_out_loss: 7.0251 - sex_out_accuracy: 0.5164 - age_out_accuracy: 0.0000e+00 - val_loss: 14.5273 - val_sex_out_loss: 0.6922 - val_age_out_loss: 13.7173 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 14.52303
# Epoch 92/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.7783 - sex_out_loss: 0.6927 - age_out_loss: 6.9681 - sex_out_accuracy: 0.5155 - age_out_accuracy: 0.0000e+00 - val_loss: 17.0706 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.2604 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 14.52303
# Epoch 93/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.8191 - sex_out_loss: 0.6931 - age_out_loss: 7.0079 - sex_out_accuracy: 0.5054 - age_out_accuracy: 0.0000e+00 - val_loss: 15.1947 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.3838 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 14.52303
# Epoch 94/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6701 - sex_out_loss: 0.6940 - age_out_loss: 6.8578 - sex_out_accuracy: 0.4832 - age_out_accuracy: 0.0000e+00 - val_loss: 14.1354 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.3247 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00094: val_loss improved from 14.52303 to 14.13541, saving model to Age_sex_detection.h5
# Epoch 95/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6319 - sex_out_loss: 0.6926 - age_out_loss: 6.8209 - sex_out_accuracy: 0.5197 - age_out_accuracy: 0.0000e+00 - val_loss: 14.8524 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.0422 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 14.13541
# Epoch 96/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5785 - sex_out_loss: 0.6932 - age_out_loss: 6.7674 - sex_out_accuracy: 0.5025 - age_out_accuracy: 0.0000e+00 - val_loss: 16.4670 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.6572 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 14.13541
# Epoch 97/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7079 - sex_out_loss: 0.6932 - age_out_loss: 6.8972 - sex_out_accuracy: 0.5047 - age_out_accuracy: 0.0000e+00 - val_loss: 16.4941 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.6845 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 14.13541
# Epoch 98/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.3639 - sex_out_loss: 0.6924 - age_out_loss: 6.5542 - sex_out_accuracy: 0.5251 - age_out_accuracy: 0.0000e+00 - val_loss: 17.5727 - val_sex_out_loss: 0.6922 - val_age_out_loss: 16.7634 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 14.13541
# Epoch 99/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.7688 - sex_out_loss: 0.6925 - age_out_loss: 6.9591 - sex_out_accuracy: 0.5211 - age_out_accuracy: 0.0000e+00 - val_loss: 16.9707 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.1613 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 14.13541
# Epoch 100/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.5371 - sex_out_loss: 0.6934 - age_out_loss: 6.7265 - sex_out_accuracy: 0.4985 - age_out_accuracy: 0.0000e+00 - val_loss: 17.6556 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.8460 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 14.13541
# Epoch 101/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.9199 - sex_out_loss: 0.6928 - age_out_loss: 7.1095 - sex_out_accuracy: 0.5139 - age_out_accuracy: 0.0000e+00 - val_loss: 17.7912 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.9812 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 14.13541
# Epoch 102/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5509 - sex_out_loss: 0.6932 - age_out_loss: 6.7397 - sex_out_accuracy: 0.5038 - age_out_accuracy: 0.0000e+00 - val_loss: 16.6013 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.7913 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 14.13541
# Epoch 103/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.3932 - sex_out_loss: 0.6924 - age_out_loss: 6.5831 - sex_out_accuracy: 0.5244 - age_out_accuracy: 0.0000e+00 - val_loss: 15.5755 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.7665 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00103: val_loss did not improve from 14.13541
# Epoch 104/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7930 - sex_out_loss: 0.6927 - age_out_loss: 6.9836 - sex_out_accuracy: 0.5166 - age_out_accuracy: 0.0000e+00 - val_loss: 17.5668 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.7583 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00104: val_loss did not improve from 14.13541
# Epoch 105/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.9182 - sex_out_loss: 0.6927 - age_out_loss: 7.1093 - sex_out_accuracy: 0.5166 - age_out_accuracy: 0.0000e+00 - val_loss: 16.2808 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.4726 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00105: val_loss did not improve from 14.13541
# Epoch 106/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.4574 - sex_out_loss: 0.6924 - age_out_loss: 6.6490 - sex_out_accuracy: 0.5250 - age_out_accuracy: 0.0000e+00 - val_loss: 14.5724 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.7640 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00106: val_loss did not improve from 14.13541
# Epoch 107/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6287 - sex_out_loss: 0.6927 - age_out_loss: 6.8200 - sex_out_accuracy: 0.5166 - age_out_accuracy: 0.0000e+00 - val_loss: 17.7673 - val_sex_out_loss: 0.6923 - val_age_out_loss: 16.9593 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00107: val_loss did not improve from 14.13541
# Epoch 108/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.6410 - sex_out_loss: 0.6924 - age_out_loss: 6.8324 - sex_out_accuracy: 0.5244 - age_out_accuracy: 0.0000e+00 - val_loss: 16.5080 - val_sex_out_loss: 0.6922 - val_age_out_loss: 15.6988 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00108: val_loss did not improve from 14.13541
# Epoch 109/500
# 30/30 [==============================] - 1s 29ms/step - loss: 7.6879 - sex_out_loss: 0.6925 - age_out_loss: 6.8781 - sex_out_accuracy: 0.5228 - age_out_accuracy: 0.0000e+00 - val_loss: 14.6605 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.8503 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00109: val_loss did not improve from 14.13541
# Epoch 110/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.5299 - sex_out_loss: 0.6932 - age_out_loss: 6.7191 - sex_out_accuracy: 0.5045 - age_out_accuracy: 0.0000e+00 - val_loss: 15.2222 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.4121 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00110: val_loss did not improve from 14.13541
# Epoch 111/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.4526 - sex_out_loss: 0.6928 - age_out_loss: 6.6421 - sex_out_accuracy: 0.5136 - age_out_accuracy: 0.0000e+00 - val_loss: 15.8451 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.0358 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00111: val_loss did not improve from 14.13541
# Epoch 112/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.6075 - sex_out_loss: 0.6933 - age_out_loss: 6.7971 - sex_out_accuracy: 0.5121 - age_out_accuracy: 0.0000e+00 - val_loss: 16.0041 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.1945 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00112: val_loss did not improve from 14.13541
# Epoch 113/500
# 30/30 [==============================] - 1s 32ms/step - loss: 7.4026 - sex_out_loss: 0.6931 - age_out_loss: 6.5921 - sex_out_accuracy: 0.5070 - age_out_accuracy: 0.0000e+00 - val_loss: 14.9559 - val_sex_out_loss: 0.6924 - val_age_out_loss: 14.1456 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00113: val_loss did not improve from 14.13541
# Epoch 114/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7846 - sex_out_loss: 0.6930 - age_out_loss: 6.9737 - sex_out_accuracy: 0.5093 - age_out_accuracy: 0.0000e+00 - val_loss: 14.0092 - val_sex_out_loss: 0.6924 - val_age_out_loss: 13.1993 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00114: val_loss improved from 14.13541 to 14.00924, saving model to Age_sex_detection.h5
# Epoch 115/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.6136 - sex_out_loss: 0.6922 - age_out_loss: 6.8042 - sex_out_accuracy: 0.5320 - age_out_accuracy: 0.0000e+00 - val_loss: 15.8398 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.0305 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00115: val_loss did not improve from 14.00924
# Epoch 116/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.5369 - sex_out_loss: 0.6922 - age_out_loss: 6.7275 - sex_out_accuracy: 0.5288 - age_out_accuracy: 0.0000e+00 - val_loss: 16.0239 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.2148 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00116: val_loss did not improve from 14.00924
# Epoch 117/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.5273 - sex_out_loss: 0.6925 - age_out_loss: 6.7181 - sex_out_accuracy: 0.5214 - age_out_accuracy: 0.0000e+00 - val_loss: 14.3043 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.4949 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00117: val_loss did not improve from 14.00924
# Epoch 118/500
# 30/30 [==============================] - 1s 33ms/step - loss: 7.7950 - sex_out_loss: 0.6928 - age_out_loss: 6.9852 - sex_out_accuracy: 0.5139 - age_out_accuracy: 0.0000e+00 - val_loss: 16.6305 - val_sex_out_loss: 0.6923 - val_age_out_loss: 15.8213 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00118: val_loss did not improve from 14.00924
# Epoch 119/500
# 30/30 [==============================] - 1s 32ms/step - loss: 7.7805 - sex_out_loss: 0.6935 - age_out_loss: 6.9698 - sex_out_accuracy: 0.4934 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2618 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.4516 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00119: val_loss improved from 14.00924 to 12.26184, saving model to Age_sex_detection.h5
# Epoch 120/500
# 30/30 [==============================] - 1s 31ms/step - loss: 8.1515 - sex_out_loss: 0.6929 - age_out_loss: 7.3408 - sex_out_accuracy: 0.5107 - age_out_accuracy: 0.0000e+00 - val_loss: 13.2673 - val_sex_out_loss: 0.6923 - val_age_out_loss: 12.4565 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00120: val_loss did not improve from 12.26184
# Epoch 121/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.8914 - sex_out_loss: 0.6930 - age_out_loss: 7.0801 - sex_out_accuracy: 0.5092 - age_out_accuracy: 0.0000e+00 - val_loss: 14.2240 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.4127 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00121: val_loss did not improve from 12.26184
# Epoch 122/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7826 - sex_out_loss: 0.6930 - age_out_loss: 6.9703 - sex_out_accuracy: 0.5079 - age_out_accuracy: 0.0000e+00 - val_loss: 18.7747 - val_sex_out_loss: 0.6923 - val_age_out_loss: 17.9635 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00122: val_loss did not improve from 12.26184
# Epoch 123/500
# 30/30 [==============================] - 1s 30ms/step - loss: 7.8075 - sex_out_loss: 0.6930 - age_out_loss: 6.9954 - sex_out_accuracy: 0.5092 - age_out_accuracy: 0.0000e+00 - val_loss: 15.2750 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.4639 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00123: val_loss did not improve from 12.26184
# Epoch 124/500
# 30/30 [==============================] - 1s 31ms/step - loss: 8.0090 - sex_out_loss: 0.6928 - age_out_loss: 7.1974 - sex_out_accuracy: 0.5135 - age_out_accuracy: 0.0000e+00 - val_loss: 15.1183 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.3071 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00124: val_loss did not improve from 12.26184
# Epoch 125/500
# 30/30 [==============================] - 1s 31ms/step - loss: 7.7343 - sex_out_loss: 0.6929 - age_out_loss: 6.9226 - sex_out_accuracy: 0.5107 - age_out_accuracy: 0.0000e+00 - val_loss: 14.9498 - val_sex_out_loss: 0.6923 - val_age_out_loss: 14.1388 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00125: val_loss did not improve from 12.26184
# Epoch 126/500
# ...
#
# Epoch 00424: val_loss did not improve from 8.78222
# Epoch 425/500
# 30/30 [==============================] - 1s 32ms/step - loss: 6.9404 - sex_out_loss: 0.6927 - age_out_loss: 6.0786 - sex_out_accuracy: 0.5160 - age_out_accuracy: 0.0000e+00 - val_loss: 12.7493 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.8876 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00425: val_loss did not improve from 8.78222
# Epoch 426/500
# 30/30 [==============================] - 1s 31ms/step - loss: 6.8135 - sex_out_loss: 0.6929 - age_out_loss: 5.9508 - sex_out_accuracy: 0.5116 - age_out_accuracy: 0.0000e+00 - val_loss: 14.1892 - val_sex_out_loss: 0.6923 - val_age_out_loss: 13.3272 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00426: val_loss did not improve from 8.78222
# Epoch 427/500
# 30/30 [==============================] - 1s 31ms/step - loss: 6.9418 - sex_out_loss: 0.6923 - age_out_loss: 6.0796 - sex_out_accuracy: 0.5257 - age_out_accuracy: 0.0000e+00 - val_loss: 12.0503 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.1886 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00427: val_loss did not improve from 8.78222
# Epoch 428/500
# 30/30 [==============================] - 1s 32ms/step - loss: 6.5926 - sex_out_loss: 0.6929 - age_out_loss: 5.7305 - sex_out_accuracy: 0.5117 - age_out_accuracy: 0.0000e+00 - val_loss: 11.8664 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.0048 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00428: val_loss did not improve from 8.78222
# Epoch 429/500
# 30/30 [==============================] - 1s 33ms/step - loss: 6.9984 - sex_out_loss: 0.6927 - age_out_loss: 6.1362 - sex_out_accuracy: 0.5176 - age_out_accuracy: 0.0000e+00 - val_loss: 10.8084 - val_sex_out_loss: 0.6922 - val_age_out_loss: 9.9462 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00429: val_loss did not improve from 8.78222
# Epoch 430/500
# 30/30 [==============================] - 1s 32ms/step - loss: 6.7044 - sex_out_loss: 0.6930 - age_out_loss: 5.8416 - sex_out_accuracy: 0.5082 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2176 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.3556 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00430: val_loss did not improve from 8.78222
# Epoch 431/500
# 30/30 [==============================] - 1s 33ms/step - loss: 6.6511 - sex_out_loss: 0.6929 - age_out_loss: 5.7884 - sex_out_accuracy: 0.5124 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1246 - val_sex_out_loss: 0.6923 - val_age_out_loss: 11.2623 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00431: val_loss did not improve from 8.78222
# Epoch 432/500
# 30/30 [==============================] - 1s 32ms/step - loss: 6.5063 - sex_out_loss: 0.6937 - age_out_loss: 5.6425 - sex_out_accuracy: 0.4914 - age_out_accuracy: 0.0000e+00 - val_loss: 11.1501 - val_sex_out_loss: 0.6923 - val_age_out_loss: 10.2875 - val_sex_out_accuracy: 0.5274 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 
report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       302
#            1       0.53      1.00      0.69       337
#
#     accuracy                           0.53       639
#    macro avg       0.26      0.50      0.35       639
# weighted avg       0.28      0.53      0.36       639
#
# Results:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE61987D550>
# Index: 156
# Actual age: 78
# Predicted Age: 69
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE617BF6790>
# Index: 582
# Actual age: 78
# Predicted Age: 68
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE622932B10>
# Index: 1008
# Actual age: 78
# Predicted Age: 64
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6D0140890>
# Index: 1434
# Actual age: 78
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE622463E10>
# Index: 203
# Actual age: 66
# Predicted Age: 59
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE622932410>
# Index: 629
# Actual age: 66
# Predicted Age: 60
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6D0140210>
# Index: 1055
# Actual age: 66
# Predicted Age: 62
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE622466FD0>
# Index: 1481
# Actual age: 66
# Predicted Age: 60
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6198FC510>
# Index: 292
# Actual age: 71
# Predicted Age: 64
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6198FC710>
# Index: 718
# Actual age: 71
# Predicted Age: 69
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE61996FB50>
# Index: 1144
# Actual age: 71
# Predicted Age: 63
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6891BFF10>
# Index: 1570
# Actual age: 71
# Predicted Age: 64
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6232B6310>
# Index: 294
# Actual age: 71
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6891BF150>
# Index: 720
# Actual age: 71
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE622490710>
# Index: 1146
# Actual age: 71
# Predicted Age: 65
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE62294D750>
# Index: 1572
# Actual age: 71
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178E44D0>
# Index: 131
# Actual age: 75
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE619927390>
# Index: 557
# Actual age: 75
# Predicted Age: 65
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE61986EED0>
# Index: 983
# Actual age: 75
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178DBA50>
# Index: 1409
# Actual age: 75
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE619999D10>
# Index: 372
# Actual age: 78
# Predicted Age: 65
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6223D6B10>
# Index: 798
# Actual age: 78
# Predicted Age: 65
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6223D66D0>
# Index: 1224
# Actual age: 78
# Predicted Age: 67
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6223D6690>
# Index: 1650
# Actual age: 78
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE619943690>
# Index: 13
# Actual age: 66
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6198996D0>
# Index: 439
# Actual age: 66
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178DBBD0>
# Index: 865
# Actual age: 66
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE619899710>
# Index: 1291
# Actual age: 66
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE619899390>
# Index: 27
# Actual age: 65
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178E3F90>
# Index: 453
# Actual age: 65
# Predicted Age: 63
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6198E5650>
# Index: 879
# Actual age: 65
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178E3790>
# Index: 1305
# Actual age: 65
# Predicted Age: 61
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178DB150>
# Index: 0
# Actual age: 65
# Predicted Age: 59
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE6178DB150>
# Index: 426
# Actual age: 65
# Predicted Age: 60
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE623248E90>
# Index: 852
# Actual age: 65
# Predicted Age: 64
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE623260790>
# Index: 1278
# Actual age: 65
# Predicted Age: 62
# Actual sex: Female
# Predicted Sex: Female
