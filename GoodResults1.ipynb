# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/GoodResults1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random

last = []
labels = []
images = []
ageList = []
sexList = []

class Image:

    def image_processing(self, folder):
      files = os.listdir(folder)
      nOfFiles = len(files)
      for filename in files:
        img = cv2.imread(folder+'/'+filename)
        if img is not None:
          label = self.establishLabels(filename)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          img = cv2.resize(img, (48, 48))
          images.append(img)
          ageList.append(label[0])
          sexList.append(label[1])

          labels.append(label)

      #self.showProcessedImage(23)

      # convert the labels and images to NumPy arrays

      images_f = np.array(images)
      sexList_f = np.array(sexList)
      ageList_f = np.array(ageList)
      labels_f = np.array(labels)

      np.save(folder + 'image.npy', images_f)
      np.save(folder + 'gender.npy', sexList_f)
      np.save(folder + 'age.npy', ageList_f)

      #self.showSexDistribution(sexList_f)
      #self.showAgeDistribution(ageList_f)

      # normalise the images array by dividing it with 255

      images_f_2 = images_f / 255
      X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.75)
      #Y_train[0:5]

      Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
      Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

      # Y_train_2[0][0:5]

      # Y_train_2[1][0:5]

      Model = self.model((48, 48, 3))
      # print(Model.summary())

      self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)

      self.testRandomImages(8, nOfFiles, images_f, images_f_2, Model)


    def establishLabels(self, filename):
        name = filename.split(".")[0]
        splitName = name.split("A")
        s = int(splitName[-1])
        a = int(splitName[-2])
        #output = {'sex': s, 'age': a}
        output = [a, s]

        return output

    def showProcessedImage(self, index):

        cv2_imshow(images[index])
        print(ageList[index])
        print(sexList[index])

        print("Press any key to exit...")
        cv2.waitKey(0) #waits for any key press

    def showSexDistribution(self, sexList_f):
        values, counts = np.unique(sexList_f, return_counts=True)
        #print(counts) #returns 207, 219

        plt.xlabel("Sex")
        plt.ylabel("Distribution")
        sex = ['Female', 'Male']
        plt.bar(sex, counts)
        plt.show()


    def showAgeDistribution(self, ageList_f):
        values, counts = np.unique(ageList_f, return_counts=True)
        #print(counts)

        plt.plot(values, counts)
        plt.xlabel('ages')
        plt.ylabel('distribution')
        plt.show()

    def testRandomImages(self, num, nOfFiles, images_f, images_f_2, Model):
      for i in range(num):
        max = int(nOfFiles - 1)
        index = random.randint(0, max)
        self.test_image(index, images_f, images_f_2, Model)

    def Convolution(self, input_tensor, filters):
        x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
            input_tensor)
        x = Dropout(0.1)(x)
        x = Activation('relu')(x)
        return x


    def model(self, input_shape):
        inputs = Input((input_shape))

        conv_1 = self.Convolution(inputs, 32)
        maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
        conv_2 = self.Convolution(maxp_1, 64)
        maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
        conv_3 = self.Convolution(maxp_2, 128)
        maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
        conv_4 = self.Convolution(maxp_3, 256)
        maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
        flatten = Flatten()(maxp_4)
        dense_1 = Dense(64, activation='relu')(flatten)
        dense_2 = Dense(64, activation='relu')(flatten)
        drop_1 = Dropout(0.2)(dense_1)
        drop_2 = Dropout(0.2)(dense_2)
        output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
        output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

        model = Model(inputs=[inputs], outputs=[output_1, output_2])
        model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                      metrics=["accuracy"])
        return model

    def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                              Y_test, Y_train_2, Y_test_2):
        fle_s='Age_sex_detection.h5'
        checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       save_freq='epoch')
        Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
        callback_list=[checkpointer,Early_stop]

        History = Model.fit(X_train, Y_train_2,
                 batch_size=64,
                 validation_data=(X_test, Y_test_2),
                 epochs=500,
                 callbacks=[callback_list])
        
        Model.evaluate(X_test, Y_test_2)
        pred=Model.predict(X_test)

        #print(pred[1])

        plt.plot(History.history['loss'])
        plt.plot(History.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #For sex

        plt.plot(History.history['sex_out_accuracy'])
        plt.plot(History.history['val_sex_out_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #for age

        fig, ax = plt.subplots()
        ax.scatter(Y_test_2[1], pred[1])
        ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
        ax.set_xlabel('Actual Age')
        ax.set_ylabel('Predicted Age')

        plt.show()

        #for sex
        j = 0
        Pred_l=[]
        while(j<len(pred[0])):
          Pred_l.append(int(np.round(pred[0][j])))
          j+=1

        print("Report:")
        report=classification_report(Y_test_2[0], Pred_l)
        print(report)

        print("Results:")
        results = confusion_matrix(Y_test_2[0], Pred_l)
        sns.heatmap(results, annot=True)

    def test_image(self, ind, images_f, images_f_2, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1=Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      actualsex = ""

      if labels[ind][1] == 0:
        actualsex = "Female"
      if labels[ind][1] == 1:
        actualsex = "Male"
      print("Index: "+ str(ind))
      print("Actual age: " + str(labels[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + actualsex)
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
Image().image_processing(folder)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 2s 582ms/step - loss: 73.3267 - sex_out_loss: 0.6969 - age_out_loss: 72.3273 - sex_out_accuracy: 0.4759 - age_out_accuracy: 0.0000e+00 - val_loss: 71.1904 - val_sex_out_loss: 0.6931 - val_age_out_loss: 70.2046 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 71.19044, saving model to Age_sex_detection.h5
# Epoch 2/500
# 2/2 [==============================] - 0s 81ms/step - loss: 70.2426 - sex_out_loss: 0.7439 - age_out_loss: 69.2070 - sex_out_accuracy: 0.5167 - age_out_accuracy: 0.0000e+00 - val_loss: 63.1696 - val_sex_out_loss: 0.7037 - val_age_out_loss: 62.1804 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 71.19044 to 63.16960, saving model to Age_sex_detection.h5
# Epoch 3/500
# 2/2 [==============================] - 0s 77ms/step - loss: 55.3263 - sex_out_loss: 0.8835 - age_out_loss: 54.1581 - sex_out_accuracy: 0.4844 - age_out_accuracy: 0.0000e+00 - val_loss: 33.8906 - val_sex_out_loss: 0.7071 - val_age_out_loss: 32.9025 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 63.16960 to 33.89064, saving model to Age_sex_detection.h5
# Epoch 4/500
# 2/2 [==============================] - 0s 73ms/step - loss: 24.0443 - sex_out_loss: 1.7521 - age_out_loss: 22.0114 - sex_out_accuracy: 0.5167 - age_out_accuracy: 0.0000e+00 - val_loss: 11.1146 - val_sex_out_loss: 0.7325 - val_age_out_loss: 10.1045 - val_sex_out_accuracy: 0.4750 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 33.89064 to 11.11461, saving model to Age_sex_detection.h5
# Epoch 5/500
# 2/2 [==============================] - 0s 76ms/step - loss: 31.4696 - sex_out_loss: 1.3813 - age_out_loss: 29.8114 - sex_out_accuracy: 0.5052 - age_out_accuracy: 0.0000e+00 - val_loss: 30.3962 - val_sex_out_loss: 1.1796 - val_age_out_loss: 28.9447 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 11.11461
# Epoch 6/500
# 2/2 [==============================] - 0s 74ms/step - loss: 19.9640 - sex_out_loss: 1.4723 - age_out_loss: 18.2204 - sex_out_accuracy: 0.4833 - age_out_accuracy: 0.0000e+00 - val_loss: 39.5313 - val_sex_out_loss: 0.7562 - val_age_out_loss: 38.5078 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 11.11461
# Epoch 7/500
# 2/2 [==============================] - 0s 75ms/step - loss: 24.6692 - sex_out_loss: 0.9674 - age_out_loss: 23.4350 - sex_out_accuracy: 0.5178 - age_out_accuracy: 0.0000e+00 - val_loss: 32.6364 - val_sex_out_loss: 1.0512 - val_age_out_loss: 31.3214 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 11.11461
# Epoch 8/500
# 2/2 [==============================] - 0s 79ms/step - loss: 16.6190 - sex_out_loss: 1.2511 - age_out_loss: 15.1044 - sex_out_accuracy: 0.5367 - age_out_accuracy: 0.0000e+00 - val_loss: 17.7416 - val_sex_out_loss: 0.7103 - val_age_out_loss: 16.7704 - val_sex_out_accuracy: 0.4625 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 11.11461
# Epoch 9/500
# 2/2 [==============================] - 0s 77ms/step - loss: 16.5916 - sex_out_loss: 0.8592 - age_out_loss: 15.4718 - sex_out_accuracy: 0.5104 - age_out_accuracy: 0.0000e+00 - val_loss: 18.4110 - val_sex_out_loss: 0.7853 - val_age_out_loss: 17.3681 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 11.11461
# Epoch 10/500
# 2/2 [==============================] - 0s 77ms/step - loss: 17.1795 - sex_out_loss: 0.8801 - age_out_loss: 16.0423 - sex_out_accuracy: 0.5482 - age_out_accuracy: 0.0000e+00 - val_loss: 28.4363 - val_sex_out_loss: 0.7429 - val_age_out_loss: 27.4392 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 11.11461
# Epoch 11/500
# 2/2 [==============================] - 0s 76ms/step - loss: 14.3444 - sex_out_loss: 0.8450 - age_out_loss: 13.2457 - sex_out_accuracy: 0.5241 - age_out_accuracy: 0.0000e+00 - val_loss: 29.9014 - val_sex_out_loss: 0.7387 - val_age_out_loss: 28.9114 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 11.11461
# Epoch 12/500
# 2/2 [==============================] - 0s 75ms/step - loss: 14.8102 - sex_out_loss: 0.8246 - age_out_loss: 13.7346 - sex_out_accuracy: 0.5273 - age_out_accuracy: 0.0000e+00 - val_loss: 25.6631 - val_sex_out_loss: 0.6989 - val_age_out_loss: 24.7153 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 11.11461
# Epoch 13/500
# 2/2 [==============================] - 0s 80ms/step - loss: 13.9931 - sex_out_loss: 0.7343 - age_out_loss: 13.0102 - sex_out_accuracy: 0.4970 - age_out_accuracy: 0.0000e+00 - val_loss: 22.4349 - val_sex_out_loss: 0.7270 - val_age_out_loss: 21.4612 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 11.11461
# Epoch 14/500
# 2/2 [==============================] - 0s 89ms/step - loss: 14.3531 - sex_out_loss: 0.7435 - age_out_loss: 13.3633 - sex_out_accuracy: 0.5345 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7337 - val_sex_out_loss: 0.7120 - val_age_out_loss: 21.7773 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 11.11461
# Epoch 15/500
# 2/2 [==============================] - 0s 76ms/step - loss: 13.4689 - sex_out_loss: 0.6918 - age_out_loss: 12.5329 - sex_out_accuracy: 0.5597 - age_out_accuracy: 0.0000e+00 - val_loss: 24.5960 - val_sex_out_loss: 0.6945 - val_age_out_loss: 23.6591 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 11.11461
# Epoch 16/500
# 2/2 [==============================] - 0s 80ms/step - loss: 12.4952 - sex_out_loss: 0.6925 - age_out_loss: 11.5605 - sex_out_accuracy: 0.5093 - age_out_accuracy: 0.0000e+00 - val_loss: 24.1217 - val_sex_out_loss: 0.6935 - val_age_out_loss: 23.1877 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 11.11461
# Epoch 17/500
# 2/2 [==============================] - 0s 74ms/step - loss: 11.8087 - sex_out_loss: 0.7023 - age_out_loss: 10.8660 - sex_out_accuracy: 0.5230 - age_out_accuracy: 0.0000e+00 - val_loss: 24.3884 - val_sex_out_loss: 0.6951 - val_age_out_loss: 23.4544 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 11.11461
# Epoch 18/500
# 2/2 [==============================] - 0s 80ms/step - loss: 13.2187 - sex_out_loss: 0.7036 - age_out_loss: 12.2764 - sex_out_accuracy: 0.5356 - age_out_accuracy: 0.0000e+00 - val_loss: 25.4564 - val_sex_out_loss: 0.6955 - val_age_out_loss: 24.5236 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 11.11461
# Epoch 19/500
# 2/2 [==============================] - 0s 82ms/step - loss: 12.8375 - sex_out_loss: 0.6955 - age_out_loss: 11.9049 - sex_out_accuracy: 0.5816 - age_out_accuracy: 0.0000e+00 - val_loss: 26.7829 - val_sex_out_loss: 0.6948 - val_age_out_loss: 25.8522 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 11.11461
# Epoch 20/500
# 2/2 [==============================] - 0s 80ms/step - loss: 13.7457 - sex_out_loss: 0.6921 - age_out_loss: 12.8180 - sex_out_accuracy: 0.5085 - age_out_accuracy: 0.0000e+00 - val_loss: 26.0786 - val_sex_out_loss: 0.6969 - val_age_out_loss: 25.1471 - val_sex_out_accuracy: 0.4719 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 11.11461
# Epoch 21/500
# 2/2 [==============================] - 0s 80ms/step - loss: 11.7214 - sex_out_loss: 0.6961 - age_out_loss: 10.7910 - sex_out_accuracy: 0.5104 - age_out_accuracy: 0.0000e+00 - val_loss: 24.4943 - val_sex_out_loss: 0.6974 - val_age_out_loss: 23.5635 - val_sex_out_accuracy: 0.4875 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 11.11461
# Epoch 22/500
# 2/2 [==============================] - 0s 82ms/step - loss: 11.9077 - sex_out_loss: 0.6920 - age_out_loss: 10.9824 - sex_out_accuracy: 0.4863 - age_out_accuracy: 0.0000e+00 - val_loss: 22.2854 - val_sex_out_loss: 0.6971 - val_age_out_loss: 21.3559 - val_sex_out_accuracy: 0.4875 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 11.11461
# Epoch 23/500
# 2/2 [==============================] - 0s 74ms/step - loss: 13.0983 - sex_out_loss: 0.6923 - age_out_loss: 12.1737 - sex_out_accuracy: 0.5397 - age_out_accuracy: 0.0000e+00 - val_loss: 23.5858 - val_sex_out_loss: 0.6928 - val_age_out_loss: 22.6616 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 11.11461
# Epoch 24/500
# 2/2 [==============================] - 0s 81ms/step - loss: 11.6910 - sex_out_loss: 0.6891 - age_out_loss: 10.7707 - sex_out_accuracy: 0.5408 - age_out_accuracy: 0.0000e+00 - val_loss: 26.2948 - val_sex_out_loss: 0.6920 - val_age_out_loss: 25.3725 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 11.11461
# Epoch 25/500
# 2/2 [==============================] - 0s 77ms/step - loss: 13.2943 - sex_out_loss: 0.6817 - age_out_loss: 12.3824 - sex_out_accuracy: 0.5356 - age_out_accuracy: 0.0000e+00 - val_loss: 24.3848 - val_sex_out_loss: 0.6917 - val_age_out_loss: 23.4635 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 11.11461
# Epoch 26/500
# 2/2 [==============================] - 0s 80ms/step - loss: 11.0691 - sex_out_loss: 0.6864 - age_out_loss: 10.1533 - sex_out_accuracy: 0.5304 - age_out_accuracy: 0.0000e+00 - val_loss: 21.5676 - val_sex_out_loss: 0.6917 - val_age_out_loss: 20.6471 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 11.11461
# Epoch 27/500
# 2/2 [==============================] - 0s 78ms/step - loss: 12.6104 - sex_out_loss: 0.6854 - age_out_loss: 11.6962 - sex_out_accuracy: 0.5367 - age_out_accuracy: 0.0000e+00 - val_loss: 22.6399 - val_sex_out_loss: 0.6917 - val_age_out_loss: 21.7202 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 11.11461
# Epoch 28/500
# 2/2 [==============================] - 0s 83ms/step - loss: 11.9225 - sex_out_loss: 0.6885 - age_out_loss: 11.0060 - sex_out_accuracy: 0.5616 - age_out_accuracy: 0.0000e+00 - val_loss: 24.2882 - val_sex_out_loss: 0.6918 - val_age_out_loss: 23.3691 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 11.11461
# Epoch 29/500
# 2/2 [==============================] - 0s 84ms/step - loss: 11.2911 - sex_out_loss: 0.6894 - age_out_loss: 10.3745 - sex_out_accuracy: 0.5115 - age_out_accuracy: 0.0000e+00 - val_loss: 21.8045 - val_sex_out_loss: 0.6919 - val_age_out_loss: 20.8859 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 11.11461
# Epoch 30/500
# 2/2 [==============================] - 0s 82ms/step - loss: 11.3657 - sex_out_loss: 0.6928 - age_out_loss: 10.4462 - sex_out_accuracy: 0.5011 - age_out_accuracy: 0.0000e+00 - val_loss: 28.5258 - val_sex_out_loss: 0.6923 - val_age_out_loss: 27.6077 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 11.11461
# Epoch 31/500
# 2/2 [==============================] - 0s 80ms/step - loss: 14.0219 - sex_out_loss: 0.6857 - age_out_loss: 13.1105 - sex_out_accuracy: 0.5638 - age_out_accuracy: 0.0000e+00 - val_loss: 26.9317 - val_sex_out_loss: 0.6924 - val_age_out_loss: 26.0141 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 11.11461
# Epoch 32/500
# 2/2 [==============================] - 0s 85ms/step - loss: 13.3211 - sex_out_loss: 0.6868 - age_out_loss: 12.4090 - sex_out_accuracy: 0.5304 - age_out_accuracy: 0.0000e+00 - val_loss: 18.2121 - val_sex_out_loss: 0.6919 - val_age_out_loss: 17.2953 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 11.11461
# Epoch 33/500
# 2/2 [==============================] - 0s 83ms/step - loss: 13.4163 - sex_out_loss: 0.6852 - age_out_loss: 12.5062 - sex_out_accuracy: 0.5701 - age_out_accuracy: 0.0000e+00 - val_loss: 26.9346 - val_sex_out_loss: 0.6916 - val_age_out_loss: 26.0189 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 11.11461
# Epoch 34/500
# 2/2 [==============================] - 0s 84ms/step - loss: 12.1540 - sex_out_loss: 0.6863 - age_out_loss: 11.2437 - sex_out_accuracy: 0.5304 - age_out_accuracy: 0.0000e+00 - val_loss: 30.2536 - val_sex_out_loss: 0.6918 - val_age_out_loss: 29.3384 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 11.11461
# Epoch 35/500
# 2/2 [==============================] - 0s 80ms/step - loss: 13.1302 - sex_out_loss: 0.6845 - age_out_loss: 12.2223 - sex_out_accuracy: 0.5681 - age_out_accuracy: 0.0000e+00 - val_loss: 16.6225 - val_sex_out_loss: 0.6919 - val_age_out_loss: 15.7070 - val_sex_out_accuracy: 0.5406 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 11.11461
# Epoch 36/500
# 2/2 [==============================] - 0s 85ms/step - loss: 14.6690 - sex_out_loss: 0.6851 - age_out_loss: 13.7604 - sex_out_accuracy: 0.5826 - age_out_accuracy: 0.0000e+00 - val_loss: 22.0804 - val_sex_out_loss: 0.6938 - val_age_out_loss: 21.1638 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 11.11461
# Epoch 37/500
# 2/2 [==============================] - 0s 82ms/step - loss: 13.0408 - sex_out_loss: 0.6789 - age_out_loss: 12.1392 - sex_out_accuracy: 0.5983 - age_out_accuracy: 0.0000e+00 - val_loss: 31.5161 - val_sex_out_loss: 0.6946 - val_age_out_loss: 30.5996 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 11.11461
# Epoch 38/500
# 2/2 [==============================] - 0s 85ms/step - loss: 14.6718 - sex_out_loss: 0.6847 - age_out_loss: 13.7652 - sex_out_accuracy: 0.5616 - age_out_accuracy: 0.0000e+00 - val_loss: 24.7479 - val_sex_out_loss: 0.6929 - val_age_out_loss: 23.8332 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 11.11461
# Epoch 39/500
# 2/2 [==============================] - 0s 82ms/step - loss: 13.1841 - sex_out_loss: 0.6723 - age_out_loss: 12.2900 - sex_out_accuracy: 0.6182 - age_out_accuracy: 0.0000e+00 - val_loss: 22.2467 - val_sex_out_loss: 0.6929 - val_age_out_loss: 21.3323 - val_sex_out_accuracy: 0.4938 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 11.11461
# Epoch 40/500
# 2/2 [==============================] - 0s 79ms/step - loss: 10.5919 - sex_out_loss: 0.6818 - age_out_loss: 9.6887 - sex_out_accuracy: 0.5544 - age_out_accuracy: 0.0000e+00 - val_loss: 26.6797 - val_sex_out_loss: 0.6928 - val_age_out_loss: 25.7659 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 11.11461
# Epoch 41/500
# 2/2 [==============================] - 0s 76ms/step - loss: 11.2048 - sex_out_loss: 0.6738 - age_out_loss: 10.3101 - sex_out_accuracy: 0.5835 - age_out_accuracy: 0.0000e+00 - val_loss: 24.4057 - val_sex_out_loss: 0.6928 - val_age_out_loss: 23.4921 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 11.11461
# Epoch 42/500
# 2/2 [==============================] - 0s 84ms/step - loss: 10.7380 - sex_out_loss: 0.6891 - age_out_loss: 9.8282 - sex_out_accuracy: 0.5304 - age_out_accuracy: 0.0000e+00 - val_loss: 19.5381 - val_sex_out_loss: 0.6920 - val_age_out_loss: 18.6255 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 11.11461
# Epoch 43/500
# 2/2 [==============================] - 0s 82ms/step - loss: 11.8597 - sex_out_loss: 0.6855 - age_out_loss: 10.9536 - sex_out_accuracy: 0.5000 - age_out_accuracy: 0.0000e+00 - val_loss: 25.5973 - val_sex_out_loss: 0.6919 - val_age_out_loss: 24.6854 - val_sex_out_accuracy: 0.5375 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 11.11461
# Epoch 44/500
# 2/2 [==============================] - 0s 89ms/step - loss: 10.7098 - sex_out_loss: 0.6802 - age_out_loss: 9.8097 - sex_out_accuracy: 0.5523 - age_out_accuracy: 0.0000e+00 - val_loss: 28.3088 - val_sex_out_loss: 0.6929 - val_age_out_loss: 27.3964 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00044: val_loss did not improve from 11.11461
# Epoch 45/500
# 2/2 [==============================] - 0s 84ms/step - loss: 12.5520 - sex_out_loss: 0.6837 - age_out_loss: 11.6488 - sex_out_accuracy: 0.4907 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7086 - val_sex_out_loss: 0.6921 - val_age_out_loss: 21.7970 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 11.11461
# Epoch 46/500
# 2/2 [==============================] - 0s 83ms/step - loss: 10.3579 - sex_out_loss: 0.6819 - age_out_loss: 9.4565 - sex_out_accuracy: 0.5293 - age_out_accuracy: 0.0000e+00 - val_loss: 19.1512 - val_sex_out_loss: 0.6913 - val_age_out_loss: 18.2405 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00046: val_loss did not improve from 11.11461
# Epoch 47/500
# 2/2 [==============================] - 0s 77ms/step - loss: 11.7845 - sex_out_loss: 0.6855 - age_out_loss: 10.8797 - sex_out_accuracy: 0.5534 - age_out_accuracy: 0.0000e+00 - val_loss: 26.3503 - val_sex_out_loss: 0.6914 - val_age_out_loss: 25.4400 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 11.11461
# Epoch 48/500
# 2/2 [==============================] - 0s 83ms/step - loss: 10.5289 - sex_out_loss: 0.6944 - age_out_loss: 9.6157 - sex_out_accuracy: 0.5503 - age_out_accuracy: 0.0000e+00 - val_loss: 23.0260 - val_sex_out_loss: 0.6922 - val_age_out_loss: 22.1151 - val_sex_out_accuracy: 0.5281 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 11.11461
# Epoch 49/500
# 2/2 [==============================] - 0s 82ms/step - loss: 10.8310 - sex_out_loss: 0.6780 - age_out_loss: 9.9342 - sex_out_accuracy: 0.5794 - age_out_accuracy: 0.0000e+00 - val_loss: 20.4394 - val_sex_out_loss: 0.6930 - val_age_out_loss: 19.5277 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 11.11461
# Epoch 50/500
# 2/2 [==============================] - 0s 78ms/step - loss: 11.0257 - sex_out_loss: 0.6902 - age_out_loss: 10.1169 - sex_out_accuracy: 0.4937 - age_out_accuracy: 0.0000e+00 - val_loss: 25.8543 - val_sex_out_loss: 0.6922 - val_age_out_loss: 24.9439 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 11.11461
# Epoch 51/500
# 2/2 [==============================] - 0s 83ms/step - loss: 10.3369 - sex_out_loss: 0.6850 - age_out_loss: 9.4337 - sex_out_accuracy: 0.5000 - age_out_accuracy: 0.0000e+00 - val_loss: 25.5250 - val_sex_out_loss: 0.6923 - val_age_out_loss: 24.6144 - val_sex_out_accuracy: 0.5406 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 11.11461
# Epoch 52/500
# 2/2 [==============================] - 0s 82ms/step - loss: 10.1522 - sex_out_loss: 0.6767 - age_out_loss: 9.2572 - sex_out_accuracy: 0.5994 - age_out_accuracy: 0.0000e+00 - val_loss: 18.4072 - val_sex_out_loss: 0.6922 - val_age_out_loss: 17.4966 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 11.11461
# Epoch 53/500
# 2/2 [==============================] - 0s 85ms/step - loss: 12.1607 - sex_out_loss: 0.6825 - age_out_loss: 11.2598 - sex_out_accuracy: 0.5607 - age_out_accuracy: 0.0000e+00 - val_loss: 25.0824 - val_sex_out_loss: 0.6928 - val_age_out_loss: 24.1715 - val_sex_out_accuracy: 0.5281 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 11.11461
# Epoch 54/500
# 2/2 [==============================] - 0s 79ms/step - loss: 10.7412 - sex_out_loss: 0.6882 - age_out_loss: 9.8350 - sex_out_accuracy: 0.4844 - age_out_accuracy: 0.0000e+00 - val_loss: 24.6946 - val_sex_out_loss: 0.6932 - val_age_out_loss: 23.7835 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 11.11461
# Epoch 55/500
# 2/2 [==============================] - 0s 79ms/step - loss: 11.0956 - sex_out_loss: 0.6908 - age_out_loss: 10.1870 - sex_out_accuracy: 0.5356 - age_out_accuracy: 0.0000e+00 - val_loss: 23.1013 - val_sex_out_loss: 0.6918 - val_age_out_loss: 22.1916 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 11.11461
# Epoch 56/500
# 2/2 [==============================] - 0s 83ms/step - loss: 10.6110 - sex_out_loss: 0.6856 - age_out_loss: 9.7075 - sex_out_accuracy: 0.5764 - age_out_accuracy: 0.0000e+00 - val_loss: 23.7723 - val_sex_out_loss: 0.6918 - val_age_out_loss: 22.8627 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 11.11461
# Epoch 57/500
# 2/2 [==============================] - 0s 85ms/step - loss: 11.2549 - sex_out_loss: 0.6847 - age_out_loss: 10.3523 - sex_out_accuracy: 0.5555 - age_out_accuracy: 0.0000e+00 - val_loss: 23.1561 - val_sex_out_loss: 0.6941 - val_age_out_loss: 22.2442 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 11.11461
# Epoch 58/500
# 2/2 [==============================] - 0s 81ms/step - loss: 9.7831 - sex_out_loss: 0.6709 - age_out_loss: 8.8944 - sex_out_accuracy: 0.5711 - age_out_accuracy: 0.0000e+00 - val_loss: 23.6343 - val_sex_out_loss: 0.6983 - val_age_out_loss: 22.7181 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 11.11461
# Epoch 59/500
# 2/2 [==============================] - 0s 83ms/step - loss: 9.1837 - sex_out_loss: 0.6937 - age_out_loss: 8.2721 - sex_out_accuracy: 0.4959 - age_out_accuracy: 0.0000e+00 - val_loss: 19.6283 - val_sex_out_loss: 0.6970 - val_age_out_loss: 18.7132 - val_sex_out_accuracy: 0.4844 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 11.11461
# Epoch 60/500
# 2/2 [==============================] - 0s 79ms/step - loss: 11.6216 - sex_out_loss: 0.6997 - age_out_loss: 10.7038 - sex_out_accuracy: 0.5241 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7999 - val_sex_out_loss: 0.6927 - val_age_out_loss: 21.8893 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 11.11461
# Epoch 61/500
# 2/2 [==============================] - 0s 82ms/step - loss: 9.7715 - sex_out_loss: 0.6775 - age_out_loss: 8.8762 - sex_out_accuracy: 0.6108 - age_out_accuracy: 0.0000e+00 - val_loss: 25.3470 - val_sex_out_loss: 0.6935 - val_age_out_loss: 24.4358 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 11.11461
# Epoch 62/500
# 2/2 [==============================] - 0s 79ms/step - loss: 10.0812 - sex_out_loss: 0.6961 - age_out_loss: 9.1674 - sex_out_accuracy: 0.5095 - age_out_accuracy: 0.0000e+00 - val_loss: 20.0571 - val_sex_out_loss: 0.6933 - val_age_out_loss: 19.1458 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 11.11461
# Epoch 63/500
# 2/2 [==============================] - 0s 80ms/step - loss: 10.1337 - sex_out_loss: 0.6777 - age_out_loss: 9.2381 - sex_out_accuracy: 0.5805 - age_out_accuracy: 0.0000e+00 - val_loss: 20.6945 - val_sex_out_loss: 0.6931 - val_age_out_loss: 19.7834 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 11.11461
# Epoch 64/500
# 2/2 [==============================] - 0s 78ms/step - loss: 10.6565 - sex_out_loss: 0.6860 - age_out_loss: 9.7525 - sex_out_accuracy: 0.5586 - age_out_accuracy: 0.0000e+00 - val_loss: 23.1386 - val_sex_out_loss: 0.6942 - val_age_out_loss: 22.2264 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 11.11461
# Epoch 65/500
# 2/2 [==============================] - 0s 81ms/step - loss: 9.1718 - sex_out_loss: 0.6994 - age_out_loss: 8.2545 - sex_out_accuracy: 0.5356 - age_out_accuracy: 0.0000e+00 - val_loss: 20.6115 - val_sex_out_loss: 0.6953 - val_age_out_loss: 19.6980 - val_sex_out_accuracy: 0.4875 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 11.11461
# Epoch 66/500
# 2/2 [==============================] - 0s 84ms/step - loss: 10.0353 - sex_out_loss: 0.6861 - age_out_loss: 9.1309 - sex_out_accuracy: 0.5794 - age_out_accuracy: 0.0000e+00 - val_loss: 23.7675 - val_sex_out_loss: 0.6935 - val_age_out_loss: 22.8559 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 11.11461
# Epoch 67/500
# 2/2 [==============================] - 0s 84ms/step - loss: 9.4015 - sex_out_loss: 0.6891 - age_out_loss: 8.4942 - sex_out_accuracy: 0.5659 - age_out_accuracy: 0.0000e+00 - val_loss: 24.1422 - val_sex_out_loss: 0.6932 - val_age_out_loss: 23.2309 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 11.11461
# Epoch 68/500
# 2/2 [==============================] - 0s 80ms/step - loss: 10.6829 - sex_out_loss: 0.6828 - age_out_loss: 9.7820 - sex_out_accuracy: 0.5386 - age_out_accuracy: 0.0000e+00 - val_loss: 23.3348 - val_sex_out_loss: 0.6937 - val_age_out_loss: 22.4231 - val_sex_out_accuracy: 0.4719 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 11.11461
# Epoch 69/500
# 2/2 [==============================] - 0s 79ms/step - loss: 9.6649 - sex_out_loss: 0.6851 - age_out_loss: 8.7618 - sex_out_accuracy: 0.5742 - age_out_accuracy: 0.0000e+00 - val_loss: 22.5227 - val_sex_out_loss: 0.6944 - val_age_out_loss: 21.6103 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 11.11461
# Epoch 70/500
# 2/2 [==============================] - 0s 81ms/step - loss: 10.0587 - sex_out_loss: 0.6821 - age_out_loss: 9.1585 - sex_out_accuracy: 0.5764 - age_out_accuracy: 0.0000e+00 - val_loss: 20.6409 - val_sex_out_loss: 0.6952 - val_age_out_loss: 19.7276 - val_sex_out_accuracy: 0.4906 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 11.11461
# Epoch 71/500
# 2/2 [==============================] - 0s 83ms/step - loss: 9.0732 - sex_out_loss: 0.6858 - age_out_loss: 8.1694 - sex_out_accuracy: 0.5627 - age_out_accuracy: 0.0000e+00 - val_loss: 25.6944 - val_sex_out_loss: 0.6954 - val_age_out_loss: 24.7813 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 11.11461
# Epoch 72/500
# 2/2 [==============================] - 0s 84ms/step - loss: 9.6780 - sex_out_loss: 0.6910 - age_out_loss: 8.7693 - sex_out_accuracy: 0.5000 - age_out_accuracy: 0.0000e+00 - val_loss: 18.9354 - val_sex_out_loss: 0.6927 - val_age_out_loss: 18.0249 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 11.11461
# Epoch 73/500
# 2/2 [==============================] - 0s 82ms/step - loss: 10.1559 - sex_out_loss: 0.6931 - age_out_loss: 9.2449 - sex_out_accuracy: 0.5167 - age_out_accuracy: 0.0000e+00 - val_loss: 23.8851 - val_sex_out_loss: 0.6926 - val_age_out_loss: 22.9749 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 11.11461
# Epoch 74/500
# 2/2 [==============================] - 0s 78ms/step - loss: 10.2115 - sex_out_loss: 0.6960 - age_out_loss: 9.2980 - sex_out_accuracy: 0.4707 - age_out_accuracy: 0.0000e+00 - val_loss: 24.4798 - val_sex_out_loss: 0.6926 - val_age_out_loss: 23.5698 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 11.11461
# Epoch 75/500
# 2/2 [==============================] - 0s 79ms/step - loss: 9.9583 - sex_out_loss: 0.6898 - age_out_loss: 9.0511 - sex_out_accuracy: 0.5514 - age_out_accuracy: 0.0000e+00 - val_loss: 18.4185 - val_sex_out_loss: 0.6925 - val_age_out_loss: 17.5083 - val_sex_out_accuracy: 0.5063 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 11.11461
# Epoch 76/500
# 2/2 [==============================] - 0s 95ms/step - loss: 9.6582 - sex_out_loss: 0.6922 - age_out_loss: 8.7484 - sex_out_accuracy: 0.5011 - age_out_accuracy: 0.0000e+00 - val_loss: 27.4367 - val_sex_out_loss: 0.6943 - val_age_out_loss: 26.5253 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 11.11461
# Epoch 77/500
# 2/2 [==============================] - 0s 79ms/step - loss: 11.4353 - sex_out_loss: 0.6836 - age_out_loss: 10.5346 - sex_out_accuracy: 0.5774 - age_out_accuracy: 0.0000e+00 - val_loss: 21.5566 - val_sex_out_loss: 0.6940 - val_age_out_loss: 20.6455 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 11.11461
# Epoch 78/500
# 2/2 [==============================] - 0s 80ms/step - loss: 9.8207 - sex_out_loss: 0.6936 - age_out_loss: 8.9099 - sex_out_accuracy: 0.5199 - age_out_accuracy: 0.0000e+00 - val_loss: 21.3989 - val_sex_out_loss: 0.6927 - val_age_out_loss: 20.4891 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 11.11461
# Epoch 79/500
# 2/2 [==============================] - 0s 82ms/step - loss: 9.3463 - sex_out_loss: 0.6841 - age_out_loss: 8.4453 - sex_out_accuracy: 0.5659 - age_out_accuracy: 0.0000e+00 - val_loss: 27.1741 - val_sex_out_loss: 0.6928 - val_age_out_loss: 26.2648 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 11.11461
# 10/10 [==============================] - 0s 4ms/step - loss: 11.1146 - sex_out_loss: 0.7325 - age_out_loss: 10.1045 - sex_out_accuracy: 0.4750 - age_out_accuracy: 0.0000e+00
# Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.64      0.54       155
#            1       0.49      0.32      0.39       165
#
#     accuracy                           0.48       320
#    macro avg       0.48      0.48      0.46       320
# weighted avg       0.48      0.47      0.46       320
#
# Results:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6AEBD4850>
# Index: 227
# Actual age: 65
# Predicted Age: 79
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6AE5B6350>
# Index: 171
# Actual age: 76
# Predicted Age: 77
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6B07F6E90>
# Index: 273
# Actual age: 69
# Predicted Age: 60
# Actual sex: Male
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6F004A2D0>
# Index: 290
# Actual age: 71
# Predicted Age: 94
# Actual sex: Male
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6F00B31D0>
# Index: 193
# Actual age: 78
# Predicted Age: 61
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6B11A4590>
# Index: 163
# Actual age: 76
# Predicted Age: 80
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6F0197610>
# Index: 199
# Actual age: 78
# Predicted Age: 62
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA6B06FF190>
# Index: 160
# Actual age: 76
# Predicted Age: 61
# Actual sex: Female
# Predicted Sex: Male
