# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/RandomImageTestAdded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random

last = []
labels = []
images = []
ageList = []
sexList = []

class Image:

    def image_processing(self, folder):
      files = os.listdir(folder)
      nOfFiles = len(files)
      for filename in files:
        img = cv2.imread(folder+'/'+filename)
        if img is not None:
          label = self.establishLabels(filename)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          img = cv2.resize(img, (48, 48))
          images.append(img)
          ageList.append(label[0])
          sexList.append(label[1])

          labels.append(label)

      #self.showProcessedImage(23)

      # convert the labels and images to NumPy arrays

      images_f = np.array(images)
      sexList_f = np.array(sexList)
      ageList_f = np.array(ageList)
      labels_f = np.array(labels)

      np.save(folder + 'image.npy', images_f)
      np.save(folder + 'gender.npy', sexList_f)
      np.save(folder + 'age.npy', ageList_f)

      #self.showSexDistribution(sexList_f)
      #self.showAgeDistribution(ageList_f)

      # normalise the images array by dividing it with 255

      images_f_2 = images_f / 255
      X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.75)
      #print(Y_train[0:5])

      Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
      Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

      #print(Y_train_2[0][0:5])

      #print(Y_train_2[1][0:5])

      Model = self.model((48, 48, 3))
      # print(Model.summary())

      self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)

      self.testRandomImages(8, nOfFiles, images_f, images_f_2, Model)


    def establishLabels(self, filename):
        name = filename.split(".")[0]
        splitName = name.split("A")
        s = int(splitName[-1])
        a = int(splitName[-2])
        #output = {'sex': s, 'age': a}
        output = [a, s]

        return output

    def showProcessedImage(self, index):

        cv2_imshow(images[index])
        print(ageList[index])
        print(sexList[index])

        print("Press any key to exit...")
        cv2.waitKey(0) #waits for any key press

    def showSexDistribution(self, sexList_f):
        values, counts = np.unique(sexList_f, return_counts=True)
        #print(counts) #returns 207, 219

        plt.xlabel("Sex")
        plt.ylabel("Distribution")
        sex = ['Female', 'Male']
        plt.bar(sex, counts)
        plt.show()


    def showAgeDistribution(self, ageList_f):
        values, counts = np.unique(ageList_f, return_counts=True)
        #print(counts)

        plt.plot(values, counts)
        plt.xlabel('ages')
        plt.ylabel('distribution')
        plt.show()

    def testRandomImages(self, num, nOfFiles, images_f, images_f_2, Model):
      for i in range(num):
        max = int(nOfFiles - 1)
        index = random.randint(0, max)
        self.test_image(index, images_f, images_f_2, Model)

    def Convolution(self, input_tensor, filters):
        x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
            input_tensor)
        x = Dropout(0.1)(x)
        x = Activation('relu')(x)
        return x


    def model(self, input_shape):
        inputs = Input((input_shape))

        conv_1 = self.Convolution(inputs, 32)
        maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
        conv_2 = self.Convolution(maxp_1, 64)
        maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
        conv_3 = self.Convolution(maxp_2, 128)
        maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
        conv_4 = self.Convolution(maxp_3, 256)
        maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
        flatten = Flatten()(maxp_4)
        dense_1 = Dense(64, activation='relu')(flatten)
        dense_2 = Dense(64, activation='relu')(flatten)
        drop_1 = Dropout(0.2)(dense_1)
        drop_2 = Dropout(0.2)(dense_2)
        output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
        output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

        model = Model(inputs=[inputs], outputs=[output_1, output_2])
        model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                      metrics=["accuracy"])
        return model

    def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                              Y_test, Y_train_2, Y_test_2):
        fle_s='Age_sex_detection.h5'
        checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
        Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
        callback_list=[checkpointer,Early_stop]

        History = Model.fit(X_train, Y_train_2,
                 batch_size=64,
                 validation_data=(X_test, Y_test_2),
                 epochs=500,
                 callbacks=[callback_list])
        
        Model.evaluate(X_test, Y_test_2)
        pred=Model.predict(X_test)

        #print(pred[1])

        plt.plot(History.history['loss'])
        plt.plot(History.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #For sex

        plt.plot(History.history['sex_out_accuracy'])
        plt.plot(History.history['val_sex_out_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #for age

        fig, ax = plt.subplots()
        ax.scatter(Y_test_2[1], pred[1])
        ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
        ax.set_xlabel('Actual Age')
        ax.set_ylabel('Predicted Age')

        plt.show()

        #for sex
        j = 0
        Pred_l=[]
        while(j<len(pred[0])):
          Pred_l.append(int(np.round(pred[0][j])))
          j+=1

        print("Report:")
        report=classification_report(Y_test_2[0], Pred_l)
        print(report)

        print("Results:")
        results = confusion_matrix(Y_test_2[0], Pred_l)
        sns.heatmap(results, annot=True)

    def test_image(self, ind, images_f, images_f_2, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1=Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      print("Index: "+ str(ind))
      print("Actual age: " + str(labels[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + str(labels[ind][1]))
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
Image().image_processing(folder)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 302ms/step - loss: 72.2382 - sex_out_loss: 0.6891 - age_out_loss: 71.2467 - sex_out_accuracy: 0.5649 - age_out_accuracy: 0.0000e+00 - val_loss: 69.5158 - val_sex_out_loss: 0.6991 - val_age_out_loss: 68.5216 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 69.51577, saving model to Age_sex_detection.h5
# Epoch 2/500
# 2/2 [==============================] - 0s 69ms/step - loss: 65.8447 - sex_out_loss: 0.7002 - age_out_loss: 64.8503 - sex_out_accuracy: 0.5544 - age_out_accuracy: 0.0000e+00 - val_loss: 53.6880 - val_sex_out_loss: 0.9920 - val_age_out_loss: 52.4074 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 69.51577 to 53.68804, saving model to Age_sex_detection.h5
# Epoch 3/500
# 2/2 [==============================] - 0s 70ms/step - loss: 36.5815 - sex_out_loss: 1.2828 - age_out_loss: 35.0105 - sex_out_accuracy: 0.4529 - age_out_accuracy: 0.0000e+00 - val_loss: 16.5915 - val_sex_out_loss: 2.7152 - val_age_out_loss: 13.5917 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 53.68804 to 16.59153, saving model to Age_sex_detection.h5
# Epoch 4/500
# 2/2 [==============================] - 0s 67ms/step - loss: 43.5689 - sex_out_loss: 3.0068 - age_out_loss: 40.2782 - sex_out_accuracy: 0.5586 - age_out_accuracy: 0.0000e+00 - val_loss: 20.6916 - val_sex_out_loss: 1.2058 - val_age_out_loss: 19.2072 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 16.59153
# Epoch 5/500
# 2/2 [==============================] - 0s 66ms/step - loss: 17.0670 - sex_out_loss: 1.8660 - age_out_loss: 14.9232 - sex_out_accuracy: 0.4633 - age_out_accuracy: 0.0000e+00 - val_loss: 41.8864 - val_sex_out_loss: 0.7723 - val_age_out_loss: 40.8412 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 16.59153
# Epoch 6/500
# 2/2 [==============================] - 0s 70ms/step - loss: 27.5636 - sex_out_loss: 1.0957 - age_out_loss: 26.1956 - sex_out_accuracy: 0.4781 - age_out_accuracy: 0.0000e+00 - val_loss: 42.3438 - val_sex_out_loss: 0.8722 - val_age_out_loss: 41.2034 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 16.59153
# Epoch 7/500
# 2/2 [==============================] - 0s 66ms/step - loss: 25.6971 - sex_out_loss: 1.0411 - age_out_loss: 24.3883 - sex_out_accuracy: 0.5252 - age_out_accuracy: 0.0000e+00 - val_loss: 29.6013 - val_sex_out_loss: 1.0966 - val_age_out_loss: 28.2404 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 16.59153
# Epoch 8/500
# 2/2 [==============================] - 0s 72ms/step - loss: 15.6146 - sex_out_loss: 1.1528 - age_out_loss: 14.1980 - sex_out_accuracy: 0.5846 - age_out_accuracy: 0.0000e+00 - val_loss: 15.6610 - val_sex_out_loss: 0.6945 - val_age_out_loss: 14.7057 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss improved from 16.59153 to 15.66099, saving model to Age_sex_detection.h5
# Epoch 9/500
# 2/2 [==============================] - 0s 69ms/step - loss: 22.6472 - sex_out_loss: 0.9666 - age_out_loss: 21.4204 - sex_out_accuracy: 0.4477 - age_out_accuracy: 0.0000e+00 - val_loss: 20.4174 - val_sex_out_loss: 0.7638 - val_age_out_loss: 19.3969 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 15.66099
# Epoch 10/500
# 2/2 [==============================] - 0s 68ms/step - loss: 18.4464 - sex_out_loss: 0.9822 - age_out_loss: 17.2081 - sex_out_accuracy: 0.4466 - age_out_accuracy: 0.0000e+00 - val_loss: 33.1780 - val_sex_out_loss: 0.7886 - val_age_out_loss: 32.1366 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 15.66099
# Epoch 11/500
# 2/2 [==============================] - 0s 65ms/step - loss: 17.4287 - sex_out_loss: 0.8594 - age_out_loss: 16.3170 - sex_out_accuracy: 0.5753 - age_out_accuracy: 0.0000e+00 - val_loss: 35.5019 - val_sex_out_loss: 0.8346 - val_age_out_loss: 34.4178 - val_sex_out_accuracy: 0.4969 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 15.66099
# Epoch 12/500
# 2/2 [==============================] - 0s 63ms/step - loss: 18.2517 - sex_out_loss: 0.9096 - age_out_loss: 17.0930 - sex_out_accuracy: 0.5189 - age_out_accuracy: 0.0000e+00 - val_loss: 26.9605 - val_sex_out_loss: 0.6991 - val_age_out_loss: 26.0147 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 15.66099
# Epoch 13/500
# 2/2 [==============================] - 0s 68ms/step - loss: 13.8434 - sex_out_loss: 0.6708 - age_out_loss: 12.9262 - sex_out_accuracy: 0.6035 - age_out_accuracy: 0.0000e+00 - val_loss: 19.4981 - val_sex_out_loss: 0.7045 - val_age_out_loss: 18.5495 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 15.66099
# Epoch 14/500
# 2/2 [==============================] - 0s 65ms/step - loss: 17.8197 - sex_out_loss: 0.7584 - age_out_loss: 16.8175 - sex_out_accuracy: 0.5063 - age_out_accuracy: 0.0000e+00 - val_loss: 23.8738 - val_sex_out_loss: 0.7048 - val_age_out_loss: 22.9276 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 15.66099
# Epoch 15/500
# 2/2 [==============================] - 0s 74ms/step - loss: 14.3593 - sex_out_loss: 0.7246 - age_out_loss: 13.3936 - sex_out_accuracy: 0.6004 - age_out_accuracy: 0.0000e+00 - val_loss: 28.6367 - val_sex_out_loss: 0.7363 - val_age_out_loss: 27.6614 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 15.66099
# Epoch 16/500
# 2/2 [==============================] - 0s 73ms/step - loss: 15.2683 - sex_out_loss: 0.7081 - age_out_loss: 14.3216 - sex_out_accuracy: 0.5796 - age_out_accuracy: 0.0000e+00 - val_loss: 28.6344 - val_sex_out_loss: 0.7062 - val_age_out_loss: 27.6914 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 15.66099
# Epoch 17/500
# 2/2 [==============================] - 0s 68ms/step - loss: 14.2144 - sex_out_loss: 0.6560 - age_out_loss: 13.3218 - sex_out_accuracy: 0.6286 - age_out_accuracy: 0.0000e+00 - val_loss: 23.8325 - val_sex_out_loss: 0.6925 - val_age_out_loss: 22.9050 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 15.66099
# Epoch 18/500
# 2/2 [==============================] - 0s 73ms/step - loss: 13.7087 - sex_out_loss: 0.7161 - age_out_loss: 12.7578 - sex_out_accuracy: 0.5115 - age_out_accuracy: 0.0000e+00 - val_loss: 24.5897 - val_sex_out_loss: 0.6918 - val_age_out_loss: 23.6646 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 15.66099
# Epoch 19/500
# 2/2 [==============================] - 0s 78ms/step - loss: 13.3021 - sex_out_loss: 0.6661 - age_out_loss: 12.4030 - sex_out_accuracy: 0.6161 - age_out_accuracy: 0.0000e+00 - val_loss: 27.0022 - val_sex_out_loss: 0.6958 - val_age_out_loss: 26.0749 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 15.66099
# Epoch 20/500
# 2/2 [==============================] - 0s 67ms/step - loss: 12.9420 - sex_out_loss: 0.6844 - age_out_loss: 12.0264 - sex_out_accuracy: 0.5440 - age_out_accuracy: 0.0000e+00 - val_loss: 26.1282 - val_sex_out_loss: 0.7003 - val_age_out_loss: 25.1979 - val_sex_out_accuracy: 0.5094 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 15.66099
# Epoch 21/500
# 2/2 [==============================] - 0s 66ms/step - loss: 14.0153 - sex_out_loss: 0.7003 - age_out_loss: 13.0852 - sex_out_accuracy: 0.5189 - age_out_accuracy: 0.0000e+00 - val_loss: 25.6553 - val_sex_out_loss: 0.7060 - val_age_out_loss: 24.7206 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 15.66099
# Epoch 22/500
# 2/2 [==============================] - 0s 75ms/step - loss: 12.9955 - sex_out_loss: 0.6882 - age_out_loss: 12.0788 - sex_out_accuracy: 0.6004 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7656 - val_sex_out_loss: 0.7048 - val_age_out_loss: 21.8334 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 15.66099
# Epoch 23/500
# 2/2 [==============================] - 0s 67ms/step - loss: 13.0887 - sex_out_loss: 0.6825 - age_out_loss: 12.1790 - sex_out_accuracy: 0.5952 - age_out_accuracy: 0.0000e+00 - val_loss: 26.0161 - val_sex_out_loss: 0.6960 - val_age_out_loss: 25.0939 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 15.66099
# Epoch 24/500
# 2/2 [==============================] - 0s 65ms/step - loss: 13.3403 - sex_out_loss: 0.6610 - age_out_loss: 12.4533 - sex_out_accuracy: 0.6568 - age_out_accuracy: 0.0000e+00 - val_loss: 30.4918 - val_sex_out_loss: 0.6964 - val_age_out_loss: 29.5705 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 15.66099
# Epoch 25/500
# 2/2 [==============================] - 0s 68ms/step - loss: 13.3998 - sex_out_loss: 0.6590 - age_out_loss: 12.5160 - sex_out_accuracy: 0.6286 - age_out_accuracy: 0.0000e+00 - val_loss: 24.0448 - val_sex_out_loss: 0.6951 - val_age_out_loss: 23.1256 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 15.66099
# Epoch 26/500
# 2/2 [==============================] - 0s 66ms/step - loss: 13.3533 - sex_out_loss: 0.6373 - age_out_loss: 12.4919 - sex_out_accuracy: 0.6788 - age_out_accuracy: 0.0000e+00 - val_loss: 22.1423 - val_sex_out_loss: 0.6937 - val_age_out_loss: 21.2253 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 15.66099
# Epoch 27/500
# 2/2 [==============================] - 0s 65ms/step - loss: 11.7468 - sex_out_loss: 0.6603 - age_out_loss: 10.8634 - sex_out_accuracy: 0.6412 - age_out_accuracy: 0.0000e+00 - val_loss: 29.3611 - val_sex_out_loss: 0.6952 - val_age_out_loss: 28.4438 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 15.66099
# Epoch 28/500
# 2/2 [==============================] - 0s 69ms/step - loss: 12.4735 - sex_out_loss: 0.6869 - age_out_loss: 11.5645 - sex_out_accuracy: 0.5670 - age_out_accuracy: 0.0000e+00 - val_loss: 27.0498 - val_sex_out_loss: 0.6987 - val_age_out_loss: 26.1298 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 15.66099
# Epoch 29/500
# 2/2 [==============================] - 0s 68ms/step - loss: 11.7702 - sex_out_loss: 0.6697 - age_out_loss: 10.8791 - sex_out_accuracy: 0.5941 - age_out_accuracy: 0.0000e+00 - val_loss: 22.5685 - val_sex_out_loss: 0.6958 - val_age_out_loss: 21.6520 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 15.66099
# Epoch 30/500
# 2/2 [==============================] - 0s 68ms/step - loss: 10.4426 - sex_out_loss: 0.6817 - age_out_loss: 9.5403 - sex_out_accuracy: 0.5544 - age_out_accuracy: 0.0000e+00 - val_loss: 26.6462 - val_sex_out_loss: 0.6962 - val_age_out_loss: 25.7302 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 15.66099
# Epoch 31/500
# 2/2 [==============================] - 0s 67ms/step - loss: 11.9464 - sex_out_loss: 0.6678 - age_out_loss: 11.0588 - sex_out_accuracy: 0.5963 - age_out_accuracy: 0.0000e+00 - val_loss: 25.0896 - val_sex_out_loss: 0.7035 - val_age_out_loss: 24.1670 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 15.66099
# Epoch 32/500
# 2/2 [==============================] - 0s 70ms/step - loss: 11.2551 - sex_out_loss: 0.6895 - age_out_loss: 10.3466 - sex_out_accuracy: 0.5859 - age_out_accuracy: 0.0000e+00 - val_loss: 25.3874 - val_sex_out_loss: 0.7024 - val_age_out_loss: 24.4665 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 15.66099
# Epoch 33/500
# 2/2 [==============================] - 0s 68ms/step - loss: 12.4423 - sex_out_loss: 0.6629 - age_out_loss: 11.5610 - sex_out_accuracy: 0.6119 - age_out_accuracy: 0.0000e+00 - val_loss: 28.3214 - val_sex_out_loss: 0.6951 - val_age_out_loss: 27.4087 - val_sex_out_accuracy: 0.5281 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 15.66099
# Epoch 34/500
# 2/2 [==============================] - 0s 66ms/step - loss: 10.8037 - sex_out_loss: 0.6647 - age_out_loss: 9.9214 - sex_out_accuracy: 0.5586 - age_out_accuracy: 0.0000e+00 - val_loss: 21.1304 - val_sex_out_loss: 0.6920 - val_age_out_loss: 20.2212 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 15.66099
# Epoch 35/500
# 2/2 [==============================] - 0s 65ms/step - loss: 10.8590 - sex_out_loss: 0.6581 - age_out_loss: 9.9837 - sex_out_accuracy: 0.6108 - age_out_accuracy: 0.0000e+00 - val_loss: 24.2866 - val_sex_out_loss: 0.6972 - val_age_out_loss: 23.3730 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 15.66099
# Epoch 36/500
# 2/2 [==============================] - 0s 75ms/step - loss: 10.6220 - sex_out_loss: 0.6698 - age_out_loss: 9.7360 - sex_out_accuracy: 0.6204 - age_out_accuracy: 0.0000e+00 - val_loss: 25.5131 - val_sex_out_loss: 0.7013 - val_age_out_loss: 24.5961 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 15.66099
# Epoch 37/500
# 2/2 [==============================] - 0s 75ms/step - loss: 10.3393 - sex_out_loss: 0.6529 - age_out_loss: 9.4708 - sex_out_accuracy: 0.5983 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7416 - val_sex_out_loss: 0.7038 - val_age_out_loss: 21.8227 - val_sex_out_accuracy: 0.5031 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 15.66099
# Epoch 38/500
# 2/2 [==============================] - 0s 68ms/step - loss: 10.6664 - sex_out_loss: 0.6661 - age_out_loss: 9.7853 - sex_out_accuracy: 0.6108 - age_out_accuracy: 0.0000e+00 - val_loss: 27.7224 - val_sex_out_loss: 0.6918 - val_age_out_loss: 26.8160 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 15.66099
# Epoch 39/500
# 2/2 [==============================] - 0s 76ms/step - loss: 10.3364 - sex_out_loss: 0.6969 - age_out_loss: 9.4251 - sex_out_accuracy: 0.5000 - age_out_accuracy: 0.0000e+00 - val_loss: 23.3936 - val_sex_out_loss: 0.6908 - val_age_out_loss: 22.4886 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 15.66099
# Epoch 40/500
# 2/2 [==============================] - 0s 69ms/step - loss: 11.5928 - sex_out_loss: 0.6573 - age_out_loss: 10.7213 - sex_out_accuracy: 0.7102 - age_out_accuracy: 0.0000e+00 - val_loss: 23.6826 - val_sex_out_loss: 0.6899 - val_age_out_loss: 22.7791 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 15.66099
# Epoch 41/500
# 2/2 [==============================] - 0s 76ms/step - loss: 11.4672 - sex_out_loss: 0.6697 - age_out_loss: 10.5840 - sex_out_accuracy: 0.5597 - age_out_accuracy: 0.0000e+00 - val_loss: 30.1471 - val_sex_out_loss: 0.6954 - val_age_out_loss: 29.2388 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 15.66099
# Epoch 42/500
# 2/2 [==============================] - 0s 79ms/step - loss: 12.5330 - sex_out_loss: 0.6815 - age_out_loss: 11.6386 - sex_out_accuracy: 0.6150 - age_out_accuracy: 0.0000e+00 - val_loss: 17.8607 - val_sex_out_loss: 0.7021 - val_age_out_loss: 16.9458 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 15.66099
# Epoch 43/500
# 2/2 [==============================] - 0s 72ms/step - loss: 12.8516 - sex_out_loss: 0.6707 - age_out_loss: 11.9682 - sex_out_accuracy: 0.5941 - age_out_accuracy: 0.0000e+00 - val_loss: 26.3456 - val_sex_out_loss: 0.6946 - val_age_out_loss: 25.4391 - val_sex_out_accuracy: 0.5281 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 15.66099
# Epoch 44/500
# 2/2 [==============================] - 0s 72ms/step - loss: 11.9955 - sex_out_loss: 0.6716 - age_out_loss: 11.1121 - sex_out_accuracy: 0.5900 - age_out_accuracy: 0.0000e+00 - val_loss: 31.9090 - val_sex_out_loss: 0.6950 - val_age_out_loss: 31.0029 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00044: val_loss did not improve from 15.66099
# Epoch 45/500
# 2/2 [==============================] - 0s 69ms/step - loss: 14.2657 - sex_out_loss: 0.6695 - age_out_loss: 13.3851 - sex_out_accuracy: 0.6421 - age_out_accuracy: 0.0000e+00 - val_loss: 18.5254 - val_sex_out_loss: 0.6949 - val_age_out_loss: 17.6195 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 15.66099
# Epoch 46/500
# 2/2 [==============================] - 0s 67ms/step - loss: 12.5269 - sex_out_loss: 0.6668 - age_out_loss: 11.6491 - sex_out_accuracy: 0.6150 - age_out_accuracy: 0.0000e+00 - val_loss: 19.4804 - val_sex_out_loss: 0.6911 - val_age_out_loss: 18.5789 - val_sex_out_accuracy: 0.5406 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00046: val_loss did not improve from 15.66099
# Epoch 47/500
# 2/2 [==============================] - 0s 72ms/step - loss: 10.4544 - sex_out_loss: 0.6900 - age_out_loss: 9.5541 - sex_out_accuracy: 0.5764 - age_out_accuracy: 0.0000e+00 - val_loss: 28.6871 - val_sex_out_loss: 0.6919 - val_age_out_loss: 27.7857 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 15.66099
# Epoch 48/500
# 2/2 [==============================] - 0s 71ms/step - loss: 12.1322 - sex_out_loss: 0.6627 - age_out_loss: 11.2600 - sex_out_accuracy: 0.6015 - age_out_accuracy: 0.0000e+00 - val_loss: 25.5470 - val_sex_out_loss: 0.6969 - val_age_out_loss: 24.6410 - val_sex_out_accuracy: 0.5219 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 15.66099
# Epoch 49/500
# 2/2 [==============================] - 0s 70ms/step - loss: 9.8829 - sex_out_loss: 0.6446 - age_out_loss: 9.0292 - sex_out_accuracy: 0.6067 - age_out_accuracy: 0.0000e+00 - val_loss: 19.8498 - val_sex_out_loss: 0.7029 - val_age_out_loss: 18.9380 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 15.66099
# Epoch 50/500
# 2/2 [==============================] - 0s 79ms/step - loss: 11.1935 - sex_out_loss: 0.6616 - age_out_loss: 10.3231 - sex_out_accuracy: 0.5920 - age_out_accuracy: 0.0000e+00 - val_loss: 25.1846 - val_sex_out_loss: 0.6987 - val_age_out_loss: 24.2777 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 15.66099
# Epoch 51/500
# 2/2 [==============================] - 0s 68ms/step - loss: 10.1226 - sex_out_loss: 0.6632 - age_out_loss: 9.2513 - sex_out_accuracy: 0.6067 - age_out_accuracy: 0.0000e+00 - val_loss: 29.9691 - val_sex_out_loss: 0.6911 - val_age_out_loss: 29.0705 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 15.66099
# Epoch 52/500
# 2/2 [==============================] - 0s 69ms/step - loss: 11.2799 - sex_out_loss: 0.6776 - age_out_loss: 10.3947 - sex_out_accuracy: 0.6193 - age_out_accuracy: 0.0000e+00 - val_loss: 22.6890 - val_sex_out_loss: 0.6902 - val_age_out_loss: 21.7913 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 15.66099
# Epoch 53/500
# 2/2 [==============================] - 0s 72ms/step - loss: 11.7870 - sex_out_loss: 0.6855 - age_out_loss: 10.8940 - sex_out_accuracy: 0.5241 - age_out_accuracy: 0.0000e+00 - val_loss: 17.3973 - val_sex_out_loss: 0.6912 - val_age_out_loss: 16.4988 - val_sex_out_accuracy: 0.5312 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 15.66099
# Epoch 54/500
# 2/2 [==============================] - 0s 70ms/step - loss: 11.1074 - sex_out_loss: 0.6795 - age_out_loss: 10.2207 - sex_out_accuracy: 0.5638 - age_out_accuracy: 0.0000e+00 - val_loss: 26.3054 - val_sex_out_loss: 0.7006 - val_age_out_loss: 25.3982 - val_sex_out_accuracy: 0.5063 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 15.66099
# Epoch 55/500
# 2/2 [==============================] - 0s 70ms/step - loss: 11.0487 - sex_out_loss: 0.6760 - age_out_loss: 10.1663 - sex_out_accuracy: 0.5816 - age_out_accuracy: 0.0000e+00 - val_loss: 26.1604 - val_sex_out_loss: 0.6973 - val_age_out_loss: 25.2570 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 15.66099
# Epoch 56/500
# 2/2 [==============================] - 0s 69ms/step - loss: 9.2590 - sex_out_loss: 0.6765 - age_out_loss: 8.3764 - sex_out_accuracy: 0.5701 - age_out_accuracy: 0.0000e+00 - val_loss: 23.1429 - val_sex_out_loss: 0.6924 - val_age_out_loss: 22.2446 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 15.66099
# Epoch 57/500
# 2/2 [==============================] - 0s 68ms/step - loss: 10.4188 - sex_out_loss: 0.6548 - age_out_loss: 9.5581 - sex_out_accuracy: 0.6234 - age_out_accuracy: 0.0000e+00 - val_loss: 23.4333 - val_sex_out_loss: 0.6919 - val_age_out_loss: 22.5359 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 15.66099
# Epoch 58/500
# 2/2 [==============================] - 0s 66ms/step - loss: 9.9472 - sex_out_loss: 0.6699 - age_out_loss: 9.0719 - sex_out_accuracy: 0.6078 - age_out_accuracy: 0.0000e+00 - val_loss: 24.1904 - val_sex_out_loss: 0.6939 - val_age_out_loss: 23.2914 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 15.66099
# Epoch 59/500
# 2/2 [==============================] - 0s 70ms/step - loss: 9.7543 - sex_out_loss: 0.6740 - age_out_loss: 8.8752 - sex_out_accuracy: 0.6108 - age_out_accuracy: 0.0000e+00 - val_loss: 22.8799 - val_sex_out_loss: 0.7015 - val_age_out_loss: 21.9736 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 15.66099
# Epoch 60/500
# 2/2 [==============================] - 0s 73ms/step - loss: 10.0645 - sex_out_loss: 0.6643 - age_out_loss: 9.1954 - sex_out_accuracy: 0.5952 - age_out_accuracy: 0.0000e+00 - val_loss: 23.7466 - val_sex_out_loss: 0.6942 - val_age_out_loss: 22.8478 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 15.66099
# Epoch 61/500
# 2/2 [==============================] - 0s 68ms/step - loss: 9.3770 - sex_out_loss: 0.6546 - age_out_loss: 8.5179 - sex_out_accuracy: 0.6204 - age_out_accuracy: 0.0000e+00 - val_loss: 25.6549 - val_sex_out_loss: 0.6921 - val_age_out_loss: 24.7587 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 15.66099
# Epoch 62/500
# 2/2 [==============================] - 0s 67ms/step - loss: 9.8162 - sex_out_loss: 0.6600 - age_out_loss: 8.9520 - sex_out_accuracy: 0.6328 - age_out_accuracy: 0.0000e+00 - val_loss: 20.8563 - val_sex_out_loss: 0.6910 - val_age_out_loss: 19.9612 - val_sex_out_accuracy: 0.5437 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 15.66099
# Epoch 63/500
# 2/2 [==============================] - 0s 68ms/step - loss: 9.9245 - sex_out_loss: 0.6608 - age_out_loss: 9.0597 - sex_out_accuracy: 0.6161 - age_out_accuracy: 0.0000e+00 - val_loss: 23.4780 - val_sex_out_loss: 0.6901 - val_age_out_loss: 22.5841 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 15.66099
# Epoch 64/500
# 2/2 [==============================] - 0s 65ms/step - loss: 10.1097 - sex_out_loss: 0.6789 - age_out_loss: 9.2269 - sex_out_accuracy: 0.5575 - age_out_accuracy: 0.0000e+00 - val_loss: 25.5758 - val_sex_out_loss: 0.6901 - val_age_out_loss: 24.6821 - val_sex_out_accuracy: 0.5406 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 15.66099
# Epoch 65/500
# 2/2 [==============================] - 0s 78ms/step - loss: 9.7827 - sex_out_loss: 0.6688 - age_out_loss: 8.9102 - sex_out_accuracy: 0.6046 - age_out_accuracy: 0.0000e+00 - val_loss: 20.7499 - val_sex_out_loss: 0.6990 - val_age_out_loss: 19.8472 - val_sex_out_accuracy: 0.5125 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 15.66099
# Epoch 66/500
# 2/2 [==============================] - 0s 67ms/step - loss: 10.2119 - sex_out_loss: 0.6473 - age_out_loss: 9.3610 - sex_out_accuracy: 0.6443 - age_out_accuracy: 0.0000e+00 - val_loss: 23.9738 - val_sex_out_loss: 0.7041 - val_age_out_loss: 23.0665 - val_sex_out_accuracy: 0.5156 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 15.66099
# Epoch 67/500
# 2/2 [==============================] - 0s 67ms/step - loss: 9.2916 - sex_out_loss: 0.6942 - age_out_loss: 8.3943 - sex_out_accuracy: 0.5900 - age_out_accuracy: 0.0000e+00 - val_loss: 22.9056 - val_sex_out_loss: 0.6924 - val_age_out_loss: 22.0103 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 15.66099
# Epoch 68/500
# 2/2 [==============================] - 0s 66ms/step - loss: 8.8305 - sex_out_loss: 0.6701 - age_out_loss: 7.9576 - sex_out_accuracy: 0.6182 - age_out_accuracy: 0.0000e+00 - val_loss: 22.3104 - val_sex_out_loss: 0.6931 - val_age_out_loss: 21.4148 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 15.66099
# Epoch 69/500
# 2/2 [==============================] - 0s 67ms/step - loss: 9.2159 - sex_out_loss: 0.6609 - age_out_loss: 8.3525 - sex_out_accuracy: 0.6015 - age_out_accuracy: 0.0000e+00 - val_loss: 23.4229 - val_sex_out_loss: 0.6983 - val_age_out_loss: 22.5224 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 15.66099
# Epoch 70/500
# 2/2 [==============================] - 0s 75ms/step - loss: 7.9647 - sex_out_loss: 0.6567 - age_out_loss: 7.1058 - sex_out_accuracy: 0.5764 - age_out_accuracy: 0.0000e+00 - val_loss: 25.1713 - val_sex_out_loss: 0.6998 - val_age_out_loss: 24.2697 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 15.66099
# Epoch 71/500
# 2/2 [==============================] - 0s 69ms/step - loss: 9.0497 - sex_out_loss: 0.6793 - age_out_loss: 8.1687 - sex_out_accuracy: 0.5837 - age_out_accuracy: 0.0000e+00 - val_loss: 22.7892 - val_sex_out_loss: 0.6960 - val_age_out_loss: 21.8917 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 15.66099
# Epoch 72/500
# 2/2 [==============================] - 0s 69ms/step - loss: 9.3841 - sex_out_loss: 0.6689 - age_out_loss: 8.5138 - sex_out_accuracy: 0.5889 - age_out_accuracy: 0.0000e+00 - val_loss: 24.5146 - val_sex_out_loss: 0.6916 - val_age_out_loss: 23.6217 - val_sex_out_accuracy: 0.5375 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 15.66099
# Epoch 73/500
# 2/2 [==============================] - 0s 73ms/step - loss: 10.1255 - sex_out_loss: 0.6655 - age_out_loss: 9.2588 - sex_out_accuracy: 0.6256 - age_out_accuracy: 0.0000e+00 - val_loss: 20.8556 - val_sex_out_loss: 0.6994 - val_age_out_loss: 19.9550 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 15.66099
# Epoch 74/500
# 2/2 [==============================] - 0s 66ms/step - loss: 10.4034 - sex_out_loss: 0.6683 - age_out_loss: 9.5338 - sex_out_accuracy: 0.5879 - age_out_accuracy: 0.0000e+00 - val_loss: 24.0704 - val_sex_out_loss: 0.7041 - val_age_out_loss: 23.1654 - val_sex_out_accuracy: 0.5281 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 15.66099
# Epoch 75/500
# 2/2 [==============================] - 0s 69ms/step - loss: 8.5913 - sex_out_loss: 0.6558 - age_out_loss: 7.7347 - sex_out_accuracy: 0.6245 - age_out_accuracy: 0.0000e+00 - val_loss: 28.6485 - val_sex_out_loss: 0.6925 - val_age_out_loss: 27.7554 - val_sex_out_accuracy: 0.5469 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 15.66099
# Epoch 76/500
# 2/2 [==============================] - 0s 81ms/step - loss: 10.5277 - sex_out_loss: 0.6699 - age_out_loss: 9.6572 - sex_out_accuracy: 0.5879 - age_out_accuracy: 0.0000e+00 - val_loss: 17.9434 - val_sex_out_loss: 0.6935 - val_age_out_loss: 17.0491 - val_sex_out_accuracy: 0.5500 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 15.66099
# Epoch 77/500
# 2/2 [==============================] - 0s 68ms/step - loss: 11.3132 - sex_out_loss: 0.6451 - age_out_loss: 10.4673 - sex_out_accuracy: 0.6434 - age_out_accuracy: 0.0000e+00 - val_loss: 23.2215 - val_sex_out_loss: 0.7005 - val_age_out_loss: 22.3204 - val_sex_out_accuracy: 0.5250 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 15.66099
# Epoch 78/500
# 2/2 [==============================] - 0s 68ms/step - loss: 8.7836 - sex_out_loss: 0.6506 - age_out_loss: 7.9325 - sex_out_accuracy: 0.6046 - age_out_accuracy: 0.0000e+00 - val_loss: 25.6580 - val_sex_out_loss: 0.6983 - val_age_out_loss: 24.7593 - val_sex_out_accuracy: 0.5344 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 15.66099
# Epoch 79/500
# 2/2 [==============================] - 0s 76ms/step - loss: 9.0369 - sex_out_loss: 0.6460 - age_out_loss: 8.1905 - sex_out_accuracy: 0.6234 - age_out_accuracy: 0.0000e+00 - val_loss: 22.0421 - val_sex_out_loss: 0.6923 - val_age_out_loss: 21.1493 - val_sex_out_accuracy: 0.4938 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 15.66099
# Epoch 80/500
# 2/2 [==============================] - 0s 75ms/step - loss: 8.4840 - sex_out_loss: 0.6632 - age_out_loss: 7.6203 - sex_out_accuracy: 0.6056 - age_out_accuracy: 0.0000e+00 - val_loss: 24.7484 - val_sex_out_loss: 0.6923 - val_age_out_loss: 23.8558 - val_sex_out_accuracy: 0.5000 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 15.66099
# Epoch 81/500
# 2/2 [==============================] - 0s 67ms/step - loss: 8.3052 - sex_out_loss: 0.6594 - age_out_loss: 7.4455 - sex_out_accuracy: 0.6004 - age_out_accuracy: 0.0000e+00 - val_loss: 19.1702 - val_sex_out_loss: 0.6944 - val_age_out_loss: 18.2752 - val_sex_out_accuracy: 0.5437 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 15.66099
# Epoch 82/500
# 2/2 [==============================] - 0s 72ms/step - loss: 9.4723 - sex_out_loss: 0.6363 - age_out_loss: 8.6354 - sex_out_accuracy: 0.6423 - age_out_accuracy: 0.0000e+00 - val_loss: 24.9590 - val_sex_out_loss: 0.7061 - val_age_out_loss: 24.0526 - val_sex_out_accuracy: 0.5188 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 15.66099
# Epoch 83/500
# 2/2 [==============================] - 0s 66ms/step - loss: 9.9580 - sex_out_loss: 0.6614 - age_out_loss: 9.0963 - sex_out_accuracy: 0.6139 - age_out_accuracy: 0.0000e+00 - val_loss: 26.8388 - val_sex_out_loss: 0.6949 - val_age_out_loss: 25.9438 - val_sex_out_accuracy: 0.5375 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 15.66099
# 10/10 [==============================] - 0s 4ms/step - loss: 15.6610 - sex_out_loss: 0.6945 - age_out_loss: 14.7057 - sex_out_accuracy: 0.5000 - age_out_accuracy: 0.0000e+00
# Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.94      0.65       161
#            1       0.47      0.06      0.10       159
#
#     accuracy                           0.50       320
#    macro avg       0.49      0.50      0.38       320
# weighted avg       0.49      0.50      0.38       320
#
# Results:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE2E484C410>
# Index: 168
# Actual age: 77
# Predicted Age: 70
# Actual sex: 0
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE27E270890>
# Index: 337
# Actual age: 74
# Predicted Age: 51
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE2167D56D0>
# Index: 238
# Actual age: 68
# Predicted Age: 55
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE2F64A4090>
# Index: 322
# Actual age: 73
# Predicted Age: 51
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE2E47918D0>
# Index: 366
# Actual age: 77
# Predicted Age: 51
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE2D03AC350>
# Index: 17
# Actual age: 65
# Predicted Age: 54
# Actual sex: 0
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE298035C50>
# Index: 402
# Actual age: 80
# Predicted Age: 64
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FE298028550>
# Index: 162
# Actual age: 77
# Predicted Age: 50
# Actual sex: 0
# Predicted Sex: Male
