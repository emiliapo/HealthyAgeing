# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/010620eastern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/MyDrive/HealthyAgeing')

# %%
import cv2
import os
import math
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random
import decimal

import DataAugmentation

last = []
labels = []
images = []
ageList = []
sexList = []

class HealthyAgeing:
  def western_image_processing(self, folder, images, labels):
    files = os.listdir(folder)
    random.shuffle(files)
    n = len(files)
    print("Number of files importing: " + str(n))
    for filename in files:
      img = cv2.imread(folder+'/'+filename)
      if img is not None:
        label = self.establishWesternLabels(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (48, 48))
        images.append(img)

        labels.append(label)
        n -= 1
        print(str(n) + " files left to import..")

    dataclass = DataAugmentation.DataAugmentation()
    augmentedDataDict = dataclass.augment(images, labels)
    images = augmentedDataDict['images'].copy()
    labels = augmentedDataDict['labels'].copy()

    nofFiles = len(images.copy())
    images_f = np.array(images)
    sexList_f = np.array(sexList)
    ageList_f = np.array(ageList)
    labels_f = np.array(labels)

    np.save('image.npy', images_f)
    np.save('gender.npy', sexList_f)
    np.save('age.npy', ageList_f)

    # normalise the images array by dividing it with 255
    images_f_2 = images_f / 255
    X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.25)
    #Y_train[0:5]

    Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
    Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

    Model = self.model((48, 48, 3))
    print(Model.summary())

    self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)
    self.testRandomImages(15, nofFiles, images_f, images_f_2, labels_f, Model)

  def eastern_image_processing(self, folder, images, labels):
    files = os.listdir(folder)
    random.shuffle(files)
    n = len(files)
    print("Number of files importing: " + str(n))
    for filename in files:
      img = cv2.imread(folder+'/'+filename)
      if img is not None:
        label = self.establishEasternLabels(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (48, 48))
        images.append(img)

        labels.append(label)
        n -= 1
        print(str(n) + " files left to import..")

    dataclass = DataAugmentation.DataAugmentation()
    augmentedDataDict = dataclass.augment(images, labels)
    images = augmentedDataDict['images'].copy()
    labels = augmentedDataDict['labels'].copy()
    
    nofFiles = len(images.copy())
    #self.showProcessedImage(564)

    # convert the labels and images to NumPy arrays

    images_f = np.array(images)
    sexList_f = np.array(sexList)
    ageList_f = np.array(ageList)
    labels_f = np.array(labels)

    np.save('image.npy', images_f)
    np.save('gender.npy', sexList_f)
    np.save('age.npy', ageList_f)

    #self.showSexDistribution(sexList_f)
    #self.showAgeDistribution(ageList_f)

    # normalise the images array by dividing it with 255
    images_f_2 = images_f / 255
    X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.25)
    #Y_train[0:5]

    Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
    Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

    # Y_train_2[0][0:5]

    # Y_train_2[1][0:5]

    Model = self.model((48, 48, 3))
    print(Model.summary())

    test = self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)
    testLabels = test[1]
    testPred = test[0]

    self.checkRanges(testLabels,testPred)

    self.testRandomImages(15, nofFiles, images_f, images_f_2, labels_f, Model)


  def establishEasternLabels(self, filename):
      name = filename.split(".")[0]
      splitName = name.split("A")
      s = int(splitName[-1])
      a = int(splitName[-2])
      #output = {'sex': s, 'age': a}
      output = [a, s]

      return output

  def establishWesternLabels(self, filename):
      name = filename.split(".")[0]
      splitName = name.split("_")
      a = int(splitName[0])
      s = int(splitName[1])
      #output = {'sex': s, 'age': a}
      output = [a, s]

      return output
    
  def showProcessedImage(self, index):

      cv2_imshow(images[index])
      print(labels[index])

      print("Press any key to exit...")
      cv2.waitKey(0) #waits for any key press

  def showSexDistribution(self, sexList_f):
      values, counts = np.unique(sexList_f, return_counts=True)
      #print(counts) #returns 207, 219

      plt.xlabel("Sex")
      plt.ylabel("Distribution")
      sex = ['Female', 'Male']
      plt.bar(sex, counts)
      plt.show()


  def showAgeDistribution(self, ageList_f):
      values, counts = np.unique(ageList_f, return_counts=True)
      #print(counts)

      plt.plot(values, counts)
      plt.xlabel('ages')
      plt.ylabel('distribution')
      plt.show()

  def testRandomImages(self, num, nOfOGFiles, images_f, images_f_2, labels_f, Model):
    for i in range(num):
      max = int(nOfOGFiles - 1)
      index = random.randint(0, max)
      self.test_image(index, images_f, images_f_2, labels_f, Model)

  def Convolution(self, input_tensor, filters):
      x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
          input_tensor)
      x = Dropout(0.1)(x)
      x = Activation('relu')(x)
      return x


  def model(self, input_shape):
      inputs = Input((input_shape))

      conv_1 = self.Convolution(inputs, 32)
      maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
      conv_2 = self.Convolution(maxp_1, 64)
      maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
      conv_3 = self.Convolution(maxp_2, 128)
      maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
      conv_4 = self.Convolution(maxp_3, 256)
      maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
      flatten = Flatten()(maxp_4)
      dense_1 = Dense(64, activation='sigmoid')(flatten)
      dense_2 = Dense(64, activation='relu')(flatten)
      drop_1 = Dropout(0.2)(dense_1)
      drop_2 = Dropout(0.2)(dense_2)
      output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
      output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

      model = Model(inputs=[inputs], outputs=[output_1, output_2])
      model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                    metrics=["accuracy"])
      return model

  def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                            Y_test, Y_train_2, Y_test_2):
      fle_s='Age_sex_detection.h5'
      checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,
                                      save_best_only=True,
                                      save_weights_only=False,
                                      mode='auto',
                                      save_freq='epoch')
      Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
      callback_list=[checkpointer,Early_stop]

      History = Model.fit(X_train, Y_train_2,
                validation_data=(X_test, Y_test_2),
                epochs=500,
                batch_size = 64,
                callbacks=[callback_list])
      
      print("History: ")
      print(History.history)
      
      Model.evaluate(X_test, Y_test_2)
      pred=Model.predict(X_test)

      #print(pred[1])

      plt.plot(History.history['loss'])
      plt.plot(History.history['val_loss'])
      plt.title('Model loss')
      plt.ylabel('Loss')
      plt.xlabel('Epoch')
      plt.legend(['Train', 'Validation'], loc='upper left')
      plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                              wspace=0.35)
      plt.show()
      
      #For sex

      plt.plot(History.history['sex_out_accuracy'])
      plt.plot(History.history['val_sex_out_accuracy'])
      plt.title('Model accuracy sex')
      plt.ylabel('Accuracy')
      plt.xlabel('Epoch')
      plt.legend(['Train', 'Validation'], loc='upper left')
      plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                              wspace=0.35)
      plt.show()
      
      #for age

      fig, ax = plt.subplots()
      ax.scatter(Y_test_2[1], pred[1])
      ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
      ax.set_xlabel('Actual Age')
      ax.set_ylabel('Predicted Age')

      plt.show()

      # Calculation of Mean Squared Error (MSE) for sex
      msesex = mean_squared_error(Y_test_2[0], pred[0])
      maesex = mean_absolute_error(Y_test_2[0], pred[0])
      print("mean_squared_error sex: " + str(msesex))
      print("ROOT mean_squared_error sex: " + str(math.sqrt(msesex)))
      print("mean_absolute_error sex: " + str(maesex) + "\n")

      # Calculation of Mean Squared Error (MSE) for age
      mseage = mean_squared_error(Y_test_2[1], pred[1])
      maeage = mean_absolute_error(Y_test_2[1], pred[1])
      print("mean_squared_error age: " + str(mseage))
      print("ROOT mean_squared_error age: " + str(math.sqrt(mseage)))
      print("mean_absolute_error age: " + str(maeage))

      #for sex
      j = 0
      Pred_l=[]
      while(j<len(pred[0])):
        Pred_l.append(int(np.round(pred[0][j])))
        j+=1

      print("Report:")
      report=classification_report(Y_test_2[0], Pred_l)
      print(report)

      print("Results:")
      results = confusion_matrix(Y_test_2[0], Pred_l)
      sns.heatmap(results, annot=True)

      return [pred, Y_test_2]

  def checkRanges(self, testLabels, pred):
    realAgeGroup = []
    predictedAgeGroup = []
    realAges = testLabels[1]
    predictedAges = pred[1]
    
    #for the confusion matrix, there is three groups an age can be in.
    #Group 0, group 1 and group 2
    #0: less than 70; 1: 71-75; 2: 76 and up
    # the real values are within 65-80
    for realAge in realAges:
      if realAge <= 70:
        realAgeGroup.append(0)
      elif realAge <= 75:
        realAgeGroup.append(1)
      else:
        realAgeGroup.append(2)

    for predictedAge in predictedAges:
      if predictedAge <= 70:
        predictedAgeGroup.append(0)
      elif predictedAge <= 75:
        predictedAgeGroup.append(1)
      else:
        predictedAgeGroup.append(2)
    
    #confusion matrix for age group accuracy
    print("Age Group Accuracy Confusion Matrix:")
    print("0: less than 70; 1: 71-75; 2: 76 and up")
    res = confusion_matrix(realAgeGroup.copy(), predictedAgeGroup.copy())
    sns.heatmap(res, annot=True)

    print("Report:")
    rep = classification_report(realAgeGroup.copy(), predictedAgeGroup.copy())
    print(rep)

    #Calculation of Mean Squared Error (MSE) for age
    mseage = mean_squared_error(realAgeGroup, predictedAgeGroup)
    maeage = mean_absolute_error(realAgeGroup, predictedAgeGroup)
    print("mean_squared_error age group: " + str(mseage))
    print("ROOT mean_squared_error age group : " + str(math.sqrt(mseage)))
    print("mean_absolute_error age group: " + str(maeage))
  
  def test_image(self, ind, images_f, images_f_2, labels_f, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1= Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      actualsex = ""
      if labels_f[ind][1] == 0:
        actualsex = "Female"
      if labels_f[ind][1] == 1:
        actualsex = "Male"

      print("Index: "+ str(ind))
      print("Actual age: " + str(labels_f[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + actualsex)
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
HealthyAgeing().eastern_image_processing(folder, images, labels)
# Out:
# Number of files importing: 426
# 425 files left to import..
# 424 files left to import..
# 423 files left to import..
# 422 files left to import..
# 421 files left to import..
# 420 files left to import..
# 419 files left to import..
# 418 files left to import..
# 417 files left to import..
# 416 files left to import..
# 415 files left to import..
# 414 files left to import..
# 413 files left to import..
# 412 files left to import..
# 411 files left to import..
# 410 files left to import..
# 409 files left to import..
# 408 files left to import..
# 407 files left to import..
# 406 files left to import..
# 405 files left to import..
# 404 files left to import..
# 403 files left to import..
# 402 files left to import..
# 401 files left to import..
# 400 files left to import..
# 399 files left to import..
# 398 files left to import..
# 397 files left to import..
# 396 files left to import..
# 395 files left to import..
# 394 files left to import..
# 393 files left to import..
# 392 files left to import..
# 391 files left to import..
# 390 files left to import..
# 389 files left to import..
# 388 files left to import..
# 387 files left to import..
# 386 files left to import..
# 385 files left to import..
# 384 files left to import..
# 383 files left to import..
# 382 files left to import..
# 381 files left to import..
# 380 files left to import..
# 379 files left to import..
# 378 files left to import..
# 377 files left to import..
# 376 files left to import..
# 375 files left to import..
# 374 files left to import..
# 373 files left to import..
# 372 files left to import..
# 371 files left to import..
# 370 files left to import..
# 369 files left to import..
# 368 files left to import..
# 367 files left to import..
# 366 files left to import..
# 365 files left to import..
# 364 files left to import..
# 363 files left to import..
# 362 files left to import..
# 361 files left to import..
# 360 files left to import..
# 359 files left to import..
# 358 files left to import..
# 357 files left to import..
# 356 files left to import..
# 355 files left to import..
# 354 files left to import..
# 353 files left to import..
# 352 files left to import..
# 351 files left to import..
# 350 files left to import..
# 349 files left to import..
# 348 files left to import..
# 347 files left to import..
# 346 files left to import..
# 345 files left to import..
# 344 files left to import..
# 343 files left to import..
# 342 files left to import..
# 341 files left to import..
# 340 files left to import..
# 339 files left to import..
# 338 files left to import..
# 337 files left to import..
# 336 files left to import..
# 335 files left to import..
# 334 files left to import..
# 333 files left to import..
# 332 files left to import..
# 331 files left to import..
# 330 files left to import..
# 329 files left to import..
# 328 files left to import..
# 327 files left to import..
# 326 files left to import..
# 325 files left to import..
# 324 files left to import..
# 323 files left to import..
# 322 files left to import..
# 321 files left to import..
# 320 files left to import..
# 319 files left to import..
# 318 files left to import..
# 317 files left to import..
# 316 files left to import..
# 315 files left to import..
# 314 files left to import..
# 313 files left to import..
# 312 files left to import..
# 311 files left to import..
# 310 files left to import..
# 309 files left to import..
# 308 files left to import..
# 307 files left to import..
# 306 files left to import..
# 305 files left to import..
# 304 files left to import..
# 303 files left to import..
# 302 files left to import..
# 301 files left to import..
# 300 files left to import..
# 299 files left to import..
# 298 files left to import..
# 297 files left to import..
# 296 files left to import..
max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 12, 12, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 128)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 6, 6, 128)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 6, 6, 256)    295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 6, 6, 256)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 6, 6, 256)    0           dropout_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 3, 3, 256)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2304)         0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           147520      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           147520      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# sex_out (Dense)                 (None, 1)            65          dropout_16[0][0]
# __________________________________________________________________________________________________
# age_out (Dense)                 (None, 1)            65          dropout_17[0][0]
# ==================================================================================================
# Total params: 683,586
# Trainable params: 683,586
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/500
# 80/80 [==============================] - 2s 17ms/step - loss: 20.2389 - sex_out_loss: 0.7258 - age_out_loss: 19.2660 - sex_out_accuracy: 0.4953 - age_out_accuracy: 0.0000e+00 - val_loss: 18.7946 - val_sex_out_loss: 0.6932 - val_age_out_loss: 17.8752 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 18.79457, saving model to Age_sex_detection.h5
# Epoch 2/500
# 80/80 [==============================] - 1s 13ms/step - loss: 8.8131 - sex_out_loss: 0.7126 - age_out_loss: 7.8818 - sex_out_accuracy: 0.5033 - age_out_accuracy: 0.0000e+00 - val_loss: 25.7368 - val_sex_out_loss: 0.6937 - val_age_out_loss: 24.8322 - val_sex_out_accuracy: 0.4894 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 18.79457
# Epoch 3/500
# 80/80 [==============================] - 1s 13ms/step - loss: 8.9342 - sex_out_loss: 0.7133 - age_out_loss: 8.0154 - sex_out_accuracy: 0.4988 - age_out_accuracy: 0.0000e+00 - val_loss: 24.6326 - val_sex_out_loss: 0.6930 - val_age_out_loss: 23.7394 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 18.79457
# Epoch 4/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.9291 - sex_out_loss: 0.7063 - age_out_loss: 7.0265 - sex_out_accuracy: 0.5067 - age_out_accuracy: 0.0000e+00 - val_loss: 17.7384 - val_sex_out_loss: 0.6930 - val_age_out_loss: 16.8531 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 18.79457 to 17.73841, saving model to Age_sex_detection.h5
# Epoch 5/500
# 80/80 [==============================] - 1s 13ms/step - loss: 8.1714 - sex_out_loss: 0.7040 - age_out_loss: 7.2784 - sex_out_accuracy: 0.5084 - age_out_accuracy: 0.0000e+00 - val_loss: 22.8674 - val_sex_out_loss: 0.6929 - val_age_out_loss: 21.9889 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 17.73841
# Epoch 6/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.7763 - sex_out_loss: 0.7018 - age_out_loss: 6.8918 - sex_out_accuracy: 0.5147 - age_out_accuracy: 0.0000e+00 - val_loss: 21.6881 - val_sex_out_loss: 0.6935 - val_age_out_loss: 20.8148 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 17.73841
# Epoch 7/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.9196 - sex_out_loss: 0.7039 - age_out_loss: 7.0387 - sex_out_accuracy: 0.4996 - age_out_accuracy: 0.0000e+00 - val_loss: 17.2795 - val_sex_out_loss: 0.6929 - val_age_out_loss: 16.4122 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss improved from 17.73841 to 17.27955, saving model to Age_sex_detection.h5
# Epoch 8/500
# 80/80 [==============================] - 1s 13ms/step - loss: 8.1321 - sex_out_loss: 0.7054 - age_out_loss: 7.2547 - sex_out_accuracy: 0.5020 - age_out_accuracy: 0.0000e+00 - val_loss: 19.1266 - val_sex_out_loss: 0.6939 - val_age_out_loss: 18.2628 - val_sex_out_accuracy: 0.4894 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from
- val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 15.44750
# Epoch 31/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.1910 - sex_out_loss: 0.6922 - age_out_loss: 6.3691 - sex_out_accuracy: 0.5241 - age_out_accuracy: 0.0000e+00 - val_loss: 15.1503 - val_sex_out_loss: 0.6921 - val_age_out_loss: 14.3284 - val_sex_out_accuracy: 0.5141 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00031: val_loss improved from 15.44750 to 15.15030, saving model to Age_sex_detection.h5
# Epoch 32/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.3228 - sex_out_loss: 0.6942 - age_out_loss: 6.4986 - sex_out_accuracy: 0.5037 - age_out_accuracy: 0.0000e+00 - val_loss: 14.8231 - val_sex_out_loss: 0.6919 - val_age_out_loss: 14.0013 - val_sex_out_accuracy: 0.5223 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00032: val_loss improved from 15.15030 to 14.82315, saving model to Age_sex_detection.h5
# Epoch 33/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.3785 - sex_out_loss: 0.6929 - age_out_loss: 6.5561 - sex_out_accuracy: 0.5158 - age_out_accuracy: 0.0000e+00 - val_loss: 15.3471 - val_sex_out_loss: 0.6925 - val_age_out_loss: 14.5260 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 14.82315
# Epoch 34/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.2317 - sex_out_loss: 0.6910 - age_out_loss: 6.4124 - sex_out_accuracy: 0.5309 - age_out_accuracy: 0.0000e+00 - val_loss: 15.1472 - val_sex_out_loss: 0.6920 - val_age_out_loss: 14.3276 - val_sex_out_accuracy: 0.5123 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 14.82315
# Epoch 35/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.3249 - sex_out_loss: 0.6922 - age_out_loss: 6.5048 - sex_out_accuracy: 0.5135 - age_out_accuracy: 0.0000e+00 - val_loss: 12.3068 - val_sex_out_loss: 0.6916 - val_age_out_loss: 11.4863 - val_sex_out_accuracy: 0.5276 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00035: val_loss improved from 14.82315 to 12.30678, saving model to Age_sex_detection.h5
# Epoch 36/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.2858 - sex_out_loss: 0.6927 - age_out_loss: 6.4646 - sex_out_accuracy: 0.5180 - age_out_accuracy: 0.0000e+00 - val_loss: 12.5282 - val_sex_out_loss: 0.6919 - val_age_out_loss: 11.7082 - val_sex_out_accuracy: 0.5276 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 12.30678
# Epoch 37/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.2625 - sex_out_loss: 0.6930 - age_out_loss: 6.4418 - sex_out_accuracy: 0.5149 - age_out_accuracy: 0.0000e+00 - val_loss: 15.0886 - val_sex_out_loss: 0.6926 - val_age_out_loss: 14.2686 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 12.30678
# Epoch 38/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.1664 - sex_out_loss: 0.6936 - age_out_loss: 6.3456 - sex_out_accuracy: 0.5100 - age_out_accuracy: 0.0000e+00 - val_loss: 13.6665 - val_sex_out_loss: 0.6928 - val_age_out_loss: 12.8456 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 12.30678
# Epoch 39/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.4383 - sex_out_loss: 0.6931 - age_out_loss: 6.6160 - sex_out_accuracy: 0.5088 - age_out_accuracy: 0.0000e+00 - val_loss: 15.8235 - val_sex_out_loss: 0.6929 - val_age_out_loss: 15.0002 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 12.30678
# Epoch 40/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.3006 - sex_out_loss: 0.6930 - age_out_loss: 6.4774 - sex_out_accuracy: 0.5178 - age_out_accuracy: 0.0000e+00 - val_loss: 16.2433 - val_sex_out_loss: 0.6920 - val_age_out_loss: 15.4223 - val_sex_out_accuracy: 0.5176 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 12.30678
# Epoch 41/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7
- val_age_out_accuracy: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 10.73311
# Epoch 62/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.0664 - sex_out_loss: 0.6887 - age_out_loss: 6.2377 - sex_out_accuracy: 0.5493 - age_out_accuracy: 0.0000e+00 - val_loss: 12.0928 - val_sex_out_loss: 0.6885 - val_age_out_loss: 11.2634 - val_sex_out_accuracy: 0.5106 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 10.73311
# Epoch 63/500
# 80/80 [==============================] - 1s 14ms/step - loss: 7.1524 - sex_out_loss: 0.6878 - age_out_loss: 6.3236 - sex_out_accuracy: 0.5440 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2525 - val_sex_out_loss: 0.6949 - val_age_out_loss: 11.4163 - val_sex_out_accuracy: 0.4842 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 10.73311
# Epoch 64/500
# 80/80 [==============================] - 1s 13ms/step - loss: 7.0073 - sex_out_loss: 0.6885 - age_out_loss: 6.1771 - sex_out_accuracy: 0.5444 - age_out_accuracy: 0.0000e+00 - val_loss: 9.7117 - val_sex_out_loss: 0.6893 - val_age_out_loss: 8.8806 - val_sex_out_accuracy: 0.5534 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00064: val_loss improved from 10.73311 to 9.71173, saving model to Age_sex_detection.h5
# Epoch 65/500
# 80/80 [==============================] - 1s 14ms/step - loss: 7.0713 - sex_out_loss: 0.6890 - age_out_loss: 6.2403 - sex_out_accuracy: 0.5409 - age_out_accuracy: 0.0000e+00 - val_loss: 11.9419 - val_sex_out_loss: 0.6889 - val_age_out_loss: 11.1092 - val_sex_out_accuracy: 0.5546 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 9.71173
# Epoch 66/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.8646 - sex_out_loss: 0.6856 - age_out_loss: 6.0347 - sex_out_accuracy: 0.5548 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1900 - val_sex_out_loss: 0.6908 - val_age_out_loss: 11.3545 - val_sex_out_accuracy: 0.5176 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 9.71173
# Epoch 67/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.9451 - sex_out_loss: 0.6851 - age_out_loss: 6.1141 - sex_out_accuracy: 0.5634 - age_out_accuracy: 0.0000e+00 - val_loss: 10.0521 - val_sex_out_loss: 0.6864 - val_age_out_loss: 9.2178 - val_sex_out_accuracy: 0.5610 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 9.71173
# Epoch 68/500
# 80/80 [==============================] - 1s 14ms/step - loss: 7.0260 - sex_out_loss: 0.6856 - age_out_loss: 6.1926 - sex_out_accuracy: 0.5556 - age_out_accuracy: 0.0000e+00 - val_loss: 13.7528 - val_sex_out_loss: 0.6873 - val_age_out_loss: 12.9175 - val_sex_out_accuracy: 0.5587 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 9.71173
# Epoch 69/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.9502 - sex_out_loss: 0.6859 - age_out_loss: 6.1160 - sex_out_accuracy: 0.5524 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1664 - val_sex_out_loss: 0.6887 - val_age_out_loss: 11.3281 - val_sex_out_accuracy: 0.5364 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 9.71173
# Epoch 70/500
# 80/80 [==============================] - 1s 14ms/step - loss: 6.8957 - sex_out_loss: 0.6877 - age_out_loss: 6.0585 - sex_out_accuracy: 0.5475 - age_out_accuracy: 0.0000e+00 - val_loss: 12.7692 - val_sex_out_loss: 0.6879 - val_age_out_loss: 11.9325 - val_sex_out_accuracy: 0.5352 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 9.71173
# Epoch 71/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.9648 - sex_out_loss: 0.6864 - age_out_loss: 6.1288 - sex_out_accuracy: 0.5487 - age_out_accuracy: 0.0000e+00 - val_loss: 10.3800 - val_sex_out_loss: 0.6907 - val_age_out_loss: 9.5385 - val_sex_out_accuracy: 0.5200 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 9.71173
# Epoch 72/500
# 80/80 [==============================] - 1s 14ms/step - loss: 6.8399 - sex_out_loss: 0.6902 - age_out_loss: 5.9992 - sex_out_accuracy: 0.5258 - age_out_accuracy: 0.0000e+00 - val_loss: 12.8373 - val_sex_out_loss: 0.6856 - val_age_out_loss: 12.0010 - val_sex_out_accuracy: 0.5687 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 9.71173
# Epoch 73/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.9416 - sex_out_loss: 0.6889 - age_out_loss: 6.1013 - sex_out_accuracy: 0.5383 - age_out_accuracy: 0.0000e+00 - val_loss: 13.5064 - val_sex_out_loss: 0.6858 - val_age_out_loss: 12.6687 - val_sex_out_accuracy: 0.5511 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 9.71173
# Epoch 74/500
# 80/80 [==============================] - 1s 14ms/step - loss: 6.9405 - sex_out_loss: 0.6815 - age_out_loss: 6.1058 - sex_out_accuracy: 0.5675 - age_out_accuracy: 0.0000e+00 - val_loss: 14.3709 - val_sex_out_loss: 0.6833 - val_age_out_loss: 13.5339 - val_sex_out_accuracy: 0.5710 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 9.71173
# Epoch 75/500
# 80/80 [==============================] - 1s 14ms/step - loss: 6.8114 - sex_out_loss: 0.6848 - age_out_loss: 5.9710 - sex_out_accuracy: 0.5485 - age_out_accuracy: 0.0000e+00 - val_loss: 13.6623 - val_sex_out_loss: 0.6847 - val_age_out_loss: 12.8203 - val_sex_out_accuracy: 0.5687 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 9.71173
# Epoch 76/500
# 80/80 [==============================] - 1s 14ms/step - loss: 6.6836 - sex_out_loss: 0.6848 - age_out_loss: 5.8406 - sex_out_accuracy: 0.5552 - age_out_accuracy: 0.0000e+00 - val_loss: 11.3981 - val_sex_out_loss: 0.6805 - val_age_out_loss: 10.5583 - val_sex_out_accuracy: 0.5804 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 9.71173
# Epoch 77/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.8205 - sex_out_loss: 0.6863 - age_out_loss: 5.9747 - sex_out_accuracy: 0.5516 - age_out_accuracy: 0.0000e+00 - val_loss: 14.6994 - val_sex_out_loss: 0.6838 - val_age_out_loss: 13.8567 - val_sex_out_accuracy: 0.5757 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 9.71173
# Epoch 78/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.7878 - sex_out_loss: 0.6821 - age_out_loss: 5.9458 - sex_out_accuracy: 0.5659 - age_out_accuracy: 0.0000e+00 - val_loss: 13.9169 - val_sex_out_loss: 0.6811 - val_age_out_loss: 13.0755 - val_sex_out_accuracy: 0.5763 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 9.71173
# Epoch 79/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.7417 - sex_out_loss: 0.6780 - age_out_loss: 5.9020 - sex_out_accuracy: 0.5790 - age_out_accuracy: 0.0000e+00 - val_loss: 10.1196 - val_sex_out_loss: 0.6776 - val_age_out_loss: 9.2797 - val_sex_out_accuracy: 0.5863 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 9.71173
# Epoch 80/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.7338 - sex_out_loss: 0.6738 - age_out_loss: 5.8980 - sex_out_accuracy: 0.5784 - age_out_accuracy: 0.0000e+00 - val_loss: 12.8850 - val_sex_out_loss: 0.6787 - val_age_out_loss: 12.0443 - val_sex_out_accuracy: 0.5769 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 9.71173
# Epoch 81/500
# 80/80 [==============================] - 1s 13ms/step - loss: 6.8352 - sex_out_loss: 0.6741 - age_out_loss: 5.9991 - sex_out_accuracy: 0.5726 - age_out_accuracy: 0.0000e+00 - val_loss: 14.6382 - val_sex_out_loss: 0.6781 - val_age_out_loss: 13.7976 - val_sex_out_accuracy: 0.5880 - val_age_out_accuracy: 0.0000e+00
#
# ...
#
# Epoch 00356: val_loss did not improve from 4.51885
# Epoch 357/500
# 80/80 [==============================] - 1s 14ms/step - loss: 5.2141 - sex_out_loss: 0.0257 - age_out_loss: 4.8758 - sex_out_accuracy: 0.9918 - age_out_accuracy: 0.0000e+00 - val_loss: 8.0747 - val_sex_out_loss: 0.0823 - val_age_out_loss: 7.6798 - val_sex_out_accuracy: 0.9712 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00357: val_loss did not improve from 4.51885
# Epoch 358/500
# 80/80 [==============================] - 1s 15ms/step - loss: 5.2852 - sex_out_loss: 0.0273 - age_out_loss: 4.9454 - sex_out_accuracy: 0.9904 - age_out_accuracy: 0.0000e+00 - val_loss: 8.6203 - val_sex_out_loss: 0.0740 - val_age_out_loss: 8.2337 - val_sex_out_accuracy: 0.9759 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00358: val_loss did not improve from 4.51885
# Epoch 359/500
# 80/80 [==============================] - 1s 15ms/step - loss: 5.2399 - sex_out_loss: 0.0343 - age_out_loss: 4.8931 - sex_out_accuracy: 0.9877 - age_out_accuracy: 0.0000e+00 - val_loss: 7.1353 - val_sex_out_loss: 0.0893 - val_age_out_loss: 6.7337 - val_sex_out_accuracy: 0.9677 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00359: val_loss did not improve from 4.51885
# Epoch 360/500
# 80/80 [==============================] - 1s 14ms/step - loss: 5.2986 - sex_out_loss: 0.0348 - age_out_loss: 4.9512 - sex_out_accuracy: 0.9888 - age_out_accuracy: 0.0000e+00 - val_loss: 6.7814 - val_sex_out_loss: 0.1025 - val_age_out_loss: 6.3660 - val_sex_out_accuracy: 0.9607 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00360: val_loss did not improve from 4.51885
# Epoch 361/500
# 80/80 [==============================] - 1s 15ms/step - loss: 5.2431 - sex_out_loss: 0.0250 - age_out_loss: 4.9045 - sex_out_accuracy: 0.9906 - age_out_accuracy: 0.0000e+00 - val_loss: 6.7313 - val_sex_out_loss: 0.1325 - val_age_out_loss: 6.2852 - val_sex_out_accuracy: 0.9624 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00361: val_loss did not improve from 4.51885
# Epoch 362/500
# 80/80 [==============================] - 1s 16ms/step - loss: 5.2665 - sex_out_loss: 0.0312 - age_out_loss: 4.9215 - sex_out_accuracy: 0.9881 - age_out_accuracy: 0.0000e+00 - val_loss: 6.5224 - val_sex_out_loss: 0.0810 - val_age_out_loss: 6.1279 - val_sex_out_accuracy: 0.9742 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 
 5.788379669189453, 5.721864223480225, 5.695137977600098, 5.680886268615723, 5.817780494689941, 5.832368850708008, 5.743850231170654, 5.761225700378418, 5.7366108894348145, 5.743396282196045, 5.674842357635498, 5.686645984649658, 5.876049995422363, 5.604056358337402, 5.729186058044434, 5.659562587738037, 5.65295934677124, 5.725903034210205, 5.817370414733887, 5.740954399108887, 5.5725884437561035, 5.715106010437012, 5.59951114654541, 5.8305864334106445, 5.760577201843262, 5.579728126525879, 5.608099460601807, 5.531619071960449, 5.645652770996094, 5.605978012084961, 5.651729106903076, 5.739755630493164, 5.701535224914551, 5.600125312805176, 5.62660026550293, 5.785847187042236, 5.691598415374756, 5.661142826080322, 5.57338523864746 ...
# 54/54 [==============================] - 0s 5ms/step - loss: 4.5188 - sex_out_loss: 0.0984 - age_out_loss: 4.1097 - sex_out_accuracy: 0.9660 - age_out_accuracy: 0.0000e+00
# mean_squared_error sex: 0.027607201591669087
# ROOT mean_squared_error sex: 0.16615415008861226
# mean_absolute_error sex: 0.05071418118119277
#
# mean_squared_error age: 23.4354576770345
# ROOT mean_squared_error age: 4.841018247955124
# mean_absolute_error age: 4.1096513461618915
# Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       834
#            1       0.96      0.97      0.97       870
#
#     accuracy                           0.97      1704
#    macro avg       0.97      0.97      0.97      1704
# weighted avg       0.97      0.97      0.97      1704
#
# Results:
# Age Group Accuracy Confusion Matrix:
# 0: less than 70; 1: 71-75; 2: 76 and up
# Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.76       762
#            1       0.19      0.24      0.21       412
#            2       0.95      0.03      0.07       530
#
#     accuracy                           0.50      1704
#    macro avg       0.59      0.42      0.35      1704
# weighted avg       0.62      0.50      0.41      1704
#
# mean_squared_error age group: 0.7177230046948356
# ROOT mean_squared_error age group : 0.8471853425873441
# mean_absolute_error age group: 0.5698356807511737
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F859C7C79D0>
# Index: 4080
# Actual age: 72
# Predicted Age: 70
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85AE1178D0>
# Index: 3294
# Actual age: 70
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F859C2ABC10>
# Index: 5176
# Actual age: 68
# Predicted Age: 64
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85AE107250>
# Index: 937
# Actual age: 78
# Predicted Age: 71
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85AE107250>
# Index: 3696
# Actual age: 69
# Predicted Age: 68
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F8586533C10>
# Index: 1454
# Actual age: 70
# Predicted Age: 67
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85865C9790>
# Index: 5714
# Actual age: 70
# Predicted Age: 69
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85865DB410>
# Index: 1173
# Actual age: 68
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F859C309D50>
# Index: 4572
# Actual age: 70
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F8586544350>
# Index: 2695
# Actual age: 69
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85865C9A50>
# Index: 4586
# Actual age: 77
# Predicted Age: 70
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85865C9750>
# Index: 3051
# Actual age: 71
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F85AE106A50>
# Index: 6551
# Actual age: 69
# Predicted Age: 64
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F859C309990>
# Index: 4285
# Actual age: 74
# Predicted Age: 69
# Actual sex: Female
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F8586552490>
# Index: 3935
# Actual age: 66
# Predicted Age: 65
# Actual sex: Female
# Predicted Sex: Male
