# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/ChangedTestSizeto095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random

last = []
labels = []
images = []
ageList = []
sexList = []

class Image:

    def image_processing(self, folder):
      files = os.listdir(folder)
      nOfFiles = len(files)
      for filename in files:
        img = cv2.imread(folder+'/'+filename)
        if img is not None:
          label = self.establishLabels(filename)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          img = cv2.resize(img, (48, 48))
          images.append(img)
          ageList.append(label[0])
          sexList.append(label[1])

          labels.append(label)

      #self.showProcessedImage(23)

      # convert the labels and images to NumPy arrays

      images_f = np.array(images)
      sexList_f = np.array(sexList)
      ageList_f = np.array(ageList)
      labels_f = np.array(labels)

      np.save(folder + 'image.npy', images_f)
      np.save(folder + 'gender.npy', sexList_f)
      np.save(folder + 'age.npy', ageList_f)

      #self.showSexDistribution(sexList_f)
      #self.showAgeDistribution(ageList_f)

      # normalise the images array by dividing it with 255

      images_f_2 = images_f / 255
      X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.95)
      #print(Y_train[0:5])

      Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
      Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

      #print(Y_train_2[0][0:5])

      #print(Y_train_2[1][0:5])

      Model = self.model((48, 48, 3))
      # print(Model.summary())

      self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)

      self.testRandomImages(8, nOfFiles, images_f, images_f_2, Model)


    def establishLabels(self, filename):
        name = filename.split(".")[0]
        splitName = name.split("A")
        s = int(splitName[-1])
        a = int(splitName[-2])
        #output = {'sex': s, 'age': a}
        output = [a, s]

        return output

    def showProcessedImage(self, index):

        cv2_imshow(images[index])
        print(ageList[index])
        print(sexList[index])

        print("Press any key to exit...")
        cv2.waitKey(0) #waits for any key press

    def showSexDistribution(self, sexList_f):
        values, counts = np.unique(sexList_f, return_counts=True)
        #print(counts) #returns 207, 219

        plt.xlabel("Sex")
        plt.ylabel("Distribution")
        sex = ['Female', 'Male']
        plt.bar(sex, counts)
        plt.show()


    def showAgeDistribution(self, ageList_f):
        values, counts = np.unique(ageList_f, return_counts=True)
        #print(counts)

        plt.plot(values, counts)
        plt.xlabel('ages')
        plt.ylabel('distribution')
        plt.show()

    def testRandomImages(self, num, nOfFiles, images_f, images_f_2, Model):
      for i in range(num):
        max = int(nOfFiles - 1)
        index = random.randint(0, max)
        self.test_image(index, images_f, images_f_2, Model)

    def Convolution(self, input_tensor, filters):
        x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
            input_tensor)
        x = Dropout(0.1)(x)
        x = Activation('relu')(x)
        return x


    def model(self, input_shape):
        inputs = Input((input_shape))

        conv_1 = self.Convolution(inputs, 32)
        maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
        conv_2 = self.Convolution(maxp_1, 64)
        maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
        conv_3 = self.Convolution(maxp_2, 128)
        maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
        conv_4 = self.Convolution(maxp_3, 256)
        maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
        flatten = Flatten()(maxp_4)
        dense_1 = Dense(64, activation='relu')(flatten)
        dense_2 = Dense(64, activation='relu')(flatten)
        drop_1 = Dropout(0.2)(dense_1)
        drop_2 = Dropout(0.2)(dense_2)
        output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
        output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

        model = Model(inputs=[inputs], outputs=[output_1, output_2])
        model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                      metrics=["accuracy"])
        return model

    def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                              Y_test, Y_train_2, Y_test_2):
        fle_s='Age_sex_detection.h5'
        checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       save_freq='epoch')
        Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
        callback_list=[checkpointer,Early_stop]

        History = Model.fit(X_train, Y_train_2,
                 batch_size=64,
                 validation_data=(X_test, Y_test_2),
                 epochs=500,
                 callbacks=[callback_list])
        
        Model.evaluate(X_test, Y_test_2)
        pred=Model.predict(X_test)

        #print(pred[1])

        plt.plot(History.history['loss'])
        plt.plot(History.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #For sex

        plt.plot(History.history['sex_out_accuracy'])
        plt.plot(History.history['val_sex_out_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #for age

        fig, ax = plt.subplots()
        ax.scatter(Y_test_2[1], pred[1])
        ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
        ax.set_xlabel('Actual Age')
        ax.set_ylabel('Predicted Age')

        plt.show()

        #for sex
        j = 0
        Pred_l=[]
        while(j<len(pred[0])):
          Pred_l.append(int(np.round(pred[0][j])))
          j+=1

        print("Report:")
        report=classification_report(Y_test_2[0], Pred_l)
        print(report)

        print("Results:")
        results = confusion_matrix(Y_test_2[0], Pred_l)
        sns.heatmap(results, annot=True)

    def test_image(self, ind, images_f, images_f_2, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1=Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      print("Index: "+ str(ind))
      print("Actual age: " + str(labels[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + str(labels[ind][1]))
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
Image().image_processing(folder)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 72.9018 - sex_out_loss: 0.6922 - age_out_loss: 71.9048 - sex_out_accuracy: 0.5238 - age_out_accuracy: 0.0000e+00 - val_loss: 73.1131 - val_sex_out_loss: 0.7626 - val_age_out_loss: 72.0518 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 73.11313, saving model to Age_sex_detection.h5
# Epoch 2/500
# 1/1 [==============================] - 0s 93ms/step - loss: 72.7133 - sex_out_loss: 0.5123 - age_out_loss: 71.9023 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 73.0996 - val_sex_out_loss: 1.0968 - val_age_out_loss: 71.7105 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 73.11313 to 73.09957, saving model to Age_sex_detection.h5
# Epoch 3/500
# 1/1 [==============================] - 0s 98ms/step - loss: 72.3620 - sex_out_loss: 0.6388 - age_out_loss: 71.4310 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 72.2693 - val_sex_out_loss: 1.2497 - val_age_out_loss: 70.7329 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 73.09957 to 72.26929, saving model to Age_sex_detection.h5
# Epoch 4/500
# 1/1 [==============================] - 0s 86ms/step - loss: 70.9904 - sex_out_loss: 0.7722 - age_out_loss: 69.9315 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 70.3611 - val_sex_out_loss: 1.2856 - val_age_out_loss: 68.7937 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 72.26929 to 70.36105, saving model to Age_sex_detection.h5
# Epoch 5/500
# 1/1 [==============================] - 0s 89ms/step - loss: 68.2343 - sex_out_loss: 0.6914 - age_out_loss: 67.2612 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 66.4632 - val_sex_out_loss: 1.1869 - val_age_out_loss: 64.9991 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss improved from 70.36105 to 66.46322, saving model to Age_sex_detection.h5
# Epoch 6/500
# 1/1 [==============================] - 0s 96ms/step - loss: 61.7946 - sex_out_loss: 0.6279 - age_out_loss: 60.8895 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 59.2930 - val_sex_out_loss: 0.9241 - val_age_out_loss: 58.0956 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss improved from 66.46322 to 59.29300, saving model to Age_sex_detection.h5
# Epoch 7/500
# 1/1 [==============================] - 0s 89ms/step - loss: 51.1877 - sex_out_loss: 0.7054 - age_out_loss: 50.2090 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 46.6591 - val_sex_out_loss: 0.7107 - val_age_out_loss: 45.6786 - val_sex_out_accuracy: 0.5284 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss improved from 59.29300 to 46.65908, saving model to Age_sex_detection.h5
# Epoch 8/500
# 1/1 [==============================] - 0s 90ms/step - loss: 35.7505 - sex_out_loss: 1.1941 - age_out_loss: 34.2866 - sex_out_accuracy: 0.2857 - age_out_accuracy: 0.0000e+00 - val_loss: 24.9240 - val_sex_out_loss: 0.7596 - val_age_out_loss: 23.8975 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss improved from 46.65908 to 24.92397, saving model to Age_sex_detection.h5
# Epoch 9/500
# 1/1 [==============================] - 0s 89ms/step - loss: 17.4546 - sex_out_loss: 1.4598 - age_out_loss: 15.7279 - sex_out_accuracy: 0.4762 - age_out_accuracy: 0.0000e+00 - val_loss: 13.2151 - val_sex_out_loss: 2.3161 - val_age_out_loss: 10.6349 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss improved from 24.92397 to 13.21506, saving model to Age_sex_detection.h5
# Epoch 10/500
# 1/1 [==============================] - 0s 91ms/step - loss: 32.4528 - sex_out_loss: 1.6027 - age_out_loss: 30.5862 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 13.1117 - val_sex_out_loss: 2.1854 - val_age_out_loss: 10.6659 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss improved from 13.21506 to 13.11170, saving model to Age_sex_detection.h5
# Epoch 11/500
# 1/1 [==============================] - 0s 92ms/step - loss: 33.0127 - sex_out_loss: 1.3970 - age_out_loss: 31.3554 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 23.1051 - val_sex_out_loss: 1.2245 - val_age_out_loss: 21.6241 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 13.11170
# Epoch 12/500
# 1/1 [==============================] - 0s 97ms/step - loss: 14.4095 - sex_out_loss: 0.9013 - age_out_loss: 13.2516 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 36.9879 - val_sex_out_loss: 0.7178 - val_age_out_loss: 36.0172 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 13.11170
# Epoch 13/500
# 1/1 [==============================] - 0s 100ms/step - loss: 21.3821 - sex_out_loss: 0.8764 - age_out_loss: 20.2528 - sex_out_accuracy: 0.6190 - age_out_accuracy: 0.0000e+00 - val_loss: 44.0159 - val_sex_out_loss: 0.6904 - val_age_out_loss: 43.0760 - val_sex_out_accuracy: 0.5235 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from
- sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 22.8323 - val_sex_out_loss: 0.8657 - val_age_out_loss: 21.7821 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 12.17961
# Epoch 76/500
# 1/1 [==============================] - 0s 95ms/step - loss: 13.8906 - sex_out_loss: 0.5124 - age_out_loss: 13.1937 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 21.8469 - val_sex_out_loss: 0.8661 - val_age_out_loss: 20.7966 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 12.17961
# Epoch 77/500
# 1/1 [==============================] - 0s 89ms/step - loss: 12.3026 - sex_out_loss: 0.5054 - age_out_loss: 11.6130 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 22.4109 - val_sex_out_loss: 0.8588 - val_age_out_loss: 21.3682 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 12.17961
# Epoch 78/500
# 1/1 [==============================] - 0s 93ms/step - loss: 12.3816 - sex_out_loss: 0.5269 - age_out_loss: 11.6709 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 25.8174 - val_sex_out_loss: 0.8264 - val_age_out_loss: 24.8075 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 12.17961
# Epoch 79/500
# 1/1 [==============================] - 0s 92ms/step - loss: 10.0140 - sex_out_loss: 0.5069 - age_out_loss: 9.3236 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 26.4301 - val_sex_out_loss: 0.8009 - val_age_out_loss: 25.4460 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 12.17961
# Epoch 80/500
# 1/1 [==============================] - 0s 94ms/step - loss: 10.1077 - sex_out_loss: 0.5284 - age_out_loss: 9.3961 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 25.9222 - val_sex_out_loss: 0.7812 - val_age_out_loss: 24.9581 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 12.17961
# Epoch 81/500
# 1/1 [==============================] - 0s 95ms/step - loss: 11.2200 - sex_out_loss: 0.5357 - age_out_loss: 10.5014 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 21.3971 - val_sex_out_loss: 0.7790 - val_age_out_loss: 20.4353 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 12.17961
# Epoch 82/500
# 1/1 [==============================] - 0s 87ms/step - loss: 11.6995 - sex_out_loss: 0.5392 - age_out_loss: 10.9776 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 20.4529 - val_sex_out_loss: 0.7882 - val_age_out_loss: 19.4821 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 12.17961
# Epoch 83/500
# 1/1 [==============================] - 0s 93ms/step - loss: 12.3104 - sex_out_loss: 0.5158 - age_out_loss: 11.6120 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 25.1825 - val_sex_out_loss: 0.7925 - val_age_out_loss: 24.2079 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 12.17961
# Epoch 84/500
# 1/1 [==============================] - 0s 96ms/step - loss: 9.0670 - sex_out_loss: 0.5128 - age_out_loss: 8.3721 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 29.5433 - val_sex_out_loss: 0.8139 - val_age_out_loss: 28.5478 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 12.17961
# Epoch 85/500
# 1/1 [==============================] - 0s 99ms/step - loss: 12.9233 - sex_out_loss: 0.5204 - age_out_loss: 12.2212 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 31.2511 - val_sex_out_loss: 0.8275 - val_age_out_loss: 30.2422 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 12.17961
# Epoch 86/500
# 1/1 [==============================] - 0s 100ms/step - loss: 14.7663 - sex_out_loss: 0.5097 - age_out_loss: 14.0752 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 27.2132 - val_sex_out_loss: 0.8541 - val_age_out_loss: 26.1779 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 12.17961
# Epoch 87/500
# 1/1 [==============================] - 0s 98ms/step - loss: 12.0461 - sex_out_loss: 0.5429 - age_out_loss: 11.3220 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 20.2073 - val_sex_out_loss: 0.8798 - val_age_out_loss: 19.1463 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 12.17961
# Epoch 88/500
# 1/1 [==============================] - 0s 91ms/step - loss: 12.1687 - sex_out_loss: 0.5554 - age_out_loss: 11.4321 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 13.3837 - val_sex_out_loss: 0.8880 - val_age_out_loss: 12.3145 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 12.17961
# Epoch 89/500
# 1/1 [==============================] - 0s 91ms/step - loss: 16.3533 - sex_out_loss: 0.5328 - age_out_loss: 15.6392 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 13.3609 - val_sex_out_loss: 0.8547 - val_age_out_loss: 12.3252 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 12.17961
# Epoch 90/500
# 1/1 [==============================] - 0s 95ms/step - loss: 16.3273 - sex_out_loss: 0.5544 - age_out_loss: 15.5919 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 19.0538 - val_sex_out_loss: 0.8052 - val_age_out_loss: 18.0680 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 12.17961
# Epoch 91/500
# 1/1 [==============================] - 0s 90ms/step - loss: 12.7367 - sex_out_loss: 0.5431 - age_out_loss: 12.0131 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 27.2665 - val_sex_out_loss: 0.7645 - val_age_out_loss: 26.3220 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 12.17961
# Epoch 92/500
# 1/1 [==============================] - 0s 105ms/step - loss: 11.2460 - sex_out_loss: 0.4932 - age_out_loss: 10.5728 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 31.8452 - val_sex_out_loss: 0.7515 - val_age_out_loss: 30.9141 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 12.17961
# Epoch 93/500
# 1/1 [==============================] - 0s 97ms/step - loss: 14.7072 - sex_out_loss: 0.5397 - age_out_loss: 13.9879 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 31.9127 - val_sex_out_loss: 0.7527 - val_age_out_loss: 30.9806 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 12.17961
# Epoch 94/500
# 1/1 [==============================] - 0s 92ms/step - loss: 15.8003 - sex_out_loss: 0.5366 - age_out_loss: 15.0843 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 27.5832 - val_sex_out_loss: 0.7668 - val_age_out_loss: 26.6370 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 12.17961
# Epoch 95/500
# 1/1 [==============================] - 0s 94ms/step - loss: 12.5492 - sex_out_loss: 0.5208 - age_out_loss: 11.8491 - sex_out_accuracy: 0.7619 - age_out_accuracy: 0.0000e+00 - val_loss: 21.8736 - val_sex_out_loss: 0.7964 - val_age_out_loss: 20.8978 - val_sex_out_accuracy: 0.4716 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 12.17961
# 13/13 [==============================] - 0s 4ms/step - loss: 12.1796 - sex_out_loss: 1.1776 - age_out_loss: 10.7691 - sex_out_accuracy: 0.4716 - age_out_accuracy: 0.0000e+00
# Report:
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64       191
#            1       0.00      0.00      0.00       214
#
#     accuracy                           0.47       405
#    macro avg       0.24      0.50      0.32       405
# weighted avg       0.22      0.47      0.30       405
#
# Results:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF1214D690>
# Index: 17
# Actual age: 65
# Predicted Age: 60
# Actual sex: 0
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF0B213ED0>
# Index: 214
# Actual age: 65
# Predicted Age: 49
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF023949D0>
# Index: 371
# Actual age: 77
# Predicted Age: 89
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF023B4D90>
# Index: 196
# Actual age: 79
# Predicted Age: 68
# Actual sex: 0
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF0235AD50>
# Index: 289
# Actual age: 72
# Predicted Age: 71
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF023CB0D0>
# Index: 134
# Actual age: 74
# Predicted Age: 52
# Actual sex: 0
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF02350350>
# Index: 384
# Actual age: 77
# Predicted Age: 57
# Actual sex: 1
# Predicted Sex: Male
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FCF02394290>
# Index: 170
# Actual age: 76
# Predicted Age: 61
# Actual sex: 0
# Predicted Sex: Male
