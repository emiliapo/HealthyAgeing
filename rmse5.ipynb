# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliapo/HealthyAgeing/blob/Working/rmse5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import math
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
import seaborn as sns
from google.colab.patches import cv2_imshow
from google.colab import drive
import random
import decimal

last = []
labels = []
images = []
ageList = []
sexList = []

class Image:

    def image_processing(self, folder):
      files = os.listdir(folder)
      random.shuffle(files)
      for filename in files:
        img = cv2.imread(folder+'/'+filename)
        if img is not None:
          label = self.establishLabels(filename)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
          img = cv2.resize(img, (48, 48))
          images.append(img)
          ageList.append(label[0])
          sexList.append(label[1])

          labels.append(label)
      nofOGFiles = len(images.copy())
      self.dataAugmentation()
      #self.showProcessedImage(564)

      # convert the labels and images to NumPy arrays

      images_f = np.array(images)
      sexList_f = np.array(sexList)
      ageList_f = np.array(ageList)
      labels_f = np.array(labels)

      np.save('image.npy', images_f)
      np.save('gender.npy', sexList_f)
      np.save('age.npy', ageList_f)

      #self.showSexDistribution(sexList_f)
      #self.showAgeDistribution(ageList_f)

      # normalise the images array by dividing it with 255
      print("Number of images" +str(len(images_f)))
      images_f_2 = images_f / 255
      X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.25)
      #Y_train[0:5]

      Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
      Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

      # Y_train_2[0][0:5]

      # Y_train_2[1][0:5]

      Model = self.model((48, 48, 3))
      # print(Model.summary())

      self.trainAndEvaluateModel(Model, X_train, X_test, Y_train, Y_test, Y_train_2, Y_test_2)

      self.testRandomImages(8, nofOGFiles, images_f, images_f_2, Model)


    def establishLabels(self, filename):
        name = filename.split(".")[0]
        splitName = name.split("A")
        s = int(splitName[-1])
        a = int(splitName[-2])
        #output = {'sex': s, 'age': a}
        output = [a, s]

        return output

    def dataAugmentation(self):
      ogimages = images.copy()
      oglabels = labels.copy()
      i = 0
      #flip originals
      for ogimage in ogimages:
        placeholder = cv2.flip(ogimage, 1)
        images.append(placeholder)
        newlabel = oglabels[i]
        labels.append(newlabel)
        i+=1
      # #scale
      imageCopy2 = images.copy()
      lableCopy2 = labels.copy()
      flippedScaledImages = []
      j = 0
      for ogimage in imageCopy2:
        if j == 0: s = 1.75
        else:
          s = float(decimal.Decimal(random.randrange(110, 165))/100) #random between 1.1 and 3.0
        scaled = cv2.resize(ogimage, None, fx= s, fy= s, interpolation= cv2.INTER_LINEAR)
        #crop back to 48 48
        cntr = int(scaled.shape[0] /2)

        crop_img = scaled[cntr - 24:cntr + 24, cntr - 24:cntr + 24].copy()
        newimg = cv2.resize(crop_img, (48,48))

        images.append(newimg)
        newlabel = lableCopy2[j].copy()
        labels.append(newlabel)

        #flip zoomed
        placeholder = cv2.flip(newimg, 1)
        flippedScaledImages.append(placeholder)
        
        j+=1

      #for the sake of consistency  
      k = 0
      for f in flippedScaledImages:
        images.append(f)
        newlabel = lableCopy2[k].copy()
        labels.append(newlabel)
        k+=1
      
      #brightness
      ogimages3 = images.copy()
      oglabels3 = labels.copy()
      b = 0
      for ogimage in ogimages3:
        value = random.uniform(0.4, 1.5)
        hsv = cv2.cvtColor(ogimage, cv2.COLOR_BGR2HSV)
        hsv = np.array(hsv, dtype = np.float64)
        hsv[:,:,1] = hsv[:,:,1]*value
        hsv[:,:,1][hsv[:,:,1]>255]  = 255
        hsv[:,:,2] = hsv[:,:,2]*value 
        hsv[:,:,2][hsv[:,:,2]>255]  = 255
        hsv = np.array(hsv, dtype = np.uint8)
        brighter = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
                       
        images.append(brighter)
        newlabel = oglabels3[b].copy()
        labels.append(newlabel)
        b+=1
    
      #channel shift
      ogimages4 = images.copy()
      oglabels4 = labels.copy()
      c = 0
      for ogimage in ogimages4:
        value = int(random.uniform(-60, 60)) #no particular reason for 60
        shifted = ogimage + value
        shifted[:,:,:][shifted[:,:,:]>255]  = 255
        shifted[:,:,:][shifted[:,:,:]<0]  = 0
        shifted = shifted.astype(np.uint8)
                       
        images.append(shifted)
        newlabel = oglabels4[c].copy()
        labels.append(newlabel)
        c+=1


      
    def showProcessedImage(self, index):

        cv2_imshow(images[index])
        print(labels[index])

        print("Press any key to exit...")
        cv2.waitKey(0) #waits for any key press

    def showSexDistribution(self, sexList_f):
        values, counts = np.unique(sexList_f, return_counts=True)
        #print(counts) #returns 207, 219

        plt.xlabel("Sex")
        plt.ylabel("Distribution")
        sex = ['Female', 'Male']
        plt.bar(sex, counts)
        plt.show()


    def showAgeDistribution(self, ageList_f):
        values, counts = np.unique(ageList_f, return_counts=True)
        #print(counts)

        plt.plot(values, counts)
        plt.xlabel('ages')
        plt.ylabel('distribution')
        plt.show()

    def testRandomImages(self, num, nOfOGFiles, images_f, images_f_2, Model):
      for i in range(num):
        max = int(nOfOGFiles - 1)
        index = random.randint(0, max)
        self.test_image(index, images_f, images_f_2, Model)
        self.test_image(index + 426, images_f, images_f_2, Model)
        self.test_image(index + 852, images_f, images_f_2, Model)
        self.test_image(index + 1278, images_f, images_f_2, Model)
      self.test_image(0, images_f, images_f_2, Model)
      self.test_image(426, images_f, images_f_2, Model)
      self.test_image(852, images_f, images_f_2, Model)
      self.test_image(1278, images_f, images_f_2, Model)
      self.test_image(2556, images_f, images_f_2, Model)
      self.test_image(5112, images_f, images_f_2, Model)

    def Convolution(self, input_tensor, filters):
        x = Conv2D(filters=filters, kernel_size=(3, 3), padding='same', strides=(1, 1), kernel_regularizer=l2(0.001))(
            input_tensor)
        x = Dropout(0.1)(x)
        x = Activation('relu')(x)
        return x


    def model(self, input_shape):
        inputs = Input((input_shape))

        conv_1 = self.Convolution(inputs, 32)
        maxp_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
        conv_2 = self.Convolution(maxp_1, 64)
        maxp_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
        conv_3 = self.Convolution(maxp_2, 128)
        maxp_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
        conv_4 = self.Convolution(maxp_3, 256)
        maxp_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)
        flatten = Flatten()(maxp_4)
        dense_1 = Dense(64, activation='relu')(flatten)
        dense_2 = Dense(64, activation='relu')(flatten)
        drop_1 = Dropout(0.2)(dense_1)
        drop_2 = Dropout(0.2)(dense_2)
        output_1 = Dense(1, activation="sigmoid", name='sex_out')(drop_1)
        output_2 = Dense(1, activation="relu", name='age_out')(drop_2)

        model = Model(inputs=[inputs], outputs=[output_1, output_2])
        model.compile(loss=["binary_crossentropy", "mae"], optimizer="Adam",
                      metrics=["accuracy"])
        return model

    def trainAndEvaluateModel(self, Model, X_train, X_test, Y_train,
                              Y_test, Y_train_2, Y_test_2):
        fle_s='Age_sex_detection.h5'
        checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       save_freq='epoch')
        Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
        callback_list=[checkpointer,Early_stop]

        History = Model.fit(X_train, Y_train_2,
                 validation_data=(X_test, Y_test_2),
                 epochs=500,
                 batch_size = 64,
                 callbacks=[callback_list])
        
        print("History: ")
        print(History.history)
        
        Model.evaluate(X_test, Y_test_2)
        pred=Model.predict(X_test)

        #print(pred[1])

        plt.plot(History.history['loss'])
        plt.plot(History.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #For sex

        plt.plot(History.history['sex_out_accuracy'])
        plt.plot(History.history['val_sex_out_accuracy'])
        plt.title('Model accuracy sex')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                                wspace=0.35)
        plt.show()
        
        #for age

        fig, ax = plt.subplots()
        ax.scatter(Y_test_2[1], pred[1])
        ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
        ax.set_xlabel('Actual Age')
        ax.set_ylabel('Predicted Age')

        plt.show()

        # Calculation of Mean Squared Error (MSE) for sex
        msesex = mean_squared_error(Y_test_2[0], pred[0])
        maesex = mean_absolute_error(Y_test_2[0], pred[0])
        print("mean_squared_error sex: " + str(msesex))
        print("ROOT mean_squared_error sex: " + str(math.sqrt(msesex)))
        print("mean_absolute_error sex: " + str(maesex) + "\n")

        # Calculation of Mean Squared Error (MSE) for age
        mseage = mean_squared_error(Y_test_2[1], pred[1])
        maeage = mean_absolute_error(Y_test_2[1], pred[1])
        print("mean_squared_error age: " + str(mseage))
        print("ROOT mean_squared_error age: " + str(math.sqrt(mseage)))
        print("mean_absolute_error age: " + str(maeage))

        #for sex
        j = 0
        Pred_l=[]
        while(j<len(pred[0])):
          Pred_l.append(int(np.round(pred[0][j])))
          j+=1

        print("Report:")
        report=classification_report(Y_test_2[0], Pred_l)
        print(report)

        print("Results:")
        results = confusion_matrix(Y_test_2[0], Pred_l)
        sns.heatmap(results, annot=True)

    def test_image(self, ind, images_f, images_f_2, Model):
      cv2_imshow(images_f[ind])
      image_test=images_f_2[ind]
      pred_1=Model.predict(np.array([image_test]))
      sex_f=['Male','Female']
      age=int(np.round(pred_1[1][0]))
      sex=int(np.round(pred_1[0][0]))
      actualsex = ""

      if labels[ind][1] == 0:
        actualsex = "Female"
      if labels[ind][1] == 1:
        actualsex = "Male"
      print("Index: "+ str(ind))
      print("Actual age: " + str(labels[ind][0]))
      print("Predicted Age: "+ str(age))
      print("Actual sex: " + actualsex)
      print("Predicted Sex: "+ sex_f[sex])
        
folder = "/content/drive/MyDrive/HealthyAgeing/Data/Eastern_Elder_Faces"
Image().image_processing(folder)
# Out:
# Number of images10224
# Epoch 1/500
# 120/120 [==============================] - 36s 21ms/step - loss: 27.6877 - sex_out_loss: 0.7357 - age_out_loss: 26.7113 - sex_out_accuracy: 0.5009 - age_out_accuracy: 0.0000e+00 - val_loss: 22.3303 - val_sex_out_loss: 0.6931 - val_age_out_loss: 21.4448 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 22.33025, saving model to Age_sex_detection.h5
# Epoch 2/500
# 120/120 [==============================] - 2s 13ms/step - loss: 8.7331 - sex_out_loss: 0.6930 - age_out_loss: 7.8529 - sex_out_accuracy: 0.5157 - age_out_accuracy: 0.0000e+00 - val_loss: 21.9844 - val_sex_out_loss: 0.6930 - val_age_out_loss: 21.1161 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 22.33025 to 21.98438, saving model to Age_sex_detection.h5
# Epoch 3/500
# 120/120 [==============================] - 2s 13ms/step - loss: 7.9800 - sex_out_loss: 0.6927 - age_out_loss: 7.1146 - sex_out_accuracy: 0.5200 - age_out_accuracy: 0.0000e+00 - val_loss: 20.8283 - val_sex_out_loss: 0.6929 - val_age_out_loss: 19.9693 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 21.98438 to 20.82826, saving model to Age_sex_detection.h5
# Epoch 4/500
# 120/120 [==============================] - 2s 13ms/step - loss: 7.7564 - sex_out_loss: 0.6929 - age_out_loss: 6.8993 - sex_out_accuracy: 0.5108 - age_out_accuracy: 0.0000e+00 - val_loss: 20.7682 - val_sex_out_loss: 0.6929 - val_age_out_loss: 19.9165 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 20.82826 to 20.76824, saving model to Age_sex_detection.h5
# Epoch 5/500
# 120/120 [==============================] - 2s 13ms/step - loss: 8.4155 - sex_out_loss: 0.6928 - age_out_loss: 7.5655 - sex_out_accuracy: 0.5129 - age_out_accuracy: 0.0000e+00 - val_loss: 23.6299 - val_sex_out_loss: 0.6930 - val_age_out_loss: 22.7845 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 20.76824
# Epoch 6/500
# 120/120 [==============================] - 2s 14ms/step - loss: 7.5374 - sex_out_loss: 0.6925 - age_out_loss: 6.6937 - sex_out_accuracy: 0.5194 - age_out_accuracy: 0.0000e+00 - val_loss: 19.7322 - val_sex_out_loss: 0.6930 - val_age_out_loss: 18.8913 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss improved from 20.76824 to 19.73225, saving model to Age_sex_detection.h5
# Epoch 7/500
# 120/120 [==============================] - 2s 14ms/step - loss: 8.0008 - sex_out_loss: 0.6927 - age_out_loss: 7.1610 - sex_out_accuracy: 0.5158 - age_out_accuracy: 0.0000e+00 - val_loss: 17.6706 - val_sex_out_loss: 0.6930 - val_age_out_loss: 16.8340 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss improved from 19.73225 to 17.67060, saving model to Age_sex_detection.h5
# Epoch 8/500
# 120/120 [==============================] - 2s 13ms/step - loss: 7.9526 - sex_out_loss: 0.6925 - age_out_loss: 7.1175 - sex_out_accuracy: 0.5187 - age_out_accuracy: 0.0000e+00 - val_loss: 16.3949 - val_sex_out_loss: 0.6930 - val_age_out_loss: 15.5616 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss improved from 17.67060 to 16.39485, saving model to Age_sex_detection.h5
# Epoch 9/500
# 120/120 [==============================] - 2s 13ms/step - loss: 7.5800 - sex_out_loss: 0.6930 - age_out_loss: 6.7477 - sex_out_accuracy: 0.5104 - age_out_accuracy: 0.0000e+00 - val_loss: 13.2217 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.3914 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss improved from 16.39485 to 13.22169, saving model to Age_sex_detection.h5
# Epoch 10/500
# 120/120 [==============================] - 2s 13ms/step - loss: 8.0701 - sex_out_loss: 0.6932 - age_out_loss: 7.2412 - sex_out_accuracy: 0.5062 - age_out_accuracy: 0.0000e+00 - val_loss: 17.1040 - val_sex_out_loss: 0.6930 - val_age_out_loss: 16.2770 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from
- val_sex_out_loss: 0.6930 - val_age_out_loss: 14.4459 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 10.57677
# Epoch 48/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.9492 - sex_out_loss: 0.6928 - age_out_loss: 6.1482 - sex_out_accuracy: 0.5144 - age_out_accuracy: 0.0000e+00 - val_loss: 18.4660 - val_sex_out_loss: 0.6930 - val_age_out_loss: 17.6652 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 10.57677
# Epoch 49/500
# 120/120 [==============================] - 2s 13ms/step - loss: 7.1154 - sex_out_loss: 0.6928 - age_out_loss: 6.3143 - sex_out_accuracy: 0.5127 - age_out_accuracy: 0.0000e+00 - val_loss: 15.9844 - val_sex_out_loss: 0.6930 - val_age_out_loss: 15.1834 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 10.57677
# Epoch 50/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8263 - sex_out_loss: 0.6923 - age_out_loss: 6.0257 - sex_out_accuracy: 0.5219 - age_out_accuracy: 0.0000e+00 - val_loss: 15.2406 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.4381 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 10.57677
# Epoch 51/500
# 120/120 [==============================] - 2s 13ms/step - loss: 6.9527 - sex_out_loss: 0.6928 - age_out_loss: 6.1503 - sex_out_accuracy: 0.5137 - age_out_accuracy: 0.0000e+00 - val_loss: 14.5835 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.7806 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 10.57677
# Epoch 52/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8325 - sex_out_loss: 0.6928 - age_out_loss: 6.0300 - sex_out_accuracy: 0.5136 - age_out_accuracy: 0.0000e+00 - val_loss: 14.9996 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.1976 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 10.57677
# Epoch 53/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.9238 - sex_out_loss: 0.6926 - age_out_loss: 6.1221 - sex_out_accuracy: 0.5162 - age_out_accuracy: 0.0000e+00 - val_loss: 15.7518 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.9491 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 10.57677
# Epoch 54/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8141 - sex_out_loss: 0.6927 - age_out_loss: 6.0118 - sex_out_accuracy: 0.5157 - age_out_accuracy: 0.0000e+00 - val_loss: 14.8674 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.0644 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 10.57677
# Epoch 55/500
# 120/120 [==============================] - 2s 13ms/step - loss: 6.8170 - sex_out_loss: 0.6926 - age_out_loss: 6.0137 - sex_out_accuracy: 0.5163 - age_out_accuracy: 0.0000e+00 - val_loss: 12.9858 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.1802 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 10.57677
# Epoch 56/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.9519 - sex_out_loss: 0.6928 - age_out_loss: 6.1461 - sex_out_accuracy: 0.5144 - age_out_accuracy: 0.0000e+00 - val_loss: 14.1653 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.3580 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 10.57677
# Epoch 57/500
# 120/120 [==============================] - 2s 13ms/step - loss: 6.8574 - sex_out_loss: 0.6929 - age_out_loss: 6.0500 - sex_out_accuracy: 0.5110 - age_out_accuracy: 0.0000e+00 - val_loss: 15.3532 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.5461 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 10.57677
# Epoch 58/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7597 - sex_out_loss: 0.6929 - age_out_loss: 5.9527 - sex_out_accuracy: 0.5129 - age_out_accuracy: 0.0000e+00 - val_loss: 13.3847 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.5769 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 10.57677
# Epoch 59/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7073 - sex_out_loss: 0.6923 - age_out_loss: 5.9002 - sex_out_accuracy: 0.5218 - age_out_accuracy: 0.0000e+00 - val_loss: 15.1540 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.3449 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 10.57677
# Epoch 60/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6796 - sex_out_loss: 0.6926 - age_out_loss: 5.8703 - sex_out_accuracy: 0.5168 - age_out_accuracy: 0.0000e+00 - val_loss: 15.2202 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.4104 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 10.57677
# Epoch 61/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8020 - sex_out_loss: 0.6924 - age_out_loss: 5.9924 - sex_out_accuracy: 0.5197 - age_out_accuracy: 0.0000e+00 - val_loss: 17.8977 - val_sex_out_loss: 0.6930 - val_age_out_loss: 17.0871 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 10.57677
# Epoch 62/500
# 120/120 [==============================] - 2s 13ms/step - loss: 6.9089 - sex_out_loss: 0.6929 - age_out_loss: 6.0976 - sex_out_accuracy: 0.5121 - age_out_accuracy: 0.0000e+00 - val_loss: 11.9131 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.1008 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 10.57677
# Epoch 63/500
# 120/120 [==============================] - 2s 14ms/step - loss: 7.0959 - sex_out_loss: 0.6921 - age_out_loss: 6.2847 - sex_out_accuracy: 0.5257 - age_out_accuracy: 0.0000e+00 - val_loss: 10.7553 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.9425 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 10.57677
# Epoch 64/500
# 120/120 [==============================] - 2s 14ms/step - loss: 7.2715 - sex_out_loss: 0.6918 - age_out_loss: 6.4597 - sex_out_accuracy: 0.5299 - age_out_accuracy: 0.0000e+00 - val_loss: 13.5558 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.7413 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 10.57677
# Epoch 65/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7899 - sex_out_loss: 0.6928 - age_out_loss: 5.9756 - sex_out_accuracy: 0.5140 - age_out_accuracy: 0.0000e+00 - val_loss: 15.3798 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.5652 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 10.57677
# Epoch 66/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8569 - sex_out_loss: 0.6929 - age_out_loss: 6.0416 - sex_out_accuracy: 0.5111 - age_out_accuracy: 0.0000e+00 - val_loss: 15.8247 - val_sex_out_loss: 0.6930 - val_age_out_loss: 15.0081 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 10.57677
# Epoch 67/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8209 - sex_out_loss: 0.6930 - age_out_loss: 6.0039 - sex_out_accuracy: 0.5100 - age_out_accuracy: 0.0000e+00 - val_loss: 15.4357 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.6181 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 10.57677
# Epoch 68/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7156 - sex_out_loss: 0.6923 - age_out_loss: 5.8981 - sex_out_accuracy: 0.5221 - age_out_accuracy: 0.0000e+00 - val_loss: 16.0036 - val_sex_out_loss: 0.6930 - val_age_out_loss: 15.1851 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 10.57677
# Epoch 69/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.9178 - sex_out_loss: 0.6926 - age_out_loss: 6.0996 - sex_out_accuracy: 0.5173 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2953 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4751 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 10.57677
# Epoch 70/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5950 - sex_out_loss: 0.6930 - age_out_loss: 5.7742 - sex_out_accuracy: 0.5099 - age_out_accuracy: 0.0000e+00 - val_loss: 13.8549 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.0331 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 10.57677
# Epoch 71/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8572 - sex_out_loss: 0.6924 - age_out_loss: 6.0356 - sex_out_accuracy: 0.5195 - age_out_accuracy: 0.0000e+00 - val_loss: 15.2176 - val_sex_out_loss: 0.6930 - val_age_out_loss: 14.3940 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 10.57677
# Epoch 72/500
# 120/120 [==============================] - 2s 13ms/step - loss: 6.6471 - sex_out_loss: 0.6929 - age_out_loss: 5.8236 - sex_out_accuracy: 0.5127 - age_out_accuracy: 0.0000e+00 - val_loss: 12.5694 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.7466 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 10.57677
# Epoch 73/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8139 - sex_out_loss: 0.6922 - age_out_loss: 5.9914 - sex_out_accuracy: 0.5225 - age_out_accuracy: 0.0000e+00 - val_loss: 13.4021 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.5771 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 10.57677
# Epoch 74/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7434 - sex_out_loss: 0.6926 - age_out_loss: 5.9182 - sex_out_accuracy: 0.5170 - age_out_accuracy: 0.0000e+00 - val_loss: 12.4828 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.6566 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 10.57677
# Epoch 75/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7964 - sex_out_loss: 0.6924 - age_out_loss: 5.9709 - sex_out_accuracy: 0.5200 - age_out_accuracy: 0.0000e+00 - val_loss: 11.9064 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.0792 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 10.57677
# Epoch 76/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6846 - sex_out_loss: 0.6930 - age_out_loss: 5.8573 - sex_out_accuracy: 0.5108 - age_out_accuracy: 0.0000e+00 - val_loss: 13.9934 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.1652 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 10.57677
# Epoch 77/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6793 - sex_out_loss: 0.6929 - age_out_loss: 5.8508 - sex_out_accuracy: 0.5121 - age_out_accuracy: 0.0000e+00 - val_loss: 11.8191 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.9890 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 10.57677
# Epoch 78/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6560 - sex_out_loss: 0.6929 - age_out_loss: 5.8255 - sex_out_accuracy: 0.5122 - age_out_accuracy: 0.0000e+00 - val_loss: 12.9137 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.0822 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 10.57677
# Epoch 79/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8162 - sex_out_loss: 0.6924 - age_out_loss: 5.9852 - sex_out_accuracy: 0.5195 - age_out_accuracy: 0.0000e+00 - val_loss: 13.9974 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.1652 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 10.57677
# Epoch 80/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6363 - sex_out_loss: 0.6929 - age_out_loss: 5.8041 - sex_out_accuracy: 0.5120 - age_out_accuracy: 0.0000e+00 - val_loss: 11.4284 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.5953 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 10.57677
# Epoch 81/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7023 - sex_out_loss: 0.6929 - age_out_loss: 5.8689 - sex_out_accuracy: 0.5124 - age_out_accuracy: 0.0000e+00 - val_loss: 10.9649 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.1306 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 10.57677
# Epoch 82/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8110 - sex_out_loss: 0.6931 - age_out_loss: 5.9759 - sex_out_accuracy: 0.5094 - age_out_accuracy: 0.0000e+00 - val_loss: 12.8791 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.0428 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 10.57677
# Epoch 83/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5514 - sex_out_loss: 0.6917 - age_out_loss: 5.7160 - sex_out_accuracy: 0.5316 - age_out_accuracy: 0.0000e+00 - val_loss: 13.3273 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.4898 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 10.57677
# Epoch 84/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6792 - sex_out_loss: 0.6923 - age_out_loss: 5.8424 - sex_out_accuracy: 0.5217 - age_out_accuracy: 0.0000e+00 - val_loss: 13.7921 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.9544 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 10.57677
# Epoch 85/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7145 - sex_out_loss: 0.6927 - age_out_loss: 5.8765 - sex_out_accuracy: 0.5159 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2436 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4040 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 10.57677
# Epoch 86/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7321 - sex_out_loss: 0.6927 - age_out_loss: 5.8926 - sex_out_accuracy: 0.5147 - age_out_accuracy: 0.0000e+00 - val_loss: 11.2465 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.4062 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 10.57677
# Epoch 87/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6303 - sex_out_loss: 0.6928 - age_out_loss: 5.7903 - sex_out_accuracy: 0.5143 - age_out_accuracy: 0.0000e+00 - val_loss: 13.5452 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.7035 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 10.57677
# Epoch 88/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6258 - sex_out_loss: 0.6929 - age_out_loss: 5.7842 - sex_out_accuracy: 0.5121 - age_out_accuracy: 0.0000e+00 - val_loss: 11.9405 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.0983 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 10.57677
# Epoch 89/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5502 - sex_out_loss: 0.6930 - age_out_loss: 5.7072 - sex_out_accuracy: 0.5108 - age_out_accuracy: 0.0000e+00 - val_loss: 11.7506 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.9071 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 10.57677
# Epoch 90/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5614 - sex_out_loss: 0.6926 - age_out_loss: 5.7185 - sex_out_accuracy: 0.5168 - age_out_accuracy: 0.0000e+00 - val_loss: 11.3412 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.4978 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 10.57677
# Epoch 91/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.7174 - sex_out_loss: 0.6930 - age_out_loss: 5.8736 - sex_out_accuracy: 0.5103 - age_out_accuracy: 0.0000e+00 - val_loss: 12.4174 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.5736 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 10.57677
# Epoch 92/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.8141 - sex_out_loss: 0.6931 - age_out_loss: 5.9698 - sex_out_accuracy: 0.5086 - age_out_accuracy: 0.0000e+00 - val_loss: 12.3002 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4551 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 10.57677
# Epoch 93/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5087 - sex_out_loss: 0.6930 - age_out_loss: 5.6638 - sex_out_accuracy: 0.5102 - age_out_accuracy: 0.0000e+00 - val_loss: 13.8734 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.0284 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 10.57677
# Epoch 94/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4804 - sex_out_loss: 0.6931 - age_out_loss: 5.6349 - sex_out_accuracy: 0.5093 - age_out_accuracy: 0.0000e+00 - val_loss: 10.6627 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.8166 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 10.57677
# Epoch 95/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4587 - sex_out_loss: 0.6920 - age_out_loss: 5.6134 - sex_out_accuracy: 0.5260 - age_out_accuracy: 0.0000e+00 - val_loss: 11.3491 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.5028 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 10.57677
# Epoch 96/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4554 - sex_out_loss: 0.6931 - age_out_loss: 5.6089 - sex_out_accuracy: 0.5093 - age_out_accuracy: 0.0000e+00 - val_loss: 10.9648 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.1176 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 10.57677
# Epoch 97/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6665 - sex_out_loss: 0.6928 - age_out_loss: 5.8192 - sex_out_accuracy: 0.5144 - age_out_accuracy: 0.0000e+00 - val_loss: 11.4953 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.6466 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 10.57677
# Epoch 98/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6139 - sex_out_loss: 0.6922 - age_out_loss: 5.7655 - sex_out_accuracy: 0.5239 - age_out_accuracy: 0.0000e+00 - val_loss: 10.1454 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.2949 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00098: val_loss improved from 10.57677 to 10.14542, saving model to Age_sex_detection.h5
# Epoch 99/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5162 - sex_out_loss: 0.6929 - age_out_loss: 5.6660 - sex_out_accuracy: 0.5118 - age_out_accuracy: 0.0000e+00 - val_loss: 11.8444 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.9946 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 10.14542
# Epoch 100/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3620 - sex_out_loss: 0.6926 - age_out_loss: 5.5124 - sex_out_accuracy: 0.5162 - age_out_accuracy: 0.0000e+00 - val_loss: 13.3652 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.5144 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 10.14542
# Epoch 101/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4396 - sex_out_loss: 0.6924 - age_out_loss: 5.5893 - sex_out_accuracy: 0.5196 - age_out_accuracy: 0.0000e+00 - val_loss: 11.5833 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.7316 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 10.14542
# Epoch 102/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5682 - sex_out_loss: 0.6927 - age_out_loss: 5.7165 - sex_out_accuracy: 0.5155 - age_out_accuracy: 0.0000e+00 - val_loss: 12.2611 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4090 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 10.14542
# Epoch 103/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5079 - sex_out_loss: 0.6930 - age_out_loss: 5.6557 - sex_out_accuracy: 0.5107 - age_out_accuracy: 0.0000e+00 - val_loss: 11.7272 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.8743 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00103: val_loss did not improve from 10.14542
# Epoch 104/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4824 - sex_out_loss: 0.6923 - age_out_loss: 5.6304 - sex_out_accuracy: 0.5221 - age_out_accuracy: 0.0000e+00 - val_loss: 10.9888 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.1356 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00104: val_loss did not improve from 10.14542
# Epoch 105/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4926 - sex_out_loss: 0.6923 - age_out_loss: 5.6398 - sex_out_accuracy: 0.5215 - age_out_accuracy: 0.0000e+00 - val_loss: 13.1701 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.3154 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00105: val_loss did not improve from 10.14542
# Epoch 106/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5155 - sex_out_loss: 0.6927 - age_out_loss: 5.6609 - sex_out_accuracy: 0.5155 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1091 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.2532 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00106: val_loss did not improve from 10.14542
# Epoch 107/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4622 - sex_out_loss: 0.6935 - age_out_loss: 5.6056 - sex_out_accuracy: 0.5019 - age_out_accuracy: 0.0000e+00 - val_loss: 12.4634 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.6066 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00107: val_loss did not improve from 10.14542
# Epoch 108/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4699 - sex_out_loss: 0.6926 - age_out_loss: 5.6132 - sex_out_accuracy: 0.5166 - age_out_accuracy: 0.0000e+00 - val_loss: 10.8693 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.0108 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00108: val_loss did not improve from 10.14542
# Epoch 109/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6490 - sex_out_loss: 0.6922 - age_out_loss: 5.7909 - sex_out_accuracy: 0.5235 - age_out_accuracy: 0.0000e+00 - val_loss: 12.9746 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.1156 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00109: val_loss did not improve from 10.14542
# Epoch 110/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4741 - sex_out_loss: 0.6926 - age_out_loss: 5.6157 - sex_out_accuracy: 0.5161 - age_out_accuracy: 0.0000e+00 - val_loss: 9.9136 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.0541 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00110: val_loss improved from 10.14542 to 9.91360, saving model to Age_sex_detection.h5
# Epoch 111/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.5315 - sex_out_loss: 0.6925 - age_out_loss: 5.6727 - sex_out_accuracy: 0.5178 - age_out_accuracy: 0.0000e+00 - val_loss: 10.1785 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.3188 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00111: val_loss did not improve from 9.91360
# Epoch 112/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.6632 - sex_out_loss: 0.6927 - age_out_loss: 5.8034 - sex_out_accuracy: 0.5152 - age_out_accuracy: 0.0000e+00 - val_loss: 12.6317 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.7706 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00112: val_loss did not improve from 9.91360
# Epoch 113/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3847 - sex_out_loss: 0.6928 - age_out_loss: 5.5234 - sex_out_accuracy: 0.5134 - age_out_accuracy: 0.0000e+00 - val_loss: 11.8620 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.9998 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00113: val_loss did not improve from 9.91360
# Epoch 114/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3841 - sex_out_loss: 0.6927 - age_out_loss: 5.5220 - sex_out_accuracy: 0.5151 - age_out_accuracy: 0.0000e+00 - val_loss: 10.7655 - val_sex_out_loss: 0.6930 - val_age_out_loss: 9.9028 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00114: val_loss did not improve from 9.91360
# Epoch 115/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4954 - sex_out_loss: 0.6935 - age_out_loss: 5.6322 - sex_out_accuracy: 0.5021 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1961 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.3323 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00115: val_loss did not improve from 9.91360
# Epoch 116/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3718 - sex_out_loss: 0.6925 - age_out_loss: 5.5085 - sex_out_accuracy: 0.5179 - age_out_accuracy: 0.0000e+00 - val_loss: 13.2694 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.4054 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00116: val_loss did not improve from 9.91360
# Epoch 117/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3001 - sex_out_loss: 0.6929 - age_out_loss: 5.4359 - sex_out_accuracy: 0.5121 - age_out_accuracy: 0.0000e+00 - val_loss: 12.3242 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4592 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00117: val_loss did not improve from 9.91360
# Epoch 118/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4326 - sex_out_loss: 0.6928 - age_out_loss: 5.5673 - sex_out_accuracy: 0.5143 - age_out_accuracy: 0.0000e+00 - val_loss: 12.3092 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.4429 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00118: val_loss did not improve from 9.91360
# Epoch 119/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4607 - sex_out_loss: 0.6927 - age_out_loss: 5.5946 - sex_out_accuracy: 0.5151 - age_out_accuracy: 0.0000e+00 - val_loss: 13.8824 - val_sex_out_loss: 0.6930 - val_age_out_loss: 13.0156 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00119: val_loss did not improve from 9.91360
# Epoch 120/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3238 - sex_out_loss: 0.6922 - age_out_loss: 5.4570 - sex_out_accuracy: 0.5228 - age_out_accuracy: 0.0000e+00 - val_loss: 13.0640 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.1959 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00120: val_loss did not improve from 9.91360
# Epoch 121/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3988 - sex_out_loss: 0.6927 - age_out_loss: 5.5307 - sex_out_accuracy: 0.5146 - age_out_accuracy: 0.0000e+00 - val_loss: 12.1479 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.2789 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00121: val_loss did not improve from 9.91360
# Epoch 122/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3098 - sex_out_loss: 0.6928 - age_out_loss: 5.4406 - sex_out_accuracy: 0.5128 - age_out_accuracy: 0.0000e+00 - val_loss: 12.9685 - val_sex_out_loss: 0.6930 - val_age_out_loss: 12.0985 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00122: val_loss did not improve from 9.91360
# Epoch 123/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.4752 - sex_out_loss: 0.6926 - age_out_loss: 5.6054 - sex_out_accuracy: 0.5162 - age_out_accuracy: 0.0000e+00 - val_loss: 11.5906 - val_sex_out_loss: 0.6930 - val_age_out_loss: 10.7206 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00123: val_loss did not improve from 9.91360
# Epoch 124/500
# 120/120 [==============================] - 2s 14ms/step - loss: 6.3618 - sex_out_loss: 0.6932 - age_out_loss: 5.4911 - sex_out_accuracy: 0.5067 - age_out_accuracy: 0.0000e+00 - val_loss: 12.4266 - val_sex_out_loss: 0.6930 - val_age_out_loss: 11.5558 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00124: val_loss did not improve from 9.91360
# Epoch 125/500
# ...
# Epoch 354/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.3755 - sex_out_loss: 0.6927 - age_out_loss: 4.4507 - sex_out_accuracy: 0.5157 - age_out_accuracy: 0.0000e+00 - val_loss: 8.8939 - val_sex_out_loss: 0.6930 - val_age_out_loss: 7.9684 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00354: val_loss did not improve from 6.00107
# Epoch 355/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.5198 - sex_out_loss: 0.6925 - age_out_loss: 4.5948 - sex_out_accuracy: 0.5190 - age_out_accuracy: 0.0000e+00 - val_loss: 7.6007 - val_sex_out_loss: 0.6930 - val_age_out_loss: 6.6748 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00355: val_loss did not improve from 6.00107
# Epoch 356/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.4446 - sex_out_loss: 0.6931 - age_out_loss: 4.5186 - sex_out_accuracy: 0.5088 - age_out_accuracy: 0.0000e+00 - val_loss: 6.2799 - val_sex_out_loss: 0.6930 - val_age_out_loss: 5.3541 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00356: val_loss did not improve from 6.00107
# Epoch 357/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.4982 - sex_out_loss: 0.6927 - age_out_loss: 4.5726 - sex_out_accuracy: 0.5158 - age_out_accuracy: 0.0000e+00 - val_loss: 7.8195 - val_sex_out_loss: 0.6930 - val_age_out_loss: 6.8934 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00357: val_loss did not improve from 6.00107
# Epoch 358/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.3565 - sex_out_loss: 0.6925 - age_out_loss: 4.4308 - sex_out_accuracy: 0.5193 - age_out_accuracy: 0.0000e+00 - val_loss: 7.5384 - val_sex_out_loss: 0.6930 - val_age_out_loss: 6.6124 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00358: val_loss did not improve from 6.00107
# Epoch 359/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.4567 - sex_out_loss: 0.6929 - age_out_loss: 4.5307 - sex_out_accuracy: 0.5117 - age_out_accuracy: 0.0000e+00 - val_loss: 7.4222 - val_sex_out_loss: 0.6930 - val_age_out_loss: 6.4959 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00359: val_loss did not improve from 6.00107
# Epoch 360/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.5061 - sex_out_loss: 0.6928 - age_out_loss: 4.5801 - sex_out_accuracy: 0.5134 - age_out_accuracy: 0.0000e+00 - val_loss: 7.6594 - val_sex_out_loss: 0.6930 - val_age_out_loss: 6.7332 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 00360: val_loss did not improve from 6.00107
# Epoch 361/500
# 120/120 [==============================] - 2s 15ms/step - loss: 5.3641 - sex_out_loss: 0.6933 - age_out_loss: 4.4376 - sex_out_accuracy: 0.5059 - age_out_accuracy: 0.0000e+00 - val_loss: 6.8987 - val_sex_out_loss: 0.6930 - val_age_out_loss: 5.9722 - val_sex_out_accuracy: 0.5102 - val_age_out_accuracy: 0.0000e+00
#
# Epoch 
report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1252
#            1       0.51      1.00      0.68      1304
#
#     accuracy                           0.51      2556
#    macro avg       0.26      0.50      0.34      2556
# weighted avg       0.26      0.51      0.34      2556
#
# Results:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FEDE0566550>
# Index: 276
# Actual age: 78
# Predicted Age: 73
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FEDE0566550>
# Index: 702
# Actual age: 78
# Predicted Age: 70
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9F86E950>
# Index: 1128
# Actual age: 78
# Predicted Age: 71
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9F854A50>
# Index: 1554
# Actual age: 78
# Predicted Age: 71
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E788790>
# Index: 195
# Actual age: 78
# Predicted Age: 73
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E740790>
# Index: 621
# Actual age: 78
# Predicted Age: 69
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E76ED90>
# Index: 1047
# Actual age: 78
# Predicted Age: 69
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E76EFD0>
# Index: 1473
# Actual age: 78
# Predicted Age: 70
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E76E210>
# Index: 257
# Actual age: 71
# Predicted Age: 65
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E725ED0>
# Index: 683
# Actual age: 71
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6C9F10>
# Index: 1109
# Actual age: 71
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6F8390>
# Index: 1535
# Actual age: 71
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E696310>
# Index: 249
# Actual age: 71
# Predicted Age: 64
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E70AD50>
# Index: 675
# Actual age: 71
# Predicted Age: 66
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E73DD90>
# Index: 1101
# Actual age: 71
# Predicted Age: 63
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E7A3610>
# Index: 1527
# Actual age: 71
# Predicted Age: 65
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E76EE50>
# Index: 93
# Actual age: 75
# Predicted Age: 67
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9F84DE50>
# Index: 519
# Actual age: 75
# Predicted Age: 68
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6E6310>
# Index: 945
# Actual age: 75
# Predicted Age: 71
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E741510>
# Index: 1371
# Actual age: 75
# Predicted Age: 70
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E7B4A10>
# Index: 72
# Actual age: 66
# Predicted Age: 62
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E65FB10>
# Index: 498
# Actual age: 66
# Predicted Age: 63
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6EEE10>
# Index: 924
# Actual age: 66
# Predicted Age: 63
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E73D290>
# Index: 1350
# Actual age: 66
# Predicted Age: 64
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E73D290>
# Index: 254
# Actual age: 70
# Predicted Age: 64
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E75FE90>
# Index: 680
# Actual age: 70
# Predicted Age: 65
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6F3650>
# Index: 1106
# Actual age: 70
# Predicted Age: 65
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E71E0D0>
# Index: 1532
# Actual age: 70
# Predicted Age: 66
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E675350>
# Index: 425
# Actual age: 65
# Predicted Age: 61
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6D6F50>
# Index: 851
# Actual age: 65
# Predicted Age: 62
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E675D50>
# Index: 1277
# Actual age: 65
# Predicted Age: 62
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E70A310>
# Index: 1703
# Actual age: 65
# Predicted Age: 61
# Actual sex: Male
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E754910>
# Index: 0
# Actual age: 80
# Predicted Age: 72
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E7B0310>
# Index: 426
# Actual age: 80
# Predicted Age: 72
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E731610>
# Index: 852
# Actual age: 80
# Predicted Age: 76
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E768750>
# Index: 1278
# Actual age: 80
# Predicted Age: 76
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E6D2E90>
# Index: 2556
# Actual age: 80
# Predicted Age: 71
# Actual sex: Female
# Predicted Sex: Female
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FED9E740190>
# Index: 5112
# Actual age: 80
# Predicted Age: 72
# Actual sex: Female
# Predicted Sex: Female
